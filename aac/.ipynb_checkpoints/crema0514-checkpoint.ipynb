# %% [markdown]
# ## Crowd-sourced Emotional Mutimodal Actors Dataset

# %% [markdown]
# ## Context
# I'm on a journey to create an emotion classifier from audio and the CREMA-D dataset is one of the 4 key datasets that I was lucky to stumble upon. What's interesting is that this dataset is the sheer variety of data which helps train a model that can be generalised across new datasets. Many audio datasets use a limited number of speakers which leads to a lot of information leakage. CREMA-D has many speakers. For this fact, the CREMA-D is a very good dataset to use to ensure the model does not overfit.
#
# 오디오에서 감정 분류기를 만드는 중이며 CREMA-D 데이터 세트는 우연히 발견한 4가지 핵심 데이터 세트 중 하나입니다. 흥미로운 점은 이 데이터셋이 새로운 데이터셋에 걸쳐 일반화할 수 있는 모델을 교육하는 데 도움이 되는 데이터의 다양성이라는 점입니다. 많은 오디오 데이터 세트는 제한된 수의 스피커를 사용하여 많은 정보 유출을 초래한다. CREMA-D에는 많은 스피커가 있습니다. 이 사실에서 CREMA-D는 모델이 과적합하지 않도록 하기 위해 사용하기 매우 좋은 데이터 세트이다.
#
# ## Content
# CREMA-D is a data set of 7,442 original clips from 91 actors. These clips were from 48 male and 43 female actors between the ages of 20 and 74 coming from a variety of races and ethnicities (African America, Asian, Caucasian, Hispanic, and Unspecified). Actors spoke from a selection of 12 sentences. The sentences were presented using one of six different emotions (Anger, Disgust, Fear, Happy, Neutral, and Sad) and four different emotion levels (Low, Medium, High, and Unspecified).
#
# CREMA-D는 91명의 배우로부터 7,442개의 원본 클립으로 구성된 데이터 세트이다. 이 동영상은 20세에서 74세 사이의 48명의 남성과 43명의 여성 배우들로부터 다양한 인종과 인종(아프리카계 미국, 아시아계, 백인계, 히스패닉계, 그리고 불특정다수)을 얻었다. 배우들은 12개의 문장으로 구성된 선곡에서 말했다. 문장은 여섯 가지 감정(분노, 혐오, 공포, 행복, 중립, 슬픔)과 네 가지 감정 수준(낮음, 중간, 높음, 지정되지 않음) 중 하나를 사용하여 제시되었다.
#
#
# ## Acknowledgements
# I wanted to thank David Cooper Cheyney for putting together this awesome dataset

# %%
import pandas as pd
import numpy as np

import os
import sys

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# to play the audio files
from IPython.display import Audio

import keras
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from keras.utils import np_utils, to_categorical
from keras.callbacks import ModelCheckpoint

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import os
import pandas as pd
CREMA = "./kaggle/cremad/AudioWAV/"
dir_list = os.listdir(CREMA)
dir_list[0:5]
# Out:
# ['1029_IOM_NEU_XX.wav',
#  '1024_TAI_NEU_XX.wav',
#  '1030_WSI_NEU_XX.wav',
#  '1036_IWL_DIS_XX.wav',
#  '1077_IEO_ANG_LO.wav']

# %% [markdown]
# ---

# %% [markdown]
# - tess-train / crema-test

# %%
import glob
TESS = "./kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad"
TESS_files=glob.glob(os.path.join(TESS + '*.wav'))

# %%
TESS_files
# Out:
# []

# %%
TESS = "./kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/"
dir_list = os.listdir(TESS)
dir_list[0:5]
# Out:
# ['YAF_happy',
#  'OAF_happy',
#  'OAF_disgust',
#  'OAF_neutral',
#  'OAF_Pleasant_surprise']

# %%
gender = []
emotion = []
path = []
female = [1002,1003,1004,1006,1007,1008,1009,1010,1012,1013,1018,1020,1021,1024,1025,1028,1029,1030,1037,1043,1046,1047,1049,
          1052,1053,1054,1055,1056,1058,1060,1061,1063,1072,1073,1074,1075,1076,1078,1079,1082,1084,1089,1091]

for i in dir_list: 
    part = i.split('_')
    if int(part[0]) in female:
        temp = 'female'
    else:
        temp = 'male'
    gender.append(temp)
    if part[2] == 'SAD' and temp == 'male':
        emotion.append('male_sad')
    elif part[2] == 'ANG' and temp == 'male':
        emotion.append('male_angry')
    elif part[2] == 'DIS' and temp == 'male':
        emotion.append('male_disgust')
    elif part[2] == 'FEA' and temp == 'male':
        emotion.append('male_fear')
    elif part[2] == 'HAP' and temp == 'male':
        emotion.append('male_happy')
    elif part[2] == 'NEU' and temp == 'male':
        emotion.append('male_neutral')
    elif part[2] == 'SAD' and temp == 'female':
        emotion.append('female_sad')
    elif part[2] == 'ANG' and temp == 'female':
        emotion.append('female_angry')
    elif part[2] == 'DIS' and temp == 'female':
        emotion.append('female_disgust')
    elif part[2] == 'FEA' and temp == 'female':
        emotion.append('female_fear')
    elif part[2] == 'HAP' and temp == 'female':
        emotion.append('female_happy')
    elif part[2] == 'NEU' and temp == 'female':
        emotion.append('female_neutral')
    else:
        emotion.append('Unknown')
    path.append(CREMA + i)
    
CREMA_df = pd.DataFrame(emotion, columns = ['labels'])
CREMA_df['source'] = 'CREMA'
CREMA_df = pd.concat([CREMA_df,pd.DataFrame(path, columns = ['path'])],axis=1)
CREMA_df.labels.value_counts()
# Out:
# male_fear         671
# male_sad          671
# male_angry        671
# male_disgust      671
# male_happy        671
# female_angry      600
# female_fear       600
# female_disgust    600
# female_happy      600
# female_sad        600
# male_neutral      575
# female_neutral    512
# Name: labels, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# Train set - TESS

# %%
dir_list
# Out:
# ['YAF_happy',
#  'OAF_happy',
#  'OAF_disgust',
#  'OAF_neutral',
#  'OAF_Pleasant_surprise',
#  'YAF_fear',
#  'YAF_disgust',
#  'YAF_pleasant_surprised',
#  'OAF_Fear',
#  'OAF_angry',
#  'YAF_sad',
#  'YAF_angry',
#  'YAF_neutral',
#  'OAF_Sad']

# %%
#TESS
TESS = "./kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/"
dir_list = os.listdir(TESS)
dir_list[0:5]
TESS_files=[]
emotion = []

for i in dir_list:
    fname = os.listdir(TESS + i)
    for f in fname:
        if i == 'OAF_angry' or i == 'YAF_angry':
            emotion.append('female_angry')
        elif i == 'OAF_disgust' or i == 'YAF_disgust':
            emotion.append('female_disgust')
        elif i == 'OAF_Fear' or i == 'YAF_fear':
            emotion.append('female_fear')
        elif i == 'OAF_happy' or i == 'YAF_happy':
            emotion.append('female_happy')
        elif i == 'OAF_neutral' or i == 'YAF_neutral':
            emotion.append('female_neutral')                                
        elif i == 'OAF_Pleasant_surprise' or i == 'YAF_pleasant_surprised':
            emotion.append('female_surprise')               
        elif i == 'OAF_Sad' or i == 'YAF_sad':
            emotion.append('female_sad')
        else:
            emotion.append('Unknown')
        TESS_files.append(TESS + i + "/" + f)

TESS_df = pd.DataFrame(emotion, columns = ['labels'])
TESS_df['source'] = 'TESS'
TESS_df = pd.concat([TESS_df,pd.DataFrame(path, columns = ['path'])],axis=1)
TESS_df.labels.value_counts()
# Out:
# female_surprise    400
# female_sad         400
# female_angry       400
# female_neutral     400
# female_happy       400
# female_fear        400
# female_disgust     400
# Name: labels, dtype: int64

# %%
TESS_files[0]
# Out:
# './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_mob_happy.wav'

# %%
TESS_df
# Out:
#             labels source path
# 0     female_happy   TESS  NaN
# 1     female_happy   TESS  NaN
# 2     female_happy   TESS  NaN
# 3     female_happy   TESS  NaN
# 4     female_happy   TESS  NaN
# ...            ...    ...  ...
# 2795    female_sad   TESS  NaN
# 2796    female_sad   TESS  NaN
# 2797    female_sad   TESS  NaN
# 2798    female_sad   TESS  NaN
# 2799    female_sad   TESS  NaN
#
# [2800 rows x 3 columns]

# %%
a=os.path.split(TESS_files[0])[-1]
b=os.path.splitext(a)[0]
print(b)
# Out:
# YAF_mob_happy

# %%
TESS_files
# Out:
# ['./kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_mob_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_peg_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_gun_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_chair_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_keep_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_void_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_raid_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_name_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_luck_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_lose_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_base_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_youth_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_learn_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_young_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_talk_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_boat_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_date_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_road_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_chain_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_half_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_book_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_red_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_life_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_white_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_join_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_cheek_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_wife_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_raise_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_chief_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_sure_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_vine_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_jail_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_good_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_get_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_wire_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_ditch_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_hall_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_lid_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_sheep_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_size_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_dime_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_loaf_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_walk_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_room_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_jar_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_laud_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_cool_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_have_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_mouse_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_bite_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_ton_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_met_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_bean_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_food_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_fat_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_deep_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_hash_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_burn_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_pearl_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_cause_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_lean_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_keg_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_phone_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_merge_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_knock_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_mill_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_near_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_take_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_beg_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_note_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_tire_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_which_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_rag_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_love_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_bought_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_page_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_team_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_goal_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_perch_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_bone_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_witch_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_rough_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_thumb_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_keen_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_read_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_haze_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_south_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_rot_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_soap_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_chalk_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_dab_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_vote_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_lot_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_far_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_sour_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_kill_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_turn_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_pole_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_yes_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_wheat_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_chat_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_make_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_moon_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_sell_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_hush_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_rain_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_mood_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_jug_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_voice_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_dodge_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_dip_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_kick_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_shout_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_bath_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_puff_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_when_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_time_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_pad_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_soup_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_numb_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_gap_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_tough_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_hurl_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_mop_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_rush_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_choice_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_such_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_rose_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_mode_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_reach_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_dead_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_germ_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_late_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_tape_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_lore_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_came_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_tool_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_bar_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_seize_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_sail_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_limb_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_pool_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_doll_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_ripe_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_live_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_wag_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_juice_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_search_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_fail_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_door_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_tell_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_kite_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_lease_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_hit_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_pike_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_nag_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_hire_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_pick_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_fall_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_king_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_gaze_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_check_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_pain_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_home_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_third_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_gin_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_goose_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_shawl_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_dog_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_rat_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_gas_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_hate_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_week_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_match_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_calm_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_long_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_should_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_whip_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_thin_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_shall_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_mess_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_sub_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_shack_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_ring_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_tip_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_judge_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_yearn_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_neat_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_wash_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_thought_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_pass_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_hole_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_back_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_shirt_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_said_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_nice_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_death_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_cab_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_fit_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_five_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_lease_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_note_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_rat_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_talk_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_rough_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_gas_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_bar_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_soup_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_dime_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_lot_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_lid_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_tell_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_cool_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_knock_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_have_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_judge_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_thin_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_long_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_doll_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_ton_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_search_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_limb_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_king_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_shawl_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_keen_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_vote_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_page_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_tool_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_sub_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_nag_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_bean_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_keg_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_turn_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_room_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_fail_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_met_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_tape_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_chief_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_moon_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_team_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_haze_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_wag_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_hall_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_goal_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_whip_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_perch_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_take_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_rush_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_home_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_germ_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_road_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_raid_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_soap_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_raise_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_tire_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_walk_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_phone_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_good_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_jail_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_base_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_kite_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_week_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_mob_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_ditch_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_void_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_half_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_gun_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_ripe_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_pick_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_fall_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_back_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_bath_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_rag_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_mood_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_door_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_keep_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_death_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_gin_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_wash_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_pool_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_reach_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_chain_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_pearl_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_hurl_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_young_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_hush_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_lore_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_hate_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_hole_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_tough_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_should_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_dab_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_pole_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_near_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_get_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_read_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_lean_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_laud_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_burn_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_yearn_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_voice_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_nice_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_check_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_cab_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_said_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_name_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_wife_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_pad_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_mess_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_size_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_sure_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_fat_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_gaze_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_late_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_book_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_dog_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_shirt_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_chair_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_shout_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_luck_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_make_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_wheat_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_rot_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_deep_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_third_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_mill_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_beg_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_came_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_love_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_south_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_mop_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_thumb_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_red_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_shack_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_seize_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_pass_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_sail_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_bone_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_hire_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_join_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_pike_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_dodge_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_lose_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_chat_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_peg_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_white_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_hit_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_goose_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_rose_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_five_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_live_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_youth_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_such_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_bought_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_when_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_jar_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_fit_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_learn_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_which_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_far_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_dead_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_merge_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_mouse_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_cheek_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_juice_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_puff_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_dip_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_gap_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_life_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_time_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_sour_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_thought_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_jug_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_calm_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_rain_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_boat_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_shall_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_mode_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_food_happy.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_kick_happy.wav',
# ...
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_pole_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_life_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_pearl_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_take_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_learn_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_mood_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_note_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_sub_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_week_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_loaf_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_shack_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_pass_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_keep_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_wash_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_ton_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_dab_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_date_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_raise_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_cheek_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_such_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_match_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_witch_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_tough_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_moon_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_kill_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_fat_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_cool_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_shirt_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_mob_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_hush_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_pad_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_jail_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_home_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_neat_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_goose_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_mode_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_rough_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_have_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_lore_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_puff_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_sure_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_laud_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_bone_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_mill_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_tape_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_hit_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_yearn_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_choice_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_keen_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_hall_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_nag_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_bar_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_jar_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_near_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_voice_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_seize_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_half_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_limb_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_thought_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_youth_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_said_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_search_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_road_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_hire_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_late_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_when_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_mop_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_burn_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_gun_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_merge_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_pool_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_read_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_shawl_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_which_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_numb_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_dog_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_join_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_south_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_peg_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_sell_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_book_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_doll_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_pick_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_base_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_sour_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_should_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_soap_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_gaze_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_get_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_cab_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_good_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_white_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_fall_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_time_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_young_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_yes_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_dip_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_gin_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_turn_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_lot_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_void_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_judge_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_hash_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_germ_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_gas_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_dodge_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_vine_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_rose_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_cause_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_food_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_bean_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_soup_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_lean_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_hate_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_chain_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_team_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_rag_ps.wav',
#  './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Pleasant_surprise/OAF_tool_ps.wav',
#  ...]

# %%
train_db=[]
for filename in TESS_files:
    path = {}
    path['filename'] = filename    
           
    filename = os.path.split(filename)[-1]
    filename = os.path.splitext(filename)[0]
    #filename = re.sub('[ㄱ-ㅣ가-힣()]','',filename).rstrip('_')
    
    path['emotion'] = filename.split('_')[2]
    path['actor'] = filename.split('_')[0]
    path['word'] = filename.split('_')[1]
    
    
    if filename.split('_')[2] == 'fear':
        path['label'] = 3
    elif filename.split('_')[2] == 'angry':
        path['label'] = 1
    elif filename.split('_')[2] == 'disgust':
        path['label'] = 2
    elif filename.split('_')[2] == 'happy':
        path['label'] = 4   
    elif filename.split('_')[2] == 'neutral':
        path['label'] = 5    
    elif filename.split('_')[2] == 'sad':
        path['label'] = 0
    else:
        continue
    
    #samples, sample_rate = librosa.load(path['filename'], res_type='kaiser_fast')
    #samples_trim, index = librosa.effects.trim(samples,top_db=20)
    #path['duration'] = round(librosa.get_duration(samples),3)
    #path['sr']= sample_rate
    train_db.append(path)
       
    df=pd.DataFrame(train_db)

# %%
train_db
# Out:
# [{'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_mob_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'mob',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_peg_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'peg',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_gun_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'gun',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_chair_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'chair',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_keep_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'keep',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_void_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'void',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_raid_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'raid',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_name_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'name',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_luck_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'luck',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_lose_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'lose',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_base_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'base',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_youth_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'youth',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF

#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_turn_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'turn',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_time_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'time',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_void_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'void',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_pole_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'pole',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_pain_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'pain',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_hate_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'hate',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_shirt_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'shirt',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_kick_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'kick',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_vote_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'vote',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_said_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'said',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_love_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'love',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_live_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'live',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_tip_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'tip',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_cheek_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'cheek',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_luck_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'luck',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_chalk_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'chalk',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_when_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'when',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_numb_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'numb',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_bath_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'bath',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_tell_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'tell',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_search_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'search',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_week_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'week',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_dip_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'dip',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_room_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'room',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_vine_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'vine',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_walk_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'walk',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_fit_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'fit',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_dog_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'dog',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_back_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'back',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_sell_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'sell',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_voice_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'voice',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_chair_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'chair',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_cause_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'cause',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_make_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'make',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_hash_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'hash',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_third_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'third',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_hit_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'hit',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_join_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'join',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_gaze_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'gaze',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_food_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'food',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_half_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'half',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_size_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'size',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_team_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'team',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_moon_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'moon',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_nag_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'nag',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_lot_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'lot',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_soap_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'soap',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_yes_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'yes',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_should_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'should',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_gun_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'gun',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_bite_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'bite',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_came_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'came',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_knock_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'knock',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_sure_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'sure',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_tough_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'tough',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_met_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'met',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_tape_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'tape',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_limb_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'limb',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_whip_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'whip',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_good_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'good',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_pearl_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'pearl',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_pike_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'pike',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_get_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'get',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_seize_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'seize',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_late_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'late',
#   'label': 3},
#  ...]

# %% [markdown]
# ---

# %% [markdown]
# test- crema

# %%
#dir
import os
import pandas as pd
CREMA = "./kaggle/input/cremad/AudioWAV/"
dir_list = os.listdir(CREMA)
dir_list[0:5]
# Out:
# ['1029_IOM_NEU_XX.wav',
#  '1024_TAI_NEU_XX.wav',
#  '1030_WSI_NEU_XX.wav',
#  '1036_IWL_DIS_XX.wav',
#  '1077_IEO_ANG_LO.wav']

# %%
gender = []
emotion = []
crema_files = []
female = [1002,1003,1004,1006,1007,1008,1009,1010,1012,1013,1018,1020,1021,1024,1025,1028,1029,1030,1037,1043,1046,1047,1049,
          1052,1053,1054,1055,1056,1058,1060,1061,1063,1072,1073,1074,1075,1076,1078,1079,1082,1084,1089,1091]

for i in dir_list: 
    part = i.split('_')
    if int(part[0]) in female:
        temp = 'female'
    else:
        temp = 'male'
    gender.append(temp)
    if part[2] == 'SAD' and temp == 'male':
        emotion.append('male_sad')
    elif part[2] == 'ANG' and temp == 'male':
        emotion.append('male_angry')
    elif part[2] == 'DIS' and temp == 'male':
        emotion.append('male_disgust')
    elif part[2] == 'FEA' and temp == 'male':
        emotion.append('male_fear')
    elif part[2] == 'HAP' and temp == 'male':
        emotion.append('male_happy')
    elif part[2] == 'NEU' and temp == 'male':
        emotion.append('male_neutral')
    elif part[2] == 'SAD' and temp == 'female':
        emotion.append('female_sad')
    elif part[2] == 'ANG' and temp == 'female':
        emotion.append('female_angry')
    elif part[2] == 'DIS' and temp == 'female':
        emotion.append('female_disgust')
    elif part[2] == 'FEA' and temp == 'female':
        emotion.append('female_fear')
    elif part[2] == 'HAP' and temp == 'female':
        emotion.append('female_happy')
    elif part[2] == 'NEU' and temp == 'female':
        emotion.append('female_neutral')
    else:
        emotion.append('Unknown')
    crema_files.append(CREMA + i)
    
CREMA_df = pd.DataFrame(emotion, columns = ['labels'])
CREMA_df['source'] = 'CREMA'
CREMA_df = pd.concat([CREMA_df,pd.DataFrame(path, columns = ['path'])],axis=1)
CREMA_df.labels.value_counts()
# Out:
# male_fear         671
# male_sad          671
# male_angry        671
# male_disgust      671
# male_happy        671
# female_angry      600
# female_fear       600
# female_disgust    600
# female_happy      600
# female_sad        600
# male_neutral      575
# female_neutral    512
# Name: labels, dtype: int64

# %%
crema_files
# Out:
# ['./kaggle/cremad/AudioWAV/1029_IOM_NEU_XX.wav',
#  './kaggle/cremad/AudioWAV/1024_TAI_NEU_XX.wav',
#  './kaggle/cremad/AudioWAV/1030_WSI_NEU_XX.wav',
#  './kaggle/cremad/AudioWAV/1036_IWL_DIS_XX.wav',
#  './kaggle/cremad/AudioWAV/1077_IEO_ANG_LO.wav',
#  './kaggle/cremad/AudioWAV/
_ANG_XX.wav',
#  './kaggle/cremad/AudioWAV/1012_MTI_FEA_XX.wav',
#  './kaggle/cremad/AudioWAV/1051_IEO_DIS_MD.wav',
#  './kaggle/cremad/AudioWAV/1034_TSI_DIS_XX.wav',
#  './kaggle/cremad/AudioWAV/1044_IWL_DIS_XX.wav',
#  './kaggle/cremad/AudioWAV/1033_IEO_SAD_MD.wav',
#  './kaggle/cremad/AudioWAV/1090_TIE_ANG_XX.wav',
#  './kaggle/cremad/AudioWAV/1007_ITS_ANG_XX.wav',
#  './kaggle/cremad/AudioWAV/1010_DFA_FEA_XX.wav',
#  './kaggle/cremad/AudioWAV/1039_WSI_DIS_XX.wav',
#  './kaggle/cremad/AudioWAV/1079_IWW_HAP_XX.wav',
#  './kaggle/cremad/AudioWAV/1044_MTI_NEU_XX.wav',
#  './kaggle/cremad/AudioWAV/1035_ITH_HAP_XX.wav',
#  './kaggle/cremad/AudioWAV/1026_ITS_ANG_XX.wav',
#  './kaggle/cremad/AudioWAV/1060_TAI_SAD_XX.wav',
#  './kaggle/cremad/AudioWAV/1043_IEO_NEU_XX.wav',
#  './kaggle/cremad/AudioWAV/1006_IWW_SAD_XX.wav',
#  './kaggle/cremad/AudioWAV/1079_TAI_SAD_XX.wav',
#  './kaggle/cremad/AudioWAV/1081_IEO_NEU_XX.wav',
#  './kaggle/cremad/AudioWAV/1030_MTI_DIS_XX.wav',
#  './kaggle/cremad/AudioWAV/1063_TAI_DIS_XX.wav',
#  './kaggle/cremad/AudioWAV/1079_TIE_NEU_XX.wav',
#  './kaggle/cremad/AudioWAV/1005_MTI_FEA_XX.wav',
#  './kaggle/cremad/AudioWAV/1013_IEO_DIS_MD.wav',
#  './kaggle/cremad/AudioWAV/1014_IWL_SAD_XX.wav',
#  './kaggle/cremad/AudioWAV/1088_DFA_NEU_XX.wav',
#  './kaggle/cremad/AudioWAV/1018_IEO_FEA_HI.wav',
#  './kaggle/cremad/AudioWAV/1032_MTI_SAD_XX.wav',
#  './kaggle/cremad/AudioWAV/1012_TIE_SAD_XX.wav',
#  './kaggle/cremad/AudioWAV/1007_ITH_ANG_XX.wav',
#  './kaggle/cremad/AudioWAV/1041_TSI_FEA_XX.wav',
#  './kaggle/cremad/AudioWAV/1054_DFA_DIS_XX.wav',
#  './kaggle/cremad/AudioWAV/1062_DFA_NEU_XX.wav',
#  './kaggle/cremad/AudioWAV/1049_DFA_ANG_XX.wav',
#  './kaggle/cremad/AudioWAV/1012_TSI_HAP_XX.wav',
#  './kaggle/cremad/AudioWAV/1043_IEO_SAD_MD.wav',
#  './kaggle/cremad/AudioWAV/1028_IEO_HAP_MD.wav',
#  './kaggle/cremad/AudioWAV/1031_TAI_ANG_XX.wav',
#  './kaggle/cremad/AudioWAV/1003_IOM_SAD_XX.wav',
#  './kaggle/cremad/AudioWAV/1045_MTI_DIS_XX.wav',
#  './kaggle/cremad/AudioWAV/1001_TIE_NEU_XX.wav',
#  './kaggle/cremad/AudioWAV/1076_IWW_NEU_XX.wav',
#  './kaggle/cremad/AudioWAV/1007_MTI_NEU_XX.wav',
#  './kaggle/cremad/AudioWAV/1078_IWL_HAP_XX.wav',
#  './kaggle/cremad/AudioWAV/1062_IWL_HAP_XX.wav',
#  './kaggle/cremad/AudioWAV/1021_WSI_FEA_XX.wav',
#  './kaggle/cremad/AudioWAV/1055_TIE_FEA_XX.wav',
#  './kaggle/cremad/AudioWAV/1061_TSI_FEA_XX.wav',
#  './kaggle/cremad/AudioWAV/1067_TIE_ANG_XX.wav',
#  './kaggle/cremad/AudioWAV/1054_WSI_ANG_XX.wav',
#  './kaggle/cremad/AudioWAV/1055_IOM_ANG_XX.wav',
#  './kaggle/cremad/AudioWAV/1057_DFA_SAD_XX.wav',
#  './kaggle/cremad/AudioWAV/1063_IEO_HAP_HI.wav',
#  './kaggle/cremad/AudioWAV/1010_IEO_SAD_LO.wav',
#  './kaggle/cremad/AudioWAV/1067_ITS_SAD_XX.wav',
#  './kaggle/cremad/AudioWAV/1081_WSI_DIS_XX.wav',
#  './kaggle/cremad/AudioWAV/1079_ITH_HAP_XX.wav',
#  './kaggle/cremad/AudioWAV/1014_IEO_FEA_HI.wav',
#  './kaggle/cremad/AudioWAV/1090_IWL_HAP_XX.wav',
#  './kaggle/cremad/AudioWAV/1019_TSI_ANG_XX.wav',
#  './kaggle/cremad/AudioWAV/1085_IOM_FEA_XX.wav',
#  './kaggle/cremad/AudioWAV/1040_TIE_HAP_XX.wav',
#  './kaggle/cremad/AudioWAV/1057_IEO_SAD_LO.wav',
#  './kaggle/cremad/AudioWAV/1030_ITS_ANG_XX.wav',
#  './kaggle/cremad/AudioWAV/1023_TIE_NEU_XX.wav',
#  './kaggle/cremad/AudioWAV/1005_IEO_HAP_HI.wav',
#  './kaggle/cremad/AudioWAV/1030_IOM_DIS_XX.wav',
#  './kaggle/cremad/AudioWAV/1062_DFA_SAD_XX.wav',
#  './kaggle/cremad/AudioWAV/1026_IWL_ANG_XX.wav',
#  './kaggle/cremad/AudioWAV/1084_TAI_ANG_XX.wav',
#  './kaggle/cremad/AudioWAV/1065_IWL_HAP_XX.wav',
#  './kaggle/cremad/AudioWAV/1081_TAI_HAP_XX.wav',
#  './kaggle/cremad/AudioWAV/1034_TAI_DIS_XX.wav',
#  './kaggle/cremad/AudioWAV/1062_TIE_DIS_XX.wav',
#  './kaggle/cremad/AudioWAV/1046_ITH_HAP_XX.wav',
#  './kaggle/cremad/AudioWAV/1081_TSI_FEA_XX.wav',
#  './kaggle/cremad/AudioWAV/1054_IOM_HAP_XX.wav',
#  './kaggle/cremad/AudioWAV/1010_TSI_HAP_XX.wav',
#  './kaggle/cremad/AudioWAV/1077_IOM_FEA_XX.wav',
#  './kaggle/cremad/AudioWAV/1076_DFA_HAP_XX.wav',
#  './kaggle/cremad/AudioWAV/1046_ITS_NEU_XX.wav',
#  './kaggle/cremad/AudioWAV/1033_ITH_ANG_XX.wav',
#  './kaggle/cremad/AudioWAV/1069_DFA_NEU_XX.wav',
#  './kaggle/cremad/AudioWAV/1065_MTI_SAD_XX.wav',
#  './kaggle/cremad/AudioWAV/1039_TSI_ANG_XX.wav',
#  './kaggle/cremad/AudioWAV/1062_ITH_HAP_XX.wav',
#  './kaggle/cremad/AudioWAV/1033_ITS_HAP_XX.wav',
#  ...]

# %%
crema_files[0]
# Out:
# './kaggle/cremad/AudioWAV/1029_IOM_NEU_XX.wav'

# %%
test_db=[]
for filename in crema_files:
    path = {}
    path['filename'] = filename    
           
    filename = os.path.split(filename)[-1]
    filename = os.path.splitext(filename)[0]
    #filename = re.sub('[ㄱ-ㅣ가-힣()]','',filename).rstrip('_')
    
    path['emotion'] = filename.split('_')[2]
    path['actor'] = filename.split('_')[0]
    #path['word'] = filename.split('_')[1]
    
    
    if filename.split('_')[2] == 'SAD':
        path['label'] = 0
    elif filename.split('_')[2] == 'ANG':
        path['label'] = 1
    elif filename.split('_')[2] == 'DIS':
        path['label'] = 2
    elif filename.split('_')[2] == 'FEA' :
        path['label'] = 3
    elif filename.split('_')[2] == 'HAP':
        path['label'] = 4
    elif filename.split('_')[2] == 'NEU' :
        path['label'] = 5

    #samples, sample_rate = librosa.load(path['filename'], res_type='kaiser_fast')
    #samples_trim, index = librosa.effects.trim(samples,top_db=20)
    #path['duration'] = round(librosa.get_duration(samples),3)
    #path['sr']= sample_rate
    test_db.append(path)
    
df=pd.DataFrame(test_db)

# %%
test_db
# Out:
# [{'filename': './kaggle/input/cremad/AudioWAV/1029_IOM_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1029',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1024_TAI_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1024',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1030_WSI_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1030',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1036_IWL_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1036',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1077_IEO_ANG_LO.wav',
#   'emotion': 'ANG',
#   'actor': '1077',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1057_IWW_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1057',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1030_IWL_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1030',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1057_ITS_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1057',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1064_IWW_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1064',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1032_IOM_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1032',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1034_TSI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1034',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1071_TSI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1071',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1004_ITS_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1004',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1025_IEO_SAD_MD.wav',
#   'emotion': 'SAD',
#   'actor': '1025',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1046_WSI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1046',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1011_ITS_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1011',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1012_ITH_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1012',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1081_IEO_HAP_LO.wav',
#   'emotion': 'HAP',
#   'actor': '1081',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1067_IWW_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1067',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1065_TIE_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1065',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1042_TAI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1042',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1080_IEO_ANG_LO.wav',
#   'emotion': 'ANG',
#   'actor': '1080',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1044_ITH_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1044',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1042_TSI_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1042',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1090_IWL_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1090',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1074_ITS_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1074',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1074_MTI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1074',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1046_TAI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1046',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1070_WSI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1070',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1047_TAI_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1047',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1024_IOM_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1024',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1087_IWL_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1087',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1061_IEO_HAP_MD.wav',
#   'emotion': 'HAP',
#   'actor': '1061',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1056_ITH_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1056',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1090_TAI_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1090',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1078_TAI_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1078',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1030_IWL_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1030',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1050_MTI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1050',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1054_IWW_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1054',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1064_DFA_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1064',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1086_TIE_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1086',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1026_MTI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1026',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1001_IEO_SAD_MD.wav',
#   'emotion': 'SAD',
#   'actor': '

#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1065_IWL_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1065',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1081_TAI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1081',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1034_TAI_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1034',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1062_TIE_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1062',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1046_ITH_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1046',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1081_TSI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1081',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1054_IOM_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1054',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1010_TSI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1010',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1077_IOM_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1077',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1076_DFA_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1076',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1046_ITS_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1046',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1033_ITH_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1033',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1069_DFA_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1069',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1065_MTI_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1065',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1039_TSI_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1039',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1062_ITH_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1062',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1033_ITS_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1033',
#   'label': 4},
#  ...]

# %% [markdown]
# ---

# %% [markdown]
# train 3d로그멜 뽑기

# %%
import numpy as np
import noisereduce as nr 

import scipy
import soundfile as sf
import librosa
from tqdm import tqdm 

sample_rate = 16000
top_db = 25
sec= 3
max_amp = 1

nfilt = 40
NFFT = 512
frame_size = 0.025
frame_stride = 0.01
pre_emphasis = False

low_freq = 300
high_freq = 8000

# %%
audio_filepath = [audio["filename"] for audio in train_db]

# %%
import warnings
warnings.filterwarnings(action='ignore')


#feature = 'mel-delta-128_fill0_1'
#output_dir = os.path.join('/Data2/emotion/features', feature)

feature = 'tess_delta_logmel'
output_dir = os.path.join('./features', feature)

overlap = True

#def deltas(X_in):
#    X_out = (X_in[:,2:,:]-X_in[:,:-2,:])/10.0
#    X_out = X_out[:,1:-1,:]+(X_in[:,4:,:]-X_in[:,:-4,:])/5.0
#    return X_out

def deltas(X_in):
    X_out = (X_in[:,1:,:]-X_in[:,:-1,:])/2.0
    X_out = X_out[:,1:,:]+(X_in[:,2:,:]-X_in[:,:-2,:])/8.0
    return X_out

if not os.path.exists(output_dir) or overlap == True:
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    low_freq_mel = (2595 * np.log10(1 + low_freq / 700))  # Convert Hz to Mel
    high_freq_mel = (2595 * np.log10(1 + high_freq / 700))  # Convert Hz to Mel
    mel_points = np.linspace(low_freq_mel, high_freq_mel, nfilt + 2)  # Equally spaced in Mel scale
    hz_points = (700 * (10**(mel_points / 2595) - 1))  # Convert Mel to Hz
    bin = np.floor((NFFT + 1) * hz_points / sample_rate)

    fbank = np.zeros((nfilt, int(np.floor(NFFT / 2 + 1))))
    for m in range(1, nfilt + 1):
        f_m_minus = int(bin[m - 1])   # left
        f_m = int(bin[m])             # center
        f_m_plus = int(bin[m + 1])    # right

        for k in range(f_m_minus, f_m):
            fbank[m - 1, k] = (k - bin[m - 1]) / (bin[m] - bin[m - 1])
        for k in range(f_m, f_m_plus):
            fbank[m - 1, k] = (bin[m + 1] - k) / (bin[m + 1] - bin[m])

    pbar = tqdm(audio_filepath)
    for filepath in pbar:
        #print("{}: Processing {} ({}/{})".format(feature, filepath, file_idx+1, num_files))

        _, current_last_level_path = os.path.split(filepath)
        base_filename, _ = os.path.splitext(current_last_level_path)
        output_path = os.path.join(output_dir, base_filename+'.npz')

        signal, _ = librosa.load(filepath, sr=sample_rate, res_type='kaiser_best')        
        
        #voice, noise = librosa.effects.trim(signal,top_db=top_db)
        #if noise[0] != 0:
        #    signal = nr.reduce_noise(audio_clip=voice, noise_clip=signal[:noise[0]], verbose=False)
        #elif noise[1] != len(signal):
        #    signal = nr.reduce_noise(audio_clip=voice, noise_clip=signal[noise[1]:], verbose=False)
        #signal = scipy.signal.wiener(signal)
        
        signal = signal * 32768
        
        seg_length = int(sample_rate * sec)
        if len(signal) > seg_length:
            signal = signal[:seg_length]
        else:
            signal = np.tile(signal, [seg_length // len(signal)+1])[:seg_length] 
            padding = seg_length - len(signal) 
            left_pad = padding // 2
            right_pad = padding - left_pad
            signal = np.pad(signal, (left_pad, right_pad), "constant")
        
        if pre_emphasis:
            emphasized_signal = np.append(signal[0], signal[1:] - pre_emphasis * signal[:-1])
        else:
            emphasized_signal = signal
        
        frame_length, frame_step = frame_size * sample_rate, frame_stride * sample_rate  # Convert from seconds to samples
        signal_length = len(emphasized_signal)
        frame_length = int(round(frame_length))
        frame_step = int(round(frame_step))
        num_frames = int(np.ceil(float(np.abs(signal_length - frame_length)) / frame_step))  # Make sure that we have at least 1 frame
        
        pad_signal_length = num_frames * frame_step + frame_length
        z = np.zeros((pad_signal_length - signal_length))
        pad_signal = np.append(emphasized_signal, z) # Pad Signal to make sure that all frames have equal number of samples without truncating any samples from the original signal
        
        indices = np.tile(np.arange(0, frame_length), (num_frames, 1)) + np.tile(np.arange(0, num_frames * frame_step, frame_step), (frame_length, 1)).T
        frames = pad_signal[indices.astype(np.int32, copy=False)]
        
        frames *= np.hamming(frame_length)
        
        mag_frames = np.absolute(np.fft.rfft(frames, NFFT))  # Magnitude of the FFT
        pow_frames = ((1.0 / NFFT) * ((mag_frames) ** 2))  # Power Spectrum
        
        filter_banks = np.dot(pow_frames, fbank.T)
        filter_banks = np.where(filter_banks == 0, np.finfo(float).eps, filter_banks)  # Numerical Stability
        #filter_banks = 20 * np.log10(filter_banks)  # dB
        filter_banks = np.log10(filter_banks)  # dB
        #spec= librosa.feature.melspectrogram(signal,
        #                                     sr=sample_rate,
        #                                     n_fft=2048,
        #                                     hop_length=1024,
        #                                     n_mels=128,
        #                                     fmin=0.0,
        #                                     fmax=22050,
        #                                     htk=True,
        #                                     norm=None)
        #spec = librosa.feature.mfcc(y=signal, sr=sample_rate, n_mfcc=40)
        #spec = np.mean(librosa.feature.mfcc(y=signal, sr=sample_rate, n_mfcc=40).T,axis=0) 
        #embedding = np.expand_dims(spec, axis=-1)
        
        #spec = np.log(spec+1e-8)
        spec = np.expand_dims(filter_banks.T, axis=-1)
        deltas_spec = deltas(spec)
        deltas_deltas_spec= deltas(deltas_spec)

        #embedding= np.concatenate((spec[:,4:-4,:],deltas_spec[:,2:-2,:],deltas_deltas_spec), axis=-1)
        embedding= np.concatenate((spec[:,2:-2,:],deltas_spec[:,1:-1,:],deltas_deltas_spec), axis=-1)
        #break
        np.savez(output_path, embedding=embedding)
        
        pbar.set_description("Processing: Saved {}".format(output_path))
        #print("{}: Saved {} ({}/{})".format(feature, output_path, file_idx+1, num_files))
        
#import matplotlib.pylab as plt
#import librosa.display

#fig = plt.figure()
#for i in range(3):
#    librosa.display.specshow(embedding[:,:,i])
#    plt.show()
    
#print(embedding.shape)
# Out:
# Processing: Saved ./features/tess_delta_logmel/OAF_reach_sad.npz: 100%|██████████| 2800/2800 [02:43<00:00, 17.13it/s]

# %%
audio_filepath = [audio["filename"] for audio in test_db]

# %%
import warnings
warnings.filterwarnings(action='ignore')


#feature = 'mel-delta-128_fill0_1'
#output_dir = os.path.join('/Data2/emotion/features', feature)

feature = 'crema_delta_logmel'
output_dir = os.path.join('./features', feature)

overlap = True

#def deltas(X_in):
#    X_out = (X_in[:,2:,:]-X_in[:,:-2,:])/10.0
#    X_out = X_out[:,1:-1,:]+(X_in[:,4:,:]-X_in[:,:-4,:])/5.0
#    return X_out

def deltas(X_in):
    X_out = (X_in[:,1:,:]-X_in[:,:-1,:])/2.0
    X_out = X_out[:,1:,:]+(X_in[:,2:,:]-X_in[:,:-2,:])/8.0
    return X_out

if not os.path.exists(output_dir) or overlap == True:
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    low_freq_mel = (2595 * np.log10(1 + low_freq / 700))  # Convert Hz to Mel
    high_freq_mel = (2595 * np.log10(1 + high_freq / 700))  # Convert Hz to Mel
    mel_points = np.linspace(low_freq_mel, high_freq_mel, nfilt + 2)  # Equally spaced in Mel scale
    hz_points = (700 * (10**(mel_points / 2595) - 1))  # Convert Mel to Hz
    bin = np.floor((NFFT + 1) * hz_points / sample_rate)

    fbank = np.zeros((nfilt, int(np.floor(NFFT / 2 + 1))))
    for m in range(1, nfilt + 1):
        f_m_minus = int(bin[m - 1])   # left
        f_m = int(bin[m])             # center
        f_m_plus = int(bin[m + 1])    # right

        for k in range(f_m_minus, f_m):
            fbank[m - 1, k] = (k - bin[m - 1]) / (bin[m] - bin[m - 1])
        for k in range(f_m, f_m_plus):
            fbank[m - 1, k] = (bin[m + 1] - k) / (bin[m + 1] - bin[m])

    pbar = tqdm(audio_filepath)
    for filepath in pbar:
        #print("{}: Processing {} ({}/{})".format(feature, filepath, file_idx+1, num_files))

        _, current_last_level_path = os.path.split(filepath)
        base_filename, _ = os.path.splitext(current_last_level_path)
        output_path = os.path.join(output_dir, base_filename+'.npz')

        signal, _ = librosa.load(filepath, sr=sample_rate, res_type='kaiser_best')        
        
        #voice, noise = librosa.effects.trim(signal,top_db=top_db)
        #if noise[0] != 0:
        #    signal = nr.reduce_noise(audio_clip=voice, noise_clip=signal[:noise[0]], verbose=False)
        #elif noise[1] != len(signal):
        #    signal = nr.reduce_noise(audio_clip=voice, noise_clip=signal[noise[1]:], verbose=False)
        #signal = scipy.signal.wiener(signal)
        
        signal = signal * 32768
        
        seg_length = int(sample_rate * sec)
        if len(signal) > seg_length:
            signal = signal[:seg_length]
        else:
            signal = np.tile(signal, [seg_length // len(signal)+1])[:seg_length] 
            padding = seg_length - len(signal) 
            left_pad = padding // 2
            right_pad = padding - left_pad
            signal = np.pad(signal, (left_pad, right_pad), "constant")
        
        if pre_emphasis:
            emphasized_signal = np.append(signal[0], signal[1:] - pre_emphasis * signal[:-1])
        else:
            emphasized_signal = signal
        
        frame_length, frame_step = frame_size * sample_rate, frame_stride * sample_rate  # Convert from seconds to samples
        signal_length = len(emphasized_signal)
        frame_length = int(round(frame_length))
        frame_step = int(round(frame_step))
        num_frames = int(np.ceil(float(np.abs(signal_length - frame_length)) / frame_step))  # Make sure that we have at least 1 frame
        
        pad_signal_length = num_frames * frame_step + frame_length
        z = np.zeros((pad_signal_length - signal_length))
        pad_signal = np.append(emphasized_signal, z) # Pad Signal to make sure that all frames have equal number of samples without truncating any samples from the original signal
        
        indices = np.tile(np.arange(0, frame_length), (num_frames, 1)) + np.tile(np.arange(0, num_frames * frame_step, frame_step), (frame_length, 1)).T
        frames = pad_signal[indices.astype(np.int32, copy=False)]
        
        frames *= np.hamming(frame_length)
        
        mag_frames = np.absolute(np.fft.rfft(frames, NFFT))  # Magnitude of the FFT
        pow_frames = ((1.0 / NFFT) * ((mag_frames) ** 2))  # Power Spectrum
        
        filter_banks = np.dot(pow_frames, fbank.T)
        filter_banks = np.where(filter_banks == 0, np.finfo(float).eps, filter_banks)  # Numerical Stability
        #filter_banks = 20 * np.log10(filter_banks)  # dB
        filter_banks = np.log10(filter_banks)  # dB
        #spec= librosa.feature.melspectrogram(signal,
        #                                     sr=sample_rate,
        #                                     n_fft=2048,
        #                                     hop_length=1024,
        #                                     n_mels=128,
        #                                     fmin=0.0,
        #                                     fmax=22050,
        #                                     htk=True,
        #                                     norm=None)
        #spec = librosa.feature.mfcc(y=signal, sr=sample_rate, n_mfcc=40)
        #spec = np.mean(librosa.feature.mfcc(y=signal, sr=sample_rate, n_mfcc=40).T,axis=0) 
        #embedding = np.expand_dims(spec, axis=-1)
        
        #spec = np.log(spec+1e-8)
        spec = np.expand_dims(filter_banks.T, axis=-1)
        deltas_spec = deltas(spec)
        deltas_deltas_spec= deltas(deltas_spec)

        #embedding= np.concatenate((spec[:,4:-4,:],deltas_spec[:,2:-2,:],deltas_deltas_spec), axis=-1)
        embedding= np.concatenate((spec[:,2:-2,:],deltas_spec[:,1:-1,:],deltas_deltas_spec), axis=-1)
        #break
        np.savez(output_path, embedding=embedding)
        
        pbar.set_description("Processing: Saved {}".format(output_path))
        #print("{}: Saved {} ({}/{})".format(feature, output_path, file_idx+1, num_files))
        
#import matplotlib.pylab as plt
#import librosa.display

#fig = plt.figure()
#for i in range(3):
#    librosa.display.specshow(embedding[:,:,i])
#    plt.show()
    
#print(embedding.shape)
# Out:
# Processing: Saved ./features/crema_delta_logmel/1030_IEO_DIS_LO.npz: 100%|██████████| 7442/7442 [01:43<00:00, 71.78it/s]

# %%
item_list_train = []
for item in train_db:
    _, current_last_level_path = os.path.split(item["filename"])
    base_filename, _ = os.path.splitext(current_last_level_path)
    feature_filename = os.path.join(output_dir, base_filename+'.npz')
    item_ = {
        'data': {
            'filename': feature_filename
        },
        'meta': {
            'label': item["label"]
        }
    }
    item_list_train.append(item_)

#item_list_val = []
#for item in val_db:
#    _, current_last_level_path = os.path.split(item["filename"])
#    base_filename, _ = os.path.splitext(current_last_level_path)
#    feature_filename = os.path.join(output_dir, base_filename+'.npz')
#    item_ = {
#        'data': {
#            'filename': feature_filename
#        },
#        'meta': {
#            'labels': item["labels"]
#        }
#    }
#    item_list_val.append(item_)
#

item_list_test = []
for item in test_db:
    _, current_last_level_path = os.path.split(item["filename"])
    base_filename, _ = os.path.splitext(current_last_level_path)
    feature_filename = os.path.join(output_dir, base_filename+'.npz')
    
    item_ = {
        'data': {
            'filename': feature_filename
        },
        'meta': {
            'label': item["label"]
        }
    }
    item_list_test.append(item_)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-09dbdb9d44d4> in <module>
#       9         },
#      10         'meta': {
# ---> 11             'label': item["label"]
#      12         }
#      13     }
#
# KeyError: 'label'

# %%
feature = 'tess_delta_logmel'
output_dir = os.path.join('./features', feature)

# %%
output_dir
# Out:
# './features/tess_delta_logmel'

# %%
train_db
# Out:
# [{'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_mob_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'mob',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_peg_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'peg',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_gun_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'gun',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_chair_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'chair',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_keep_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'keep',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_void_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'void',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_raid_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'raid',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_name_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'name',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_luck_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'luck',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_lose_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'lose',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_base_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'base',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_youth_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'youth',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_learn_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'learn',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_young_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'young',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_talk_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'talk',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_boat_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'boat',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_date_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'date',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_road_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'road',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_chain_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'chain',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_half_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'half',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_book_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'book',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_red_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'red',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_life_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'life',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_white_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'white',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_join_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'join',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_cheek_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'cheek',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_wife_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'wife',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_raise_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'raise',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_chief_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'chief',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_sure_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'sure',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_vine_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'vine',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_jail_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'jail',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_good_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'good',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_get_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'get',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_wire_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'wire',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_ditch_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'ditch',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_hall_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'hall',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_lid_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'lid',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_sheep_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'sheep',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_size_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'size',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_dime_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'dime',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_loaf_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'loaf',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_walk_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'walk',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_room_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'room',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_jar_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'jar',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_laud_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'laud',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_cool_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'cool',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_have_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'have',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_mouse_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'mouse',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_bite_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'bite',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_ton_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'ton',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_met_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'met',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_bean_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'bean',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_food_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'food',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_fat_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'fat',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_deep_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'deep',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_hash_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'hash',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_burn_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'burn',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_pearl_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'pearl',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_cause_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'cause',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_lean_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'lean',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_keg_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'keg',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_phone_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'phone',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_merge_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'merge',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_knock_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'knock',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_mill_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'mill',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_near_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'near',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_take_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'take',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_beg_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'beg',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_note_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'note',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_tire_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'tire',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_which_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'which',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_rag_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'rag',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_love_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'love',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_bought_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'bought',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_page_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'page',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_team_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'team',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_goal_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'goal',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_perch_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'perch',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_bone_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'bone',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_witch_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'witch',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_rough_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'rough',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_thumb_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'thumb',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_keen_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'keen',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_read_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'read',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_haze_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'haze',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_south_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'south',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_rot_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'rot',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_soap_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'soap',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_chalk_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'chalk',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_dab_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'dab',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_vote_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'vote',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_lot_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'lot',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_far_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'far',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_sour_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'sour',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_kill_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'kill',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_turn_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'turn',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_pole_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'pole',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_yes_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'yes',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_wheat_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'wheat',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_chat_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'chat',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_make_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'make',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_moon_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'moon',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_sell_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'sell',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_hush_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'hush',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_rain_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'rain',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_mood_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'mood',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_jug_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'jug',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_voice_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'voice',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_dodge_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'dodge',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_dip_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'dip',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_kick_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'kick',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_shout_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'shout',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_bath_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'bath',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_puff_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'puff',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_when_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'when',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_time_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'time',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_pad_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'pad',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_soup_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'soup',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_numb_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'numb',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_gap_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'gap',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_tough_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'tough',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_hurl_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'hurl',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_mop_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'mop',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_rush_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'rush',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_choice_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'choice',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_such_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'such',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_rose_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'rose',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_mode_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'mode',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_reach_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'reach',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_dead_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'dead',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_germ_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'germ',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_late_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'late',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_tape_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'tape',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_lore_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'lore',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_came_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'came',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_tool_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'tool',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_bar_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'bar',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_seize_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'seize',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_sail_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'sail',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_limb_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'limb',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_pool_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'pool',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_doll_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'doll',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_ripe_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'ripe',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_live_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'live',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_wag_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'wag',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_juice_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'juice',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_search_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'search',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_fail_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'fail',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_door_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'door',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_tell_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'tell',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_kite_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'kite',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_lease_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'lease',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_hit_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'hit',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_pike_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'pike',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_nag_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'nag',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_hire_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'hire',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_pick_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'pick',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_fall_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'fall',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_king_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'king',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_gaze_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'gaze',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_check_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'check',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_pain_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'pain',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_home_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'home',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_third_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'third',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_gin_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'gin',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_goose_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'goose',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_shawl_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'shawl',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_dog_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'dog',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_rat_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'rat',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_gas_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'gas',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_hate_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'hate',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_week_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'week',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_match_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'match',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_calm_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'calm',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_long_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'long',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_should_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'should',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_whip_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'whip',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_thin_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'thin',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_shall_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'shall',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_mess_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'mess',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_sub_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'sub',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_shack_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'shack',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_ring_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'ring',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_tip_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'tip',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_judge_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'judge',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_yearn_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'yearn',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_neat_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'neat',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_wash_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'wash',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_thought_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'thought',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_pass_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'pass',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_hole_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'hole',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_back_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'back',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_shirt_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'shirt',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_said_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'said',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_nice_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'nice',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_death_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'death',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_cab_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'cab',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_fit_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'fit',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_happy/YAF_five_happy.wav',
#   'emotion': 'happy',
#   'actor': 'YAF',
#   'word': 'five',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_lease_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'lease',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_note_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'note',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_rat_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'rat',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_talk_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'talk',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_rough_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'rough',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_gas_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'gas',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_bar_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'bar',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_soup_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'soup',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_dime_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'dime',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_lot_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'lot',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_lid_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'lid',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_tell_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'tell',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_cool_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'cool',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_knock_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'knock',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_have_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'have',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_judge_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'judge',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_thin_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'thin',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_long_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'long',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_doll_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'doll',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_ton_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'ton',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_search_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'search',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_limb_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'limb',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_king_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'king',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_shawl_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'shawl',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_keen_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'keen',
#   'label': 4},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_happy/OAF_vote_happy.wav',
#   'emotion': 'happy',
#   'actor': 'OAF',
#   'word': 'vote',
#   'label': 4},
# ...
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'deep',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_sheep_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'sheep',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_burn_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'burn',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_hurl_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'hurl',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_ring_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'ring',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_have_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'have',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_shawl_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'shawl',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_bean_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'bean',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_calm_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'calm',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_witch_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'witch',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_goose_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'goose',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_chief_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'chief',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_turn_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'turn',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_time_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'time',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_void_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'void',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_pole_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'pole',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_pain_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'pain',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_hate_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'hate',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_shirt_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'shirt',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_kick_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'kick',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_vote_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'vote',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_said_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'said',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_love_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'love',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_live_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'live',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_tip_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'tip',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_cheek_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'cheek',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_luck_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'luck',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_chalk_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'chalk',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_when_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'when',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_numb_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'numb',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_bath_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'bath',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_tell_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'tell',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_search_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'search',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_week_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'week',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_dip_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'dip',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_room_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'room',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_vine_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'vine',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_walk_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'walk',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_fit_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'fit',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_dog_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'dog',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_back_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'back',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_sell_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'sell',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_voice_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'voice',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_chair_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'chair',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_cause_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'cause',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_make_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'make',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_hash_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'hash',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_third_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'third',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_hit_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'hit',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_join_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'join',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_gaze_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'gaze',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_food_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'food',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_half_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'half',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_size_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'size',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_team_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'team',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_moon_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'moon',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_nag_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'nag',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_lot_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'lot',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_soap_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'soap',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_yes_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'yes',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_should_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'should',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_gun_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'gun',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_bite_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'bite',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_came_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'came',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_knock_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'knock',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_sure_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'sure',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_tough_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'tough',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_met_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'met',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_tape_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'tape',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_limb_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'limb',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_whip_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'whip',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_good_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'good',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_pearl_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'pearl',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_pike_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'pike',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_get_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'get',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_seize_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'seize',
#   'label': 3},
#  {'filename': './kaggle/input/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_fear/YAF_late_fear.wav',
#   'emotion': 'fear',
#   'actor': 'YAF',
#   'word': 'late',
#   'label': 3},
#  ...]

# %%
item_list_train = []
for item in train_db:
    _, current_last_level_path = os.path.split(item["filename"])
    base_filename, _ = os.path.splitext(current_last_level_path)
    feature_filename = os.path.join(output_dir, base_filename+'.npz')
    item_ = {
        'data': {
            'filename': feature_filename
        },
        'meta': {
            'label': item["label"]
        }
    }
    item_list_train.append(item_)

# %%
item_list_train
# Out:
# [{'data': {'filename': './features/tess_delta_logmel/YAF_mob_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_peg_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_gun_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_chair_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_keep_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_void_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_raid_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_name_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_luck_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_lose_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_base_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_youth_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_learn_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_young_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_talk_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_boat_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_date_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_road_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_chain_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_half_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_book_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_red_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_life_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_white_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_join_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_cheek_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_wife_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_raise_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_chief_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_sure_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_vine_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_jail_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_good_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_get_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_wire_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_ditch_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_hall_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_lid_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_sheep_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_size_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_dime_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_loaf_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_walk_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_room_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_jar_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_laud_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_cool_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_have_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_mouse_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_bite_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_ton_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_met_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_bean_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_food_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_fat_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_deep_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_hash_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_burn_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_pearl_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_cause_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_lean_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_keg_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_phone_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_merge_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_knock_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_mill_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_near_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_take_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_beg_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_note_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_tire_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_which_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_rag_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_love_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_bought_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_page_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_team_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_goal_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_perch_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_bone_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_witch_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_rough_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_thumb_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_keen_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_read_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_haze_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_south_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_rot_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_soap_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_chalk_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_dab_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_vote_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_lot_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_far_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_sour_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_kill_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_turn_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_pole_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_yes_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_wheat_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_chat_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_make_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_moon_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_sell_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_hush_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_rain_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_mood_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_jug_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_voice_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_dodge_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_dip_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_kick_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_shout_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_bath_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_puff_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_when_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_time_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_pad_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_soup_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_numb_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_gap_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_tough_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_hurl_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_mop_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_rush_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_choice_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_such_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_rose_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_mode_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_reach_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_dead_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_germ_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_late_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_tape_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_lore_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_came_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_tool_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_bar_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_seize_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_sail_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_limb_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_pool_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_doll_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_ripe_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_live_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_wag_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_juice_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_search_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_fail_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_door_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_tell_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_kite_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_lease_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_hit_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_pike_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_nag_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_hire_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_pick_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_fall_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_king_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_gaze_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_check_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_pain_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_home_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_third_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_gin_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_goose_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_shawl_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_dog_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_rat_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_gas_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_hate_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_week_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_match_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_calm_happy.npz'},
#   'meta': {'label': 4}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF
fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_jar_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_shall_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_learn_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_yearn_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_raid_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_raise_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_merge_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_beg_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_rough_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_kill_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_pass_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_loaf_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_mill_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_doll_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_ripe_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_young_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_chain_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_youth_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_cool_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_ton_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_jail_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_mess_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_rush_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_phone_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_lean_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_lid_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_pool_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_dab_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_sub_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_bone_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_mob_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_which_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_deep_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_sheep_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_burn_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_hurl_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_ring_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_have_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_shawl_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_bean_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_calm_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_witch_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_goose_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_chief_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_turn_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_time_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_void_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_pole_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_pain_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_hate_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_shirt_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_kick_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_vote_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_said_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_love_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_live_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_tip_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_cheek_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_luck_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_chalk_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_when_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_numb_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_bath_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_tell_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_search_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_week_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_dip_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_room_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_vine_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_walk_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_fit_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_dog_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_back_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_sell_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_voice_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_chair_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_cause_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_make_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_hash_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_third_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_hit_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_join_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_gaze_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_food_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_half_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_size_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_team_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_moon_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_nag_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_lot_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_soap_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_yes_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_should_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_gun_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_bite_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_came_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_knock_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_sure_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_tough_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_met_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_tape_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_limb_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_whip_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_good_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_pearl_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_pike_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_get_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_seize_fear.npz'},
#   'meta': {'label': 3}},
#  {'data': {'filename': './features/tess_delta_logmel/YAF_late_fear.npz'},
#   'meta': {'label': 3}},
#  ...]

# %%
X_train = []
Y_train = []
for item in item_list_train:
    binary_matrix = np.zeros((6,1))
    pos = item["meta"]["label"]
    binary_matrix[pos,:] = 1
    
    audio = np.load(item["data"]["filename"])
    embedding = audio['embedding']

    X_train.append(embedding)
    Y_train.append(binary_matrix.T)
    
X_train = np.array(X_train)
Y_train = np.vstack(Y_train)

# %% [markdown]
# ---

# %% [markdown]
# crema-testset

# %%
training_files=[audio["filename"] for audio in train_db]

# %%
test_db
# Out:
# [{'filename': './kaggle/input/cremad/AudioWAV/1029_IOM_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1029',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1024_TAI_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1024',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1030_WSI_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1030',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1036_IWL_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1036',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1077_IEO_ANG_LO.wav',
#   'emotion': 'ANG',
#   'actor': '1077',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1057_IWW_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1057',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1030_IWL_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1030',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1057_ITS_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1057',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1064_IWW_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1064',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1032_IOM_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1032',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1034_TSI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1034',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1071_TSI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1071',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1004_ITS_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1004',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1025_IEO_SAD_MD.wav',
#   'emotion': 'SAD',
#   'actor': '1025',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1046_WSI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1046',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1011_ITS_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1011',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1012_ITH_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1012',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1081_IEO_HAP_LO.wav',
#   'emotion': 'HAP',
#   'actor': '1081',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1067_IWW_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1067',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1065_TIE_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1065',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1042_TAI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1042',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1080_IEO_ANG_LO.wav',
#   'emotion': 'ANG',
#   'actor': '1080',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1044_ITH_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1044',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1042_TSI_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1042',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1090_IWL_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1090',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1074_ITS_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1074',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1074_MTI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1074',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1046_TAI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1046',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1070_WSI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1070',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1047_TAI_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1047',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1024_IOM_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1024',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1087_IWL_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1087',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1061_IEO_HAP_MD.wav',
#   'emotion': 'HAP',
#   'actor': '1061',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1056_ITH_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1056',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1090_TAI_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1090',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1078_TAI_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1078',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1030_IWL_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1030',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1050_MTI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1050',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1054_IWW_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1054',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1064_DFA_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1064',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1086_TIE_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1086',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1026_MTI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1026',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1001_IEO_SAD_MD.wav',
#   'emotion': 'SAD',
#   'actor': '1001',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1065_WSI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1065',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1063_ITS_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1063',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1081_IWW_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1081',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1016_IOM_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1016',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1006_ITS_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1006',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1039_IOM_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1039',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1050_IWL_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1050',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1080_ITH_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1080',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1084_TSI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1084',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1007_ITH_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1007',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1019_IEO_SAD_MD.wav',
#   'emotion': 'SAD',
#   'actor': '1019',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1091_MTI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1091',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1059_TSI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1059',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1021_IEO_DIS_MD.wav',
#   'emotion': 'DIS',
#   'actor': '1021',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1013_ITH_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1013',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1043_IEO_SAD_HI.wav',
#   'emotion': 'SAD',
#   'actor': '1043',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1034_WSI_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1034',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1084_TAI_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1084',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1014_TIE_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1014',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1037_TAI_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1037',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1069_ITS_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1069',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1036_ITS_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1036',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1015_TSI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1015',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1040_IWL_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1040',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1003_DFA_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1003',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1045_IEO_DIS_MD.wav',
#   'emotion': 'DIS',
#   'actor': '1045',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1030_IEO_HAP_LO.wav',
#   'emotion': 'HAP',
#   'actor': '1030',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1066_TSI_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1066',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1063_DFA_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1063',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1020_WSI_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1020',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1056_IEO_HAP_HI.wav',
#   'emotion': 'HAP',
#   'actor': '1056',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1034_IOM_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1034',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1020_TSI_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1020',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1004_IEO_DIS_MD.wav',
#   'emotion': 'DIS',
#   'actor': '1004',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1087_IEO_HAP_MD.wav',
#   'emotion': 'HAP',
#   'actor': '1087',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1054_IEO_SAD_LO.wav',
#   'emotion': 'SAD',
#   'actor': '1054',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1033_ITS_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1033',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1024_IEO_DIS_MD.wav',
#   'emotion': 'DIS',
#   'actor': '1024',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1001_IWL_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1001',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1038_IEO_DIS_LO.wav',
#   'emotion': 'DIS',
#   'actor': '1038',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1013_MTI_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1013',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1051_IWW_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1051',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1044_IEO_FEA_LO.wav',
#   'emotion': 'FEA',
#   'actor': '1044',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1001_WSI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1001',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1084_MTI_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1084',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1067_IWW_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1067',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1081_TAI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1081',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1060_ITS_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1060',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1083_ITS_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1083',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1002_TIE_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1002',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1057_TAI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1057',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1014_MTI_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1014',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1026_DFA_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1026',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1082_IEO_ANG_HI.wav',
#   'emotion': 'ANG',
#   'actor': '1082',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1019_IEO_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1019',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1002_ITH_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1002',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1044_IEO_SAD_HI.wav',
#   'emotion': 'SAD',
#   'actor': '1044',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1045_TIE_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1045',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1054_ITS_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1054',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1091_IEO_DIS_MD.wav',
#   'emotion': 'DIS',
#   'actor': '1091',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1056_TAI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1056',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1078_ITS_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1078',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1015_WSI_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1015',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1051_IWL_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1051',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1033_TSI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1033',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1081_ITS_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1081',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1062_IEO_SAD_HI.wav',
#   'emotion': 'SAD',
#   'actor': '1062',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1054_IOM_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1054',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1024_IWL_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1024',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1062_TSI_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1062',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1052_WSI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1052',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1009_TAI_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1009',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1074_MTI_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1074',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1032_WSI_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1032',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1035_IOM_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1035',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1008_IWL_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1008',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1081_TSI_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1081',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1033_TIE_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1033',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1077_TSI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1077',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1081_ITH_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1081',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1062_IOM_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1062',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1068_IWW_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1068',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1088_DFA_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1088',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1032_TIE_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1032',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1020_TSI_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1020',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1007_TIE_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1007',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1012_IWW_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1012',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1038_MTI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1038',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1015_TIE_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1015',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1054_ITH_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1054',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1004_ITH_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1004',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1078_IWW_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1078',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1008_TSI_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1008',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1014_IWW_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1014',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1045_IWL_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1045',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1075_WSI_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1075',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1001_TAI_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1001',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1084_ITH_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1084',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1050_IEO_SAD_HI.wav',
#   'emotion': 'SAD',
#   'actor': '1050',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1018_ITH_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1018',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1025_IOM_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1025',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1043_WSI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1043',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1019_IEO_ANG_MD.wav',
#   'emotion': 'ANG',
#   'actor': '1019',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1052_ITS_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1052',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1062_TSI_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1062',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1069_MTI_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1069',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1060_ITS_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1060',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1053_IWW_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1053',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1020_ITH_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1020',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1003_IWW_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1003',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1035_TSI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1035',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1090_IEO_ANG_LO.wav',
#   'emotion': 'ANG',
#   'actor': '1090',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1052_IEO_ANG_HI.wav',
#   'emotion': 'ANG',
#   'actor': '1052',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1063_ITH_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1063',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1017_IEO_FEA_LO.wav',
#   'emotion': 'FEA',
#   'actor': '1017',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1075_IWW_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1075',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1066_MTI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1066',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1064_ITH_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1064',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1057_IOM_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1057',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1030_IEO_DIS_MD.wav',
#   'emotion': 'DIS',
#   'actor': '1030',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1057_IWW_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1057',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1047_IWL_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1047',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1089_IWW_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1089',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1045_IEO_HAP_LO.wav',
#   'emotion': 'HAP',
#   'actor': '1045',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1089_TSI_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1089',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1033_WSI_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1033',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1072_MTI_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1072',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1041_WSI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1041',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1072_IEO_HAP_LO.wav',
#   'emotion': 'HAP',
#   'actor': '1072',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1047_TIE_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1047',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1059_IEO_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1059',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1012_MTI_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1012',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1026_IEO_SAD_MD.wav',
#   'emotion': 'SAD',
#   'actor': '1026',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1091_IEO_SAD_MD.wav',
#   'emotion': 'SAD',
#   'actor': '1091',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1039_ITS_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1039',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1042_TSI_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1042',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1049_DFA_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1049',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1036_ITS_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1036',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1075_IOM_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1075',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1076_TSI_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1076',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1027_WSI_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1027',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1038_TIE_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1038',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1066_IWL_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1066',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1001_ITH_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1001',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1036_TAI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1036',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1062_TIE_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1062',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1082_TAI_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1082',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1072_IEO_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1072',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1042_IWL_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1042',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1028_TSI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1028',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1085_IEO_SAD_LO.wav',
#   'emotion': 'SAD',
#   'actor': '1085',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1073_IEO_SAD_MD.wav',
#   'emotion': 'SAD',
#   'actor': '1073',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1073_IWL_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1073',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1023_DFA_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1023',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1056_TAI_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1056',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1080_TIE_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1080',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1049_IWL_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1049',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1010_IEO_SAD_HI.wav',
#   'emotion': 'SAD',
#   'actor': '1010',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1040_IEO_SAD_MD.wav',
#   'emotion': 'SAD',
#   'actor': '1040',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1049_ITH_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1049',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1005_TSI_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1005',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1050_TSI_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1050',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1089_WSI_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '
MTI_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1032',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1012_TIE_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1012',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1007_ITH_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1007',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1041_TSI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1041',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1054_DFA_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1054',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1062_DFA_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1062',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1049_DFA_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1049',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1012_TSI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1012',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1043_IEO_SAD_MD.wav',
#   'emotion': 'SAD',
#   'actor': '1043',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1028_IEO_HAP_MD.wav',
#   'emotion': 'HAP',
#   'actor': '1028',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1031_TAI_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1031',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1003_IOM_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1003',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1045_MTI_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1045',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1001_TIE_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1001',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1076_IWW_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1076',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1007_MTI_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1007',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1078_IWL_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1078',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1062_IWL_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1062',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1021_WSI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1021',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1055_TIE_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1055',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1061_TSI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1061',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1067_TIE_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1067',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1054_WSI_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1054',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1055_IOM_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1055',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1057_DFA_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1057',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1063_IEO_HAP_HI.wav',
#   'emotion': 'HAP',
#   'actor': '1063',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1010_IEO_SAD_LO.wav',
#   'emotion': 'SAD',
#   'actor': '1010',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1067_ITS_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1067',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1081_WSI_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1081',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1079_ITH_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1079',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1014_IEO_FEA_HI.wav',
#   'emotion': 'FEA',
#   'actor': '1014',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1090_IWL_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1090',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1019_TSI_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1019',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1085_IOM_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1085',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1040_TIE_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1040',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1057_IEO_SAD_LO.wav',
#   'emotion': 'SAD',
#   'actor': '1057',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1030_ITS_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1030',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1023_TIE_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1023',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1005_IEO_HAP_HI.wav',
#   'emotion': 'HAP',
#   'actor': '1005',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1030_IOM_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1030',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1062_DFA_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1062',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1026_IWL_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1026',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1084_TAI_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1084',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1065_IWL_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1065',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1081_TAI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1081',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1034_TAI_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1034',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1062_TIE_DIS_XX.wav',
#   'emotion': 'DIS',
#   'actor': '1062',
#   'label': 2},
#  {'filename': './kaggle/input/cremad/AudioWAV/1046_ITH_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1046',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1081_TSI_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1081',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1054_IOM_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1054',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1010_TSI_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1010',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1077_IOM_FEA_XX.wav',
#   'emotion': 'FEA',
#   'actor': '1077',
#   'label': 3},
#  {'filename': './kaggle/input/cremad/AudioWAV/1076_DFA_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1076',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1046_ITS_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1046',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1033_ITH_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1033',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1069_DFA_NEU_XX.wav',
#   'emotion': 'NEU',
#   'actor': '1069',
#   'label': 5},
#  {'filename': './kaggle/input/cremad/AudioWAV/1065_MTI_SAD_XX.wav',
#   'emotion': 'SAD',
#   'actor': '1065',
#   'label': 0},
#  {'filename': './kaggle/input/cremad/AudioWAV/1039_TSI_ANG_XX.wav',
#   'emotion': 'ANG',
#   'actor': '1039',
#   'label': 1},
#  {'filename': './kaggle/input/cremad/AudioWAV/1062_ITH_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1062',
#   'label': 4},
#  {'filename': './kaggle/input/cremad/AudioWAV/1033_ITS_HAP_XX.wav',
#   'emotion': 'HAP',
#   'actor': '1033',
#   'label': 4},
#  ...]

# %%
output_dir
# Out:
# './features/crema_delta_logmel'

# %%
feature = 'crema_delta_logmel'
output_dir = os.path.join('./features', feature)

# %%
item_list_test = []
for item in test_db:
    _, current_last_level_path = os.path.split(item["filename"])
    base_filename, _ = os.path.splitext(current_last_level_path)
    feature_filename = os.path.join(output_dir, base_filename+'.npz')
    
    item_ = {
        'data': {
            'filename': feature_filename
        },
        'meta': {
            'label': item["label"]
        }
    }
    item_list_test.append(item_)

# %%
item_list_test[:5]
# Out:
# [{'data': {'filename': './features/crema_delta_logmel/1029_IOM_NEU_XX.npz'},
#   'meta': {'label': 5}},
#  {'data': {'filename': './features/crema_delta_logmel/1024_TAI_NEU_XX.npz'},
#   'meta': {'label': 5}},
#  {'data': {'filename': './features/crema_delta_logmel/1030_WSI_NEU_XX.npz'},
#   'meta': {'label': 5}},
#  {'data': {'filename': './features/crema_delta_logmel/1036_IWL_DIS_XX.npz'},
#   'meta': {'label': 2}},
#  {'data': {'filename': './features/crema_delta_logmel/1077_IEO_ANG_LO.npz'},
#   'meta': {'label': 1}}]

# %%
X_test = []
Y_test = []
for item in item_list_test:
    binary_matrix = np.zeros((6, 1))
    pos = item["meta"]["label"]
    binary_matrix[pos,:] = 1
    
    audio = np.load(item["data"]["filename"])
    embedding = audio['embedding']
    
    X_test.append(embedding)
    Y_test.append(binary_matrix.T)
    
X_test = np.array(X_test)
Y_test = np.vstack(Y_test)

# %%
embedding.shape
# Out:
# (40, 294, 3)

# %%
import matplotlib.pylab as plt
import librosa.display

fig = plt.figure()
for i in range(3):
    librosa.display.specshow(X_train[0][:,:,i])
    plt.show()
#librosa.display.specshow(X_train[0])
plt.show()

# %%
import warnings

import tensorflow
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input

from tensorflow.keras.layers import ZeroPadding2D, BatchNormalization, Activation, Conv2D, SeparableConv2D
from tensorflow.keras.layers import MaxPooling2D, GlobalAveragePooling2D, GlobalMaxPooling2D
from tensorflow.keras.layers import Concatenate, Add, Multiply, Lambda
from tensorflow.keras.layers import LeakyReLU, LSTM, Bidirectional, Reshape, Attention
from tensorflow.keras.layers import add, MaxPool2D
from tensorflow.keras.layers import Dense, Dropout

from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K

# %%
import tensorflow.keras
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
import numpy as np

# %%
input_shape = X_train.shape[1:]
input_shape
# Out:
# (40, 294, 3)

# %%
from tensorflow.keras.layers import Layer

class Attention(Layer):
    
    def __init__(self, return_sequences=True):
        self.return_sequences = return_sequences
        super(Attention,self).__init__()
        
    def build(self, input_shape):
        
        self.W=self.add_weight(name="att_weight", shape=(input_shape[-1],1),
                               initializer="normal")
        self.b=self.add_weight(name="att_bias", shape=(input_shape[1],1),
                               initializer="zeros")
        
        super(Attention,self).build(input_shape)
        
    def call(self, x):
        
        e = K.tanh(K.dot(x,self.W)+self.b)
        a = K.softmax(e, axis=1)
        output = x*a
        
        if self.return_sequences:
            return output
        
        return K.sum(output, axis=1)
    
Inputs = Input(shape = input_shape)

tConv = Conv2D(128, 3, strides=1)(Inputs)
tConv = LeakyReLU()(tConv)
tConv = MaxPooling2D((2,4), strides=(2,4), padding="valid")(tConv)

shorcut = Conv2D(128, 3, strides=1, dilation_rate=2, padding="same")(tConv)
shorcut = BatchNormalization()(shorcut)

UFLB1 = Conv2D(128, 3, strides=1, dilation_rate=2, padding="same")(tConv)
UFLB1 = BatchNormalization()(UFLB1)
UFLB1 = LeakyReLU()(UFLB1)

UFLB2 = Conv2D(128, 3, strides=1, dilation_rate=2, padding="same")(UFLB1)
UFLB2 = BatchNormalization()(UFLB2)
UFLB2 = LeakyReLU()(UFLB2)

UFLB3 = Conv2D(128, 3, strides=1, dilation_rate=2, padding="same")(UFLB2)
UFLB3 = BatchNormalization()(UFLB3)
UFLB3 = LeakyReLU()(UFLB3)

DConv = Add()([shorcut, UFLB3])
DConv = LeakyReLU()(DConv)
#DConv = Dropout(0.5)(DConv)

Linear = GlobalAveragePooling2D()(UFLB3)
Linear = Reshape((-1,128))(Linear)
#Linear = Dense(128)(Linear)
#shape = UFLB3.shape
#Linear = Reshape((shape[1],shape[2]*shape[3]))(UFLB3)

#BLSTM = LSTM(256)(Linear)
BLSTM = Bidirectional(LSTM(256, return_sequences=True),merge_mode='sum')(Linear)

Atten = Attention(return_sequences=False)(BLSTM)

Output = Dense(6, activation='softmax')(Atten)
#Output = LeakyReLU()(Output)
#Output = Dropout(0.5)(Output)

model = Model(inputs=Inputs, outputs=Output)

adam = Adam(lr=1e-4)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['categorical_accuracy'])
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 40, 294, 3)]      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 38, 292, 128)      3584
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 38, 292, 128)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 19, 73, 128)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 19, 73, 128)       147584
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 19, 73, 128)       512
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 19, 73, 128)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 19, 73, 128)       147584
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 19, 73, 128)       512
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 19, 73, 128)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 19, 73, 128)       147584
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 19, 73, 128)       512
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 19, 73, 128)       0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 128)               0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 1, 128)            0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 1, 256)            788480
# _________________________________________________________________
# attention_2 (Attention)      (None, 256)               257
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 1542
# =================================================================
# Total params: 1,238,151
# Trainable params: 1,237,383
# Non-trainable params: 768
# _________________________________________________________________

# %%
EPOCH = 500

def sigmoidal_decay(e, start=0, end=100, lr_start=1e-3, lr_end=1e-5):
    if e < start:
        return lr_start    
    if e > end:
        return lr_end    
    middle = (start + end) / 2
    s = lambda x: 1 / (1 + np.exp(-x))    
    return s(13 * (-e + middle) / np.abs(end - start)) * np.abs(lr_start - lr_end) + lr_end

lr_reduce = LearningRateScheduler(lambda e: sigmoidal_decay(e, end=EPOCH))

model.fit(X_train, Y_train, 
          validation_data=(X_test, Y_test),
          batch_size = 32,
          epochs=EPOCH, 
          callbacks=[lr_reduce])
# Out:
# Epoch 1/500
# 75/75 [==============================] - 106s 1s/step - loss: 1.1585 - categorical_accuracy: 0.5084 - val_loss: 3.1259 - val_categorical_accuracy: 0.1719
# Epoch 2/500
# 75/75 [==============================] - 103s 1s/step - loss: 0.3634 - categorical_accuracy: 0.8775 - val_loss: 10.1294 - val_categorical_accuracy: 0.1763
# Epoch 3/500
# 75/75 [==============================] - 108s 1s/step - loss: 0.0945 - categorical_accuracy: 0.9781 - val_loss: 8.8708 - val_categorical_accuracy: 0.1822
# Epoch 4/500
# 75/75 [==============================] - 106s 1s/step - loss: 0.0686 - categorical_accuracy: 0.9821 - val_loss: 14.2784 - val_categorical_accuracy: 0.1708
# Epoch 5/500
# 75/75 [==============================] - 108s 1s/step - loss: 0.0847 - categorical_accuracy: 0.9729 - val_loss: 9.4783 - val_categorical_accuracy: 0.1838
# Epoch 6/500
# 75/75 [==============================] - 110s 1s/step - loss: 0.0491 - categorical_accuracy: 0.9864 - val_loss: 9.6315 - val_categorical_accuracy: 0.2663
# Epoch 7/500
# 75/75 [==============================] - 104s 1s/step - loss: 0.0505 - categorical_accuracy: 0.9820 - val_loss: 16.5634 - val_categorical_accuracy: 0.1707
# Epoch 8/500
# 75/75 [==============================] - 108s 1s/step - loss: 0.0457 - categorical_accuracy: 0.9856 - val_loss: 14.1014 - val_categorical_accuracy: 0.2122
# Epoch 9/500
# 75/75 [==============================] - 105s 1s/step - loss: 0.0360 - categorical_accuracy: 0.9900 - val_loss: 8.8938 - val_categorical_accuracy: 0.2009
# Epoch 10/500
# 75/75 [==============================] - 112s 2s/step - loss: 0.0705 - categorical_accuracy: 0.9777 - val_loss: 13.3267 - val_categorical_accuracy: 0.1732
# Epoch 11/500
