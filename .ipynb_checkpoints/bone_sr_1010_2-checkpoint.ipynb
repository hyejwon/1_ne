# %% [markdown]
# ## import Library

# %%
## with structural

from __future__ import division

import numpy as np
from matplotlib import colors
import matplotlib.pyplot as plt
import seaborn
seaborn.set(style='ticks')


import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

import keras
from keras.preprocessing.image import ImageDataGenerator
from  keras import callbacks
from keras.callbacks import EarlyStopping
from keras.layers import Input, Dense, Lambda, Flatten, Reshape, Layer, merge, BatchNormalization
from keras.layers import Conv2D, Conv2DTranspose, MaxPooling2D, Dropout, UpSampling2D, Activation
from keras.models import Model
from keras import backend as K
from keras import metrics
#from keras.datasets import mnist
from keras.layers.advanced_activations import LeakyReLU
import tensorflow as tf
import math
import time
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 기본적인 설정

# %%
np.random.seed(1337)

img_rows, img_cols, img_chns = 12, 12, 1 # 입력 데이터 크기, 채널
upscale = 8 # 몇배 업스케일 할 것인가, (12x8 = 96)
batch_size = 64 
epochs = 5
val_ratio = 2/11 # validation set을 몇 % 사용할 것인가
resume_mode = 0  # 0: restart, 1: check point, 2: final 
verbose = 1      # 0: non output, 1: batch, 2: epoch

pre_upscale = False  #고해상화 하기 전에 기존 cv의 pre-upscaling 방법론을 사용할 것인가?

if pre_upscale:
    input_train = low_img_train
    input_val = low_img_val

if K.image_data_format() == 'channels_first':  #image datad의 형태가 (채널, 가로, 세로)인지 (가로,세로,채널)인지에 따라 tensor가 다르게 정의됩니다.
    original_img_size = (img_chns, img_rows, img_cols)
    input_size = (img_chns, img_rows, img_cols)
    disp_size = (6, img_rows + 1, img_cols + 1)
    se_size = (4, img_rows, img_cols)


else:
    original_img_size = (img_rows*upscale, img_cols*upscale, img_chns)
    input_size = (img_rows, img_cols, img_chns)
    disp_size = (img_rows+1, img_cols+1, 6)
    se_size = (img_rows, img_cols, 4)
    diff_size = (img_rows, img_cols, 6)

nY = img_rows*img_cols

# %% [markdown]
# ## 입력데이터를 로딩합니다.

# %%
print('data loading.....')

folder = '12x8' # 입력파일 디렉토리

# 저해상도, 고해상도 이미지를 로드합니다. 
low_img = np.load('./%s/low.npy' % folder)
high_img = np.load('./%s/high.npy'% folder)

# 필요한 경우 데이터의 스케일을 0~1 사이로 맞춰줍니다.
#print(low_img[0])
# low_img = (low_img - 0.01)*(1.00/0.99)
# high_img = (high_img - 0.01)*(1.00/0.99)
#print(low_img[0])


# Displacement 데이터를 읽어옵니다. 숫자는 case를 의미하고 vector 정보이므로 dx, dy를 따로 입력합니다. 
dx1 = np.load('./%s/dx1.npy'% folder)
dx2 = np.load('./%s/dx2.npy'% folder)
dx3 = np.load('./%s/dx3.npy'% folder)
dy1 = np.load('./%s/dy1.npy'% folder)
dy2 = np.load('./%s/dy2.npy'% folder)
dy3 = np.load('./%s/dy3.npy'% folder)

# strain energy 정보를 읽어옵니다. 숫자는 case를 의미합니다.
se1 = np.load('./%s/se1.npy'% folder)
se2 = np.load('./%s/se2.npy'% folder)
se3 = np.load('./%s/se3.npy'% folder)
se_sum = np.load('./%s/se_sum.npy'% folder)

# 추가적인 데이터셋을 로드합니다. 이름은 validation 셋으로 되어있지만 실제로는 두 데이터를 합친다음에 1/11만 validation set으로 이용합니다. 

low_img_val = np.load('./%s/low_val.npy' % folder)
high_img_val = np.load('./%s/high_val.npy'% folder)
dx1_val = np.load('./%s/dx1_val.npy'% folder)
dx2_val = np.load('./%s/dx2_val.npy'% folder)
dx3_val = np.load('./%s/dx3_val.npy'% folder)
dy1_val = np.load('./%s/dy1_val.npy'% folder)
dy2_val = np.load('./%s/dy2_val.npy'% folder)
dy3_val = np.load('./%s/dy3_val.npy'% folder)

se1_val = np.load('./%s/se1_val.npy'% folder)
se2_val = np.load('./%s/se2_val.npy'% folder)
se3_val = np.load('./%s/se3_val.npy'% folder)
se_sum_val = np.load('./%s/se_sum_val.npy'% folder)




# 두 데이터를 하나로 합쳐줍니다. 
low_img = np.concatenate((low_img,low_img_val),axis=0)
high_img = np.concatenate((high_img,high_img_val),axis=0)
dx1 = np.concatenate((dx1,dx1_val),axis=0)
dx2 = np.concatenate((dx2,dx2_val),axis=0)
dx3 = np.concatenate((dx3,dx3_val),axis=0)
dy1 = np.concatenate((dy1,dy1_val),axis=0)
dy2 = np.concatenate((dy2,dy2_val),axis=0)
dy3 = np.concatenate((dy3,dy3_val),axis=0)

se1 = np.concatenate((se1,se1_val),axis=0)
se2 = np.concatenate((se2,se2_val),axis=0)
se3 = np.concatenate((se3,se3_val),axis=0)
se_sum = np.concatenate((se_sum,se_sum_val),axis=0)

# 메모리 부족 문제로 합치고 난 변수들을 삭제합니다. 
del low_img_val, high_img_val, dx1_val, dx2_val, dx3_val
del dy1_val, dy2_val, dy3_val
del se1_val, se2_val, se3_val, se_sum_val
# Out:
# data loading.....

# %% [markdown]
# ## Test dataset 나누기

# %%
## 데이터를 정해진 비율대로 train/test set으로 나누고 batch 수에 맞게 데이터 갯수를 조정합니다.


print('data processing.....')

nData = low_img.shape[0]
# val_num = int(val_ratio * nData)

size = 1000

def multiple_slice(a, start1, end1, start2, end2):
    return np.concatenate((a[start1:end1, :], a[start2:end2, :]),axis=0)
    

# low_img_train = low_img[0:case_size*5, :]  # 1~5 까지
# high_img_train = high_img[0:case_size*5:, :]


# Train 데이터 자르기
start1 = 0
end1 = size*4
start2 = size*6
end2 = size*9
low_img_train = multiple_slice(low_img,start1,end1,start2,end2)
high_img_train = multiple_slice(high_img,start1,end1,start2,end2)
dx1_train = multiple_slice(dx1,start1,end1,start2,end2)
dx2_train = multiple_slice(dx2,start1,end1,start2,end2)
dx3_train = multiple_slice(dx3,start1,end1,start2,end2)
dy1_train = multiple_slice(dy1,start1,end1,start2,end2)
dy2_train = multiple_slice(dy2,start1,end1,start2,end2)
dy3_train = multiple_slice(dy3,start1,end1,start2,end2)
se1_train = multiple_slice(se1,start1,end1,start2,end2)
se2_train = multiple_slice(se2,start1,end1,start2,end2)
se3_train = multiple_slice(se3,start1,end1,start2,end2)
se_sum_train = multiple_slice(se_sum,start1,end1,start2,end2)

#validation : 5, 10번 
start1 = size*4
end1 = size*5
start2 = size*9
end2 = size*10
low_img_val = multiple_slice(low_img,start1,end1,start2,end2)
high_img_val = multiple_slice(high_img,start1,end1,start2,end2)
dx1_val = multiple_slice(dx1,start1,end1,start2,end2)
dx2_val = multiple_slice(dx2,start1,end1,start2,end2)
dx3_val = multiple_slice(dx3,start1,end1,start2,end2)
dy1_val = multiple_slice(dy1,start1,end1,start2,end2)
dy2_val = multiple_slice(dy2,start1,end1,start2,end2)
dy3_val = multiple_slice(dy3,start1,end1,start2,end2)
se1_val = multiple_slice(se1,start1,end1,start2,end2)
se2_val = multiple_slice(se2,start1,end1,start2,end2)
se3_val = multiple_slice(se3,start1,end1,start2,end2)
se_sum_val = multiple_slice(se_sum,start1,end1,start2,end2)


# Test 데이터 자르기 6번 11번
start1 = size*5
end1 = size*6
start2 = size*10
end2 = size*11
low_img_test = multiple_slice(low_img,start1,end1,start2,end2)
high_img_test = multiple_slice(high_img,start1,end1,start2,end2)
dx1_test = multiple_slice(dx1,start1,end1,start2,end2)
dx2_test = multiple_slice(dx2,start1,end1,start2,end2)
dx3_test = multiple_slice(dx3,start1,end1,start2,end2)
dy1_test = multiple_slice(dy1,start1,end1,start2,end2)
dy2_test = multiple_slice(dy2,start1,end1,start2,end2)
dy3_test = multiple_slice(dy3,start1,end1,start2,end2)
se1_test = multiple_slice(se1,start1,end1,start2,end2)
se2_test = multiple_slice(se2,start1,end1,start2,end2)
se3_test = multiple_slice(se3,start1,end1,start2,end2)
se_sum_test = multiple_slice(se_sum,start1,end1,start2,end2)

print('size of data(train, val, test):',low_img_train.shape, low_img_val.shape, low_img_test.shape)
# Out:
# data processing.....
# size of data(train, val, test): (7000, 144) (2000, 144) (2000, 144)

# %%
## validation set을 다시 나눕니다.

# Train 데이터 자르기

# %% [markdown]
# ## 데이터를 image 형태로 reshape 합니다. (1D -> 2D)

# %%
def data_reshape(img,rows = img_rows,cols=img_cols,ch=1):
    return img.reshape((img.shape[0],rows,cols,ch))

low_img_train = data_reshape(low_img_train,ch=1)
high_img_train = data_reshape(high_img_train,img_rows*upscale, img_cols*upscale,1)

dx1_train = data_reshape(dx1_train,img_rows+1, img_cols+1,1)
dx2_train = data_reshape(dx2_train,img_rows+1, img_cols+1,1)
dx3_train = data_reshape(dx3_train,img_rows+1, img_cols+1,1)
dy1_train = data_reshape(dy1_train,img_rows+1, img_cols+1,1)
dy2_train = data_reshape(dy2_train,img_rows+1, img_cols+1,1)
dy3_train = data_reshape(dy3_train,img_rows+1, img_cols+1,1)


se1_train = data_reshape(se1_train,ch=1)
se2_train = data_reshape(se2_train,ch=1)
se3_train = data_reshape(se3_train,ch=1)
se_sum_train = data_reshape(se_sum_train,ch=1)

disp_train = np.concatenate((dx1_train,dx2_train,dx3_train,dy1_train,dy2_train,dy3_train),axis=3)
se_train = np.concatenate((se1_train, se2_train, se3_train, se_sum_train),axis=3)


low_img_test = data_reshape(low_img_test,ch=1)
high_img_test = data_reshape(high_img_test,img_rows*upscale, img_cols*upscale,1)


dx1_test = data_reshape(dx1_test,img_rows+1, img_cols+1,1)
dx2_test = data_reshape(dx2_test,img_rows+1, img_cols+1,1)
dx3_test = data_reshape(dx3_test,img_rows+1, img_cols+1,1)
dy1_test = data_reshape(dy1_test,img_rows+1, img_cols+1,1)
dy2_test = data_reshape(dy2_test,img_rows+1, img_cols+1,1)
dy3_test = data_reshape(dy3_test,img_rows+1, img_cols+1,1)


se1_test = data_reshape(se1_test,ch=1)
se2_test = data_reshape(se2_test,ch=1)
se3_test = data_reshape(se3_test,ch=1)
se_sum_test = data_reshape(se_sum_test,ch=1)


disp_test = np.concatenate((dx1_test,dx2_test,dx3_test,dy1_test,dy2_test,dy3_test),axis=3)
se_test = np.concatenate((se1_test, se2_test, se3_test, se_sum_test),axis=3)


low_img_val = data_reshape(low_img_val,ch=1)
high_img_val = data_reshape(high_img_val,img_rows*upscale, img_cols*upscale,1)

dx1_val = data_reshape(dx1_val,img_rows+1, img_cols+1,1)
dx2_val = data_reshape(dx2_val,img_rows+1, img_cols+1,1)
dx3_val = data_reshape(dx3_val,img_rows+1, img_cols+1,1)
dy1_val = data_reshape(dy1_val,img_rows+1, img_cols+1,1)
dy2_val = data_reshape(dy2_val,img_rows+1, img_cols+1,1)
dy3_val = data_reshape(dy3_val,img_rows+1, img_cols+1,1)


se1_val = data_reshape(se1_val,ch=1)
se2_val = data_reshape(se2_val,ch=1)
se3_val = data_reshape(se3_val,ch=1)
se_sum_val = data_reshape(se_sum_val,ch=1)

disp_val = np.concatenate((dx1_val,dx2_val,dx3_val,dy1_val,dy2_val,dy3_val),axis=3)
se_val = np.concatenate((se1_val, se2_val, se3_val, se_sum_val),axis=3)

# %% [markdown]
# ## 32비트 형태로 입력데이터를 형변환 (의미가 있는지는..)

# %%
# low_img_train = low_img_train.astype(np.float32)
# high_img_train = high_img_train.astype(np.float32)
# disp_train_x = disp_train_x.astype(np.float32)
# disp_train_y = disp_train_y.astype(np.float32)
# se_train = se_train.astype(np.float32)

# low_img_val = low_img_val.astype(np.float32)
# high_img_val = high_img_val.astype(np.float32)
# disp_val = disp_val.astype(np.float32)
# se_val = se_val.astype(np.float32)

# %%
print(low_img_test.shape)
print(high_img_test.shape)
print(disp_test.shape)
print(se_test.shape)
# Out:
# (2000, 12, 12, 1)
# (2000, 96, 96, 1)
# (2000, 13, 13, 6)
# (2000, 12, 12, 4)

# %% [markdown]
# ## 경계에 걸린 패치 제거하기

# %%
## 경계에 걸린놈 제거하기. 빈공간의 경우 displacement 가 0로 세팅되어 있기 때문에 미분계산시 오류 발생. 

n_zero = 0
del_list = []
for i in range(high_img_train.shape[0]):
#     print(low_img_train[i].min())
    if(high_img_train[i].min()<0.0001):  ## 뼈 내부의 밀도 하한값은 0.001이므로 이 값 이하를 가질 수 없음.
        n_zero = n_zero +1
        del_list.append(i)
print(n_zero)



low_img_train = np.delete(low_img_train, del_list,axis=0)
high_img_train = np.delete(high_img_train, del_list,axis=0)
disp_train = np.delete(disp_train, del_list,axis=0)
se_train = np.delete(se_train, del_list,axis=0)
# Out:
# 1153

# %%
del_list = []
n_zero_test = 0
for i in range(high_img_test.shape[0]):
#     print(low_img_train[i].min())
    if(high_img_test[i].min()<0.0001):
        n_zero_test = n_zero_test +1
        del_list.append(i)
        

low_img_test = np.delete(low_img_test, del_list,axis=0)
high_img_test = np.delete(high_img_test, del_list,axis=0)
disp_test = np.delete(disp_test, del_list,axis=0)
se_test = np.delete(se_test, del_list,axis=0)

print(n_zero_test)
# Out:
# 313

# %%
del_list = []
n_zero_val = 0
for i in range(high_img_val.shape[0]):
#     print(low_img_val[i].min())
    if(high_img_val[i].min()<0.0001):
        n_zero_val = n_zero_val +1
        del_list.append(i)
        

low_img_val = np.delete(low_img_val, del_list,axis=0)
high_img_val = np.delete(high_img_val, del_list,axis=0)
disp_val = np.delete(disp_val, del_list,axis=0)
se_val = np.delete(se_val, del_list,axis=0)

print(n_zero_val)
# Out:
# 340

# %%
print(low_img_train.shape)
print(low_img_test.shape)
# Out:
# (5847, 12, 12, 1)
# (1687, 12, 12, 1)

# %%
## all 블랙이나 all zero에 가까운 그림들 세어보기

n = 0
del_list = []
for i in range(high_img_train.shape[0]):
#     print(low_img_train[i].min())
    if(high_img_train[i].mean()<0.05):
        n = n +1
#         del_list.append(i)
print('all zero',n)
# Out:
# all zero 363

# %%
## all 블랙이나 all zero에 가까운 그림들 세어보기

n = 0
del_list = []
for i in range(high_img_train.shape[0]):
#     print(low_img_train[i].min())
    if(high_img_train[i].mean()>0.95):
        n = n +1
#         del_list.append(i)
print('all one',n)


# 제거할까?
# Out:
# all one 166

# %% [markdown]
# ## 미분값(strain) 계산하기

# %%
print('min, max', disp_train.max(), disp_train.min())
print('disp x size',disp_train.shape)

plt.hist(disp_train.flatten(), bins=15)

## displacement는 위치에 따라 다른 값을 가지므로 방향성을 찾을 수 없음.
## Transformer 를 쓴다면?!
# Out:
# min, max 29.98295 -24.55797
# disp x size (5847, 13, 13, 6)
# (array([   7056.,   40012.,  125808.,  267718.,  383684.,  650516.,
#         2189639.,  885111.,  488969.,  435899.,  277605.,  123012.,
#           38496.,   10816.,    4517.]),
#  array([-24.55797  , -20.92191  , -17.285847 , -13.649786 , -10.013724 ,
#          -6.377663 ,  -2.741602 ,   0.8944594,   4.530521 ,   8.166582 ,
#          11.802644 ,  15.4387045,  19.074766 ,  22.710827 ,  26.34689  ,
#          29.98295  ], dtype=float32),
#  <a list of 15 Patch objects>)

# %%
diff_dx_train = np.gradient(disp_train,axis=2)
diff_dy_train = np.gradient(disp_train,axis=1)

diff_dx_test = np.gradient(disp_test,axis=2)
diff_dy_test = np.gradient(disp_test,axis=1)

diff_dx_val = np.gradient(disp_val,axis=2)
diff_dy_val = np.gradient(disp_val,axis=1)

plt.hist(diff_dx_train.flatten(), bins=30)
plt.show()

plt.hist(diff_dy_train.flatten(), bins=30)
plt.show()

# %%
## 대략 -1~1로 scaling 하기 위해서 10을 곱함.
diff_dx_train = diff_dx_train*10
diff_dy_train = diff_dy_train*10

diff_dx_test = diff_dx_test*10
diff_dy_test = diff_dy_test*10

diff_dx_val = diff_dx_val*10
diff_dy_val = diff_dy_val*10

# %%
id = 100

nTrain = diff_dx_train.shape[0]


def plt_plot(data):
    plt.imshow(data, origin='lower')
    plt.colorbar()
    plt.show()    
    
    
plt_plot(diff_dx_train[id,:,:,0])
plt_plot(diff_dx_train[id,:,:,1])
plt_plot(diff_dx_train[id,:,:,2])
plt_plot(diff_dx_train[id,:,:,3])
plt_plot(diff_dx_train[id,:,:,4])
plt_plot(diff_dx_train[id,:,:,5])

# %%
diff_train = np.concatenate( (diff_dx_train[:,:,:,0:3], diff_dy_train[:,:,:,3:6]), axis=3) ## xx,xy,yx, yy 중 xx,yy 성분만 우선 사용
diff_test = np.concatenate( (diff_dx_test[:,:,:,0:3], diff_dy_test[:,:,:,3:6]), axis=3) ## xx,xy,yx, yy 중 xx,yy 성분만 우선 사용
diff_val = np.concatenate( (diff_dx_val[:,:,:,0:3], diff_dy_val[:,:,:,3:6]), axis=3)

print(diff_train.shape)
print(diff_val.shape)
print(diff_test.shape)

from skimage.transform import resize
diff_train_resize = resize(diff_train, (diff_train.shape[0],12, 12,6),anti_aliasing=True)
diff_test_resize = resize(diff_test, (diff_test.shape[0],12, 12,6),anti_aliasing=True)
diff_val_resize = resize(diff_val, (diff_val.shape[0],12, 12,6),anti_aliasing=True)

print(diff_train_resize.shape)
print(diff_test_resize.shape)


diff_train = diff_train_resize
diff_test = diff_test_resize
diff_val = diff_val_resize
# Out:
# (5847, 13, 13, 6)
# (1660, 13, 13, 6)
# (1687, 13, 13, 6)
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\skimage\transform\_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\skimage\transform\_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\skimage\transform\_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# (5847, 12, 12, 6)
# (1687, 12, 12, 6)

# %%
##strain energy


plt.hist((se_train.flatten()), bins=15)
plt.show()
plt.hist(np.log(se_train.flatten()), bins=15)
# Out:
# (array([5.10000e+01, 3.01000e+02, 1.18800e+03, 4.92700e+03, 1.55900e+04,
#         4.68290e+04, 1.34230e+05, 3.27635e+05, 4.82579e+05, 4.77347e+05,
#         6.10813e+05, 7.20020e+05, 4.33977e+05, 1.07419e+05, 4.96600e+03]),
#  array([-13.10742598, -12.1102696 , -11.11311321, -10.11595683,
#          -9.11880045,  -8.12164407,  -7.12448768,  -6.1273313 ,
#          -5.13017492,  -4.13301854,  -3.13586216,  -2.13870577,
#          -1.14154939,  -0.14439301,   0.85276337,   1.84991975]),
#  <a list of 15 Patch objects>)

# %% [markdown]
# ## 데이터를 augmentation 하기위한 함수 정의 (90도씩 돌리고 flip -> 8배)

# %%
from scipy.ndimage import rotate
import math

# plt.imshow(low[500].reshape(img_rows, img_cols), cmap='Greys', vmin=0, vmax=1)
# plt.show()

def rot_augment(img):
    img90 = np.rot90(img,k=1,axes=(2,1))
    img180 = np.rot90(img,k=2,axes=(2,1))
    img270 = np.rot90(img,k=3,axes=(2,1))

    return np.concatenate((img, img90, img180, img270), axis=0)
    # return img

def flip_augment(img):
    fl=img[:,:,::-1,:]

#     fl=img[:,::-1,:,:]

    return np.concatenate((img,fl),axis=0)

def flip_augment_vector(img):
#     fl=-img[:,::-1,:,:]
    fl=-img[:,:,::-1,:]
    return np.concatenate((img,fl),axis=0)

def augment(img):
    return flip_augment(rot_augment(img))
    #return rot_augment(img)

def rot_vector(vx,vy,k):
    vx = np.rot90(vx,k,axes=(2,1))
    vy = np.rot90(vy,k,axes=(2,1))

    th = (2*3.141592)*(k*90/360)
    print('th=',th)
    vx_rot = vx*math.cos(th)-vy*math.sin(th)
    vy_rot = vx*math.sin(th)+vy*math.cos(th)
    
    return vx_rot, vy_rot

def rot_augment_vector(vx, vy):

    vx90, vy90 = rot_vector(vx,vy,1)
    vx180, vy180 = rot_vector(vx,vy,2)
    vx270, vy270 = rot_vector(vx,vy,3)

    vx = np.concatenate((vx,vx90,vx180,vx270),axis=0)
    vy = np.concatenate((vy,vy90,vy180,vy270),axis=0)
    
    return flip_augment_vector(vx), flip_augment(vy)

def rot_augment_vector2(v):

    vx = v[:,:,:,:3]
    vy = v[:,:,:,3:]
    
    vx_arg, vy_arg = rot_augment_vector(vx,vy)
    return np.concatenate((vx_arg,vy_arg),axis=3)


#return vx, vy

# %%
## 맞는지 테스트가 필요함.


# test = np.array([0,1],[])

# %% [markdown]
# ## Augmentation

# %%
low_img_train_aug = augment(low_img_train)
high_img_train_aug = augment(high_img_train)

low_img_val_aug = augment(low_img_val)
high_img_val_aug = augment(high_img_val)
# disp_train_x, disp_train_y = rot_augment_vector(disp_train_x, disp_train_y)
# disp_train = np.concatenate((disp_train_x,disp_train_y),axis=3)


disp_train_aug = rot_augment_vector2(disp_train)
diff_train_aug = rot_augment_vector2(diff_train)

disp_val_aug = rot_augment_vector2(disp_val)
diff_val_aug = rot_augment_vector2(diff_val)

se_train_aug = augment(se_train)
se_val_aug = augment(se_val)
if pre_upscale: up_img_train = augment(up_img_train)


print('data augment end')

print(disp_train.shape)
# Out:
# th= 1.570796
# th= 3.141592
# th= 4.712388000000001
# th= 1.570796
# th= 3.141592
# th= 4.712388000000001
# th= 1.570796
# th= 3.141592
# th= 4.712388000000001
# th= 1.570796
# th= 3.141592
# th= 4.712388000000001
# data augment end
# (5847, 13, 13, 6)

# %% [markdown]
# ## Augmentation 함수 확인

# %%
id = 101
for i in range(8):
    plt.imshow(high_img_train_aug[id+nTrain*i,:,:,0],origin='lower')
    plt.show()

# %%
x = np.arange(0,12,1)
y = np.arange(0,12,1)

X, Y = np.meshgrid(x, y)


for i in range(8):
    u = diff_train_aug[id+nTrain*i,:,:,0]
    v = diff_train_aug[id+nTrain*i,:,:,3]

    fig, ax = plt.subplots(figsize=(7,7))
    ax.quiver(X,Y,u,v)
    plt.show()

# %% [markdown]
# ## 저해상도 및 고해상도 입력데이터를 한번 찍어봅니다.

# %%
# id = 105

plt.imshow(high_img_train[id].reshape(img_rows*upscale, img_cols*upscale), cmap='Greys', vmin=0, vmax=1,origin='lower')
plt.show()
plt.imshow(low_img_train[id].reshape(img_rows, img_cols), cmap='Greys', vmin=0, vmax=1,origin='lower')
plt.show()

# %%
print(low_img_train.max(),low_img_train.min())
print(high_img_train.max(),high_img_train.min())

## min, max를 한번찍어봅니다. 1보다 큰 값이 있네요? scaling 혹은 bound를 쳐줘야 할까요?
# Out:
# 1.015873 0.01001114
# 1.0 0.01

# %%
## 3 to 4 tensor

diff_train_aug[id+nTrain*i,:,:,0]
diff_train_aug[id+nTrain*i,:,:,3]

# x = diff_train_aug

diff_train_aug2 = np.zeros((diff_train_aug.shape[0],12,12,3,2))
diff_train_aug2[:,:,:,0,0] = diff_train_aug[:,:,:,0]
diff_train_aug2[:,:,:,1,0] = diff_train_aug[:,:,:,1]
diff_train_aug2[:,:,:,2,0] = diff_train_aug[:,:,:,2]

diff_train_aug2[:,:,:,0,1] = diff_train_aug[:,:,:,3]
diff_train_aug2[:,:,:,1,1] = diff_train_aug[:,:,:,4]
diff_train_aug2[:,:,:,2,1] = diff_train_aug[:,:,:,5]
# diff_train_aug2[:,:,:,0,0] = diff_train_aug[:,:,:,0]
# diff_train_aug2[:,:,:,0,1] = diff_train_aug[:,:,:,1]
# diff_train_aug2[:,:,:,0,2] = diff_train_aug[:,:,:,2]

# diff_train_aug2[:,:,:,1,0] = diff_train_aug[:,:,:,3]
# diff_train_aug2[:,:,:,1,1] = diff_train_aug[:,:,:,4]
# diff_train_aug2[:,:,:,1,2] = diff_train_aug[:,:,:,5]

print(diff_train_aug2.shape)

# diff_val_aug2 = np.zeros(diff_val_aug.shape[0],12,12,3,2)
diff_val_aug2 = np.zeros((diff_val_aug.shape[0],12,12,3,2))
diff_val_aug2[:,:,:,0,0] = diff_val_aug[:,:,:,0]
diff_val_aug2[:,:,:,1,0] = diff_val_aug[:,:,:,1]
diff_val_aug2[:,:,:,2,0] = diff_val_aug[:,:,:,2]

diff_val_aug2[:,:,:,0,1] = diff_val_aug[:,:,:,3]
diff_val_aug2[:,:,:,1,1] = diff_val_aug[:,:,:,4]
diff_val_aug2[:,:,:,2,1] = diff_val_aug[:,:,:,5]

print(diff_val_aug2.shape)


diff_test2 = np.zeros((diff_test.shape[0],12,12,3,2))
diff_test2[:,:,:,0,0] = diff_test[:,:,:,0]
diff_test2[:,:,:,1,0] = diff_test[:,:,:,1]
diff_test2[:,:,:,2,0] = diff_test[:,:,:,2]

diff_test2[:,:,:,0,1] = diff_test[:,:,:,3]
diff_test2[:,:,:,1,1] = diff_test[:,:,:,4]
diff_test2[:,:,:,2,1] = diff_test[:,:,:,5]
# Out:
# (46776, 12, 12, 3, 2)
# (13280, 12, 12, 3, 2)

# %% [markdown]
# ## 모델정의 (Structural Information을 고려하는 경우)

# %%
interpolation='bilinear' #'nearest'   #upscaling시 방법 nearest는 같은 값으로 채우고, bilinear는 interpolation 합니다.
act_f = 'relu'
ker_num = int(64)


## 입력 tensor의 정의 
x = Input(batch_shape=(None,) + input_size)
y = Input(batch_shape=(None,) + original_img_size)
disp = Input(batch_shape=(None,) + disp_size)
diff = Input(batch_shape=(None,) + diff_size)
diff2 = Input(batch_shape=(None,) + (12,12,3,2))
se = Input(batch_shape=(None,) + se_size)


## model의 정의 
from keras.layers import Conv3D, MaxPooling3D, Permute

# disp는 nodal information이고 se는 element information이므로 차원이 다릅니다. (n,m),(n+1,m+1)
# 따라서 차원을 맞춰주기 위해서 padding이 없고 filter size 가 2인 cnn을 먹여서 차원을 같게 맞춰준후 concatenate합니다. 
def ConvBlock(fn, fs, act, pad, init, repeat,x):
    for i in range(repeat):
        x = Conv2D(fn,fs,activation=act, padding = pad, kernel_initializer = init)(x)
        x = BatchNormalization()(x)
    return x


def SrModel(stInfo=True):
    if stInfo==True:
#         conv0 = Conv2D(6, 2, activation = act_f, padding = 'valid', kernel_initializer = 'he_normal')(disp)
#         conv01 = BatchNormalization()(conv0)
#         merge_disp_se = keras.layers.concatenate([conv01,se], axis = 3)


#         conv02 = Conv2D(ker_num, 3, activation = act_f, padding = 'same', kernel_initializer = 'he_normal')(merge_disp_se)
#         conv03 = BatchNormalization()(conv02)
#         x_merge = keras.layers.concatenate([x,diff,se], axis=3)


## permutational layer 
        conv0 = Conv3D(32,(3,3,1), activation = act_f, padding = 'same', kernel_initializer = 'he_normal')(diff2)
#         conv0 = BatchNormalization()(conv0)
        conv0 = Conv3D(64,(3,3,1), activation = act_f, padding = 'same', kernel_initializer = 'he_normal')(conv0)
#         conv0 = BatchNormalization()(conv0)
        conv0 = Conv3D(128,(3,3,1), activation = act_f, padding = 'same', kernel_initializer = 'he_normal')(conv0)
#         conv1 = Permute((1,2,4,3))(conv0)
#         conv0 = BatchNormalization()(conv0)
        conv2 = MaxPooling3D((1,1,3))(conv0)
        conv2 = Permute((1,2,4,3))(conv2)
        conv3 = Reshape((12,12,128))(conv2)
        x_merge = keras.layers.concatenate([x,conv3], axis=3)
    else:
        x_merge = x
        
    
    
    y = UpSampling2D(size = (upscale,upscale), interpolation=interpolation)(x_merge)

    y1 = ConvBlock(ker_num,3,act_f,'same','he_normal',3,y) ## Level 1
    p1 = MaxPooling2D(pool_size=(2, 2))(y1)

    y2 = ConvBlock(ker_num*2,3,act_f,'same','he_normal',3,p1) ## Level 2
    p2 = MaxPooling2D(pool_size=(2, 2))(y2)

    y3 = ConvBlock(ker_num*4,3,act_f,'same','he_normal',3,p2) ## Level 3
    p3 = MaxPooling2D(pool_size=(2, 2))(y3)

    
    if stInfo==True:
#         y4 = keras.layers.concatenate([conv03,p3], axis = 3) ## Level 4
        y4 = ConvBlock(ker_num*8,3,act_f,'same','he_normal',3,p3)
    else:
        y4 = ConvBlock(ker_num*8,3,act_f,'same','he_normal',3,p3)        
    



    up1 = Conv2D(ker_num*2, 2, activation=act_f, padding='same', kernel_initializer='he_normal')(UpSampling2D(size=(2, 2), interpolation=interpolation)(y4))
    y5 = keras.layers.concatenate([y3, up1], axis=3)
    y5 = ConvBlock(ker_num,3,act_f,'same','he_normal',3,y5)

    up2 = Conv2D(ker_num*2, 2, activation=act_f, padding='same', kernel_initializer='he_normal')(UpSampling2D(size=(2, 2), interpolation=interpolation)(y5))
    y6 = keras.layers.concatenate([y2, up2], axis=3)
    y6 = ConvBlock(ker_num,3,act_f,'same','he_normal',3,y6)

    up3 = Conv2D(ker_num, 2, activation=act_f, padding='same', kernel_initializer='he_normal')(UpSampling2D(size=(2, 2), interpolation=interpolation)(y6))
    y7 = keras.layers.concatenate([y1, up3], axis=3)
    y7 = ConvBlock(ker_num,3,act_f,'same','he_normal',3,y7)

    y8 = Conv2D(2, 3, activation=act_f, padding='same', kernel_initializer='he_normal')(y7)
    y9 = BatchNormalization()(y8)
    y10 = Conv2D(1, 1, activation='sigmoid')(y9)
    

    if stInfo==True:
#         model = Model([x, diff2, se], y10)
#         model = Model([x, disp, se], y10)
        model = Model([x, diff2], y10)
    else:
        model = Model(x, y10)
           

    return model

# %%
## 시험 조건
strInfo = True
epochs = 20 # 20epoch는 되야함..


model = SrModel(strInfo)

model.summary()
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 12, 12, 3, 2) 0
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 12, 12, 3, 32 608         input_5[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 12, 12, 3, 64 18496       conv3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 12, 12, 3, 12 73856       conv3d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_1 (MaxPooling3D)  (None, 12, 12, 1, 12 0           conv3d_3[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 12, 12, 128,  0           max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# input_1 (InputLayer)            (None, 12, 12, 1)    0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 12, 12, 128)  0           permute_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12, 12, 129)  0           input_1[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 96, 96, 129)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 96, 96, 64)   74368       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 96, 96, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 96, 96, 64)   36928       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 96, 96, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 96, 96, 64)   36928       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 96, 96, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 48, 48, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 48, 48, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 48, 48, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 48, 48, 128)  147584      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 48, 48, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 48, 48, 128)  147584      batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 48, 48, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 24, 24, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 24, 24, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 24, 24, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 24, 24, 256)  590080      batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 24, 24, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 24, 24, 256)  590080      batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 24, 24, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 256)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 12, 12, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 12, 12, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 12, 12, 512)  2359808     batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 12, 12, 512)  2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 12, 12, 512)  2359808     batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 12, 12, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 24, 24, 512)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 24, 24, 128)  262272      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 24, 24, 384)  0           batch_normalization_9[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 24, 24, 64)   221248      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 24, 24, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 24, 24, 64)   36928       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 24, 24, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 24, 24, 64)   36928       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 24, 24, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 48, 48, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 48, 48, 128)  32896       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 48, 48, 256)  0           batch_normalization_6[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 48, 48, 64)   147520      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 48, 48, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 48, 48, 64)   36928       batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 48, 48, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 48, 48, 64)   36928       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 48, 48, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 96, 96, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 96, 96, 64)   16448       up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 96, 96, 128)  0           batch_normalization_3[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 96, 96, 64)   73792       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 96, 96, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 96, 96, 64)   36928       batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 96, 96, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 96, 96, 64)   36928       batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 96, 96, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 96, 96, 2)    1154        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 96, 96, 2)    8           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 96, 96, 1)    3           batch_normalization_22[0][0]
# ==================================================================================================
# Total params: 8,976,045
# Trainable params: 8,969,129
# Non-trainable params: 6,916
# __________________________________________________________________________________________________

# %%
if resume_mode == 2:
    print('load final weight')
    model.load_weights('model_weight.h5')
if resume_mode == 1:
    print('load check point')
    model.load_weights('check.h5')
#vae.load_weights('check.h5')
model.compile(optimizer='adam',#''rmsprop',
            #loss=vae_loss4,
            loss='mae',
            #metrics=['mae', 'acc'],
            )
#vae.summary()

# %%
from sklearn.utils import shuffle
## suffle train data
# low_img_train_aug, high_img_train_aug,diff_train_aug, se_train_aug = shuffle(low_img_train_aug, 
#                                                                         high_img_train_aug, diff_train_aug, se_train_aug, random_state=0)


print(low_img_train_aug.shape)
print(high_img_train_aug.shape)

id = 150
plt.imshow(high_img_train[id].reshape(img_rows*upscale, img_cols*upscale), cmap='Greys', vmin=0, vmax=1,origin='lower')
plt.show()
plt.imshow(low_img_train[id].reshape(img_rows, img_cols), cmap='Greys', vmin=0, vmax=1,origin='lower')
plt.show()
# Out:
# (46776, 12, 12, 1)
# (46776, 96, 96, 1)

# %%
csv_logger = callbacks.CSVLogger('log.txt',append=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

checkpoint = callbacks.ModelCheckpoint('check.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True, mode='auto', period=1)


if strInfo==True:
    his = model.fit([low_img_train_aug, 
#              disp_train_aug, 
            diff_train_aug2,
#              se_train_aug,
                    ], 
            high_img_train_aug,
            shuffle=True,
            epochs=epochs,
            batch_size=batch_size,
#             validation_split=0.2,
            verbose=verbose,
            callbacks=[csv_logger, checkpoint],
                       #early_stopping
                       # ])
            validation_data=([
                low_img_val_aug,
                diff_val_aug2,
#                 se_val_aug
            ], 
                high_img_val_aug)
             )

else: 
    his = model.fit(low_img_train_aug, 
            high_img_train_aug,
            shuffle=True,
            epochs=epochs,
            batch_size=batch_size,
#             validation_split=0.2,
            verbose=verbose,
            callbacks=[csv_logger, checkpoint],
                       #early_stopping
                       # ])
            validation_data=(
                low_img_val_aug,
                high_img_val_aug)
             )    
        

    

model.save('model_final.h5',overwrite=True)
model.save_weights('model_final_weight.h5')
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 46776 samples, validate on 13280 samples
# Epoch 1/20
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-33-94041d3135ae> in <module>
#      25 #                 se_val_aug
#      26             ],
# ---> 27                 high_img_val_aug)
#      28              )
#      29
#
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     526             None, None,
#     527             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 528             c_api.TF_GetCode(self.status.status))
#     529     # Delete the underlying status object from memory otherwise it stays alive
#     530     # as there is a reference to status from this from the traceback due to
#
# UnknownError: Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[{{node conv3d_1/convolution}}]]
# 	 [[{{node loss/mul}}]]

# %%
fig, loss_ax = plt.subplots()
# acc_ax = loss_ax.twinx()

loss_ax.plot(his.history['loss'], 'y', label='train loss')
loss_ax.plot(his.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper right')
# seaborn.despine(ax=loss_ax, offset=0) # the important part here

# loss_ax.axhline(y=0, color='k')
# loss_ax.axvline(x=0, color='k')

plt.ylim(bottom=0)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Testset으로 성능 평가

# %%
## load best model
model.load_weights("check.h5")

# %%
if strInfo==True:
#     evaluate = model.evaluate([low_img_test, disp_test, se_test], high_img_test,  batch_size, verbose=2)
#     predict_img = model.predict([low_img_test, disp_test, se_test],  batch_size, verbose=2)
#     evaluate = model.evaluate([low_img_test, diff_test2, se_test], high_img_test,  batch_size, verbose=2)
#     predict_img = model.predict([low_img_test, diff_test2, se_test],  batch_size, verbose=2)

    evaluate = model.evaluate([low_img_test, diff_test2], high_img_test,  batch_size, verbose=2)
    predict_img = model.predict([low_img_test, diff_test2],  batch_size, verbose=2)
    
else:
    evaluate = model.evaluate(low_img_test, high_img_test,  batch_size, verbose=2)
    predict_img = model.predict(low_img_test,  batch_size, verbose=2)
    
    
print('test accuracy(mae):', evaluate)

# %%
# permutational invariance??

# diff_test2 = np.zeros((diff_test.shape[0],12,12,3,2))
diff_test2[:,:,:,2,0] = diff_test[:,:,:,0]
diff_test2[:,:,:,1,0] = diff_test[:,:,:,1]
diff_test2[:,:,:,1,0] = diff_test[:,:,:,2]

diff_test2[:,:,:,2,1] = diff_test[:,:,:,3]
diff_test2[:,:,:,1,1] = diff_test[:,:,:,4]
diff_test2[:,:,:,0,1] = diff_test[:,:,:,5]


if strInfo==True:
#     evaluate = model.evaluate([low_img_test, disp_test, se_test], high_img_test,  batch_size, verbose=2)
#     predict_img = model.predict([low_img_test, disp_test, se_test],  batch_size, verbose=2)
#     evaluate = model.evaluate([low_img_test, diff_test2, se_test], high_img_test,  batch_size, verbose=2)
#     predict_img = model.predict([low_img_test, diff_test2, se_test],  batch_size, verbose=2)

    evaluate = model.evaluate([low_img_test, diff_test2], high_img_test,  batch_size, verbose=2)
    predict_img = model.predict([low_img_test, diff_test2],  batch_size, verbose=2)
    
else:
    evaluate = model.evaluate(low_img_test, high_img_test,  batch_size, verbose=2)
    predict_img = model.predict(low_img_test,  batch_size, verbose=2)
    
    
print('test accuracy(mae):', evaluate)

# %%
id = 150
plt.imshow(low_img_test[id,:,:,0])
plt.show()
plt.imshow(high_img_test[id,:,:,0])
plt.show()

plt.imshow(predict_img[id,:,:,0])
plt.show()

# %%
## 결과를 플롯하기 위한 함수 
def comparison_plot(start=0, n_figure=200, show=False):
    plot_row = 2
    plot_col = 3
    #n_figure = 200

#     predict_img = model.predict([low_img_val, disp_val, se_val],  batch_size, verbose=2)

    # np.savetxt('predict.txt',y_predict)


    for i_figure in range(0, n_figure):

        # fig = plt.figure(nrows=4, ncols=5)
        fig = plt.figure()
        # plt.subplots_adjust(hspace = 0.5, wspace = 0.3)
        # print('predict start:', start + i_figure * plot_row*plot_col)

        start_time = time.time()
        for i_col in range(0, plot_col):
            for i_row in range(0, plot_row):

                index = start + i_figure * plot_row * plot_col  + plot_row * i_col + i_row
                # print('index',index)
                one_y_orig = high_img_test[index].reshape(img_rows*upscale, img_cols*upscale).transpose()
                one_y_low = low_img_test[index].reshape(img_rows, img_cols).transpose()
                one_y_predict = predict_img[index].reshape(img_rows*upscale, img_cols*upscale).transpose()


                plt.subplot(plot_col, plot_row * 3, (plot_row *3 * i_col + i_row*3) + 1) # 2 * 3 * 4 + 1 * 3 + 3 = 24 + 3 + 3 = 30
                plt.imshow(one_y_low, cmap='Greys', vmin=0, vmax=1)
                plt.xticks([])
                plt.yticks([])
                # plt.ylabel("n:%d" % index+1)
                if i_col == plot_col - 1:
                    plt.xlabel("low-res.")

                plt.subplot(plot_col, plot_row*3, (plot_row *3 * i_col + i_row*3) + 2)
                plt.imshow(one_y_predict, cmap='Greys', vmin=0, vmax=1)
                plt.xticks([])
                plt.yticks([])
                # plt.ylabel("n:%d" % index + 1)
                if i_col == plot_col - 1:
                    plt.xlabel("predicted")
                plt.subplot(plot_col, plot_row * 3, (plot_row *3 * i_col + i_row*3) + 3)
                plt.imshow(one_y_orig, cmap='Greys', vmin=0, vmax=1)
                plt.xticks([])
                plt.yticks([])
                # plt.ylabel("n:%d" % index + 1)
                if i_col == plot_col - 1:
                    plt.xlabel("high-res.")


        end_time= (time.time() - start_time)/plot_row
        # print('computing time for predict : %f s' % end_time)
        #plt.savefig("../train/vae/cmp_epoch%03d_latent%02d_i%04d.png" % (epochs, latent_dim, i_figure))
        plt.tight_layout()

        
        import os
        outDir = "./output_fig"
        if not os.path.isdir(outDir):
            os.mkdir(outDir)
            
        plt.savefig("./output_fig/out_figure_%s.png" % i_figure,dpi=300)
        if show==True:
#             plt.figure(figsize=(2,2)) 
#             plt.rcParams['figure.figsize'] = [100, 50]
            plt.show()
        plt.close()

# %%
# 0번부터 3개의 데이터의 결과를 출력합니다.
comparison_plot(100,1,True)

# %%
# 100번 부터 100개의 데이터를 출력합니다. (화면 출력 X)
# comparison_plot(100, 100, False)
