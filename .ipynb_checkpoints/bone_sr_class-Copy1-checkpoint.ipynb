# %% [markdown]
# ## import Library

# %%
## with structural

from __future__ import division
# import setGPU
# gpu_id = setGPU.bestGPU
gpu_id="0"
import os
# !pip install warning
import warnings
warnings.filterwarnings(action='ignore')

# multi_gpu = False
# if multi_gpu == False:
#     gpu_id="0"

#     os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
#     os.environ["CUDA_VISIBLE_DEVICES"]=gpu_id
# else:
#     gpu_id='t'

# print(gpu_id)
import numpy as np
from matplotlib import colors
import matplotlib.pyplot as plt
import seaborn
seaborn.set(style='ticks')


import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

import keras
from keras.preprocessing.image import ImageDataGenerator
from  keras import callbacks
from keras.callbacks import EarlyStopping
from keras.layers import Input, Dense, Lambda, Flatten, Reshape, Layer, merge, BatchNormalization
from keras.layers import Conv2D, Conv2DTranspose, MaxPooling2D, Dropout, UpSampling2D, Activation
from keras.models import Model
from keras import backend as K
from keras import metrics
#from keras.datasets import mnist
from keras.layers.advanced_activations import LeakyReLU
import tensorflow as tf
import math
import time
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 기본적인 설정

# %%
np.random.seed(1337)

img_rows, img_cols, img_chns = 12, 12, 1 # 입력 데이터 크기, 채널
upscale = 8 # 몇배 업스케일 할 것인가, (12x8 = 96)

# val_ratio = 2/11 # validation set을 몇 % 사용할 것인가
# resume_mode = 0  # 0: restart, 1: check point, 2: final 
verbose = 1      # 0: non output, 1: batch, 2: epoch


if K.image_data_format() == 'channels_first':  #image datad의 형태가 (채널, 가로, 세로)인지 (가로,세로,채널)인지에 따라 tensor가 다르게 정의됩니다.
    original_img_size = (img_chns, img_rows, img_cols)
    input_size = (img_chns, img_rows, img_cols)
    disp_size = (6, img_rows + 1, img_cols + 1)
    se_size = (4, img_rows, img_cols)


else:
    original_img_size = (img_rows*upscale, img_cols*upscale, img_chns)
    input_size = (img_rows, img_cols, img_chns)
    disp_size = (img_rows+1, img_cols+1, 6)
    se_size = (img_rows, img_cols, 4)
    diff_size = (img_rows, img_cols, 6)

nY = img_rows*img_cols

# %% [markdown]
# ## 입력데이터를 로딩합니다.

# %%
print('data loading.....')

folder = '12x8' # 입력파일 디렉토리

# 저해상도, 고해상도 이미지를 로드합니다. 
low_img = np.load('./%s/low.npy' % folder)
high_img = np.load('./%s/high.npy'% folder)



# Displacement 데이터를 읽어옵니다. 숫자는 case를 의미하고 vector 정보이므로 dx, dy를 따로 입력합니다. 
dx1 = np.load('./%s/dx1.npy'% folder)
dx2 = np.load('./%s/dx2.npy'% folder)
dx3 = np.load('./%s/dx3.npy'% folder)
dy1 = np.load('./%s/dy1.npy'% folder)
dy2 = np.load('./%s/dy2.npy'% folder)
dy3 = np.load('./%s/dy3.npy'% folder)

# strain energy 정보를 읽어옵니다. 숫자는 case를 의미합니다.
se1 = np.load('./%s/se1.npy'% folder)
se2 = np.load('./%s/se2.npy'% folder)
se3 = np.load('./%s/se3.npy'% folder)
se_sum = np.load('./%s/se_sum.npy'% folder)

# 추가적인 데이터셋을 로드합니다. 이름은 validation 셋으로 되어있지만 실제로는 두 데이터를 합친다음에 1/11만 validation set으로 이용합니다. 

low_img_val = np.load('./%s/low_val.npy' % folder)
high_img_val = np.load('./%s/high_val.npy'% folder)
dx1_val = np.load('./%s/dx1_val.npy'% folder)
dx2_val = np.load('./%s/dx2_val.npy'% folder)
dx3_val = np.load('./%s/dx3_val.npy'% folder)
dy1_val = np.load('./%s/dy1_val.npy'% folder)
dy2_val = np.load('./%s/dy2_val.npy'% folder)
dy3_val = np.load('./%s/dy3_val.npy'% folder)

se1_val = np.load('./%s/se1_val.npy'% folder)
se2_val = np.load('./%s/se2_val.npy'% folder)
se3_val = np.load('./%s/se3_val.npy'% folder)
se_sum_val = np.load('./%s/se_sum_val.npy'% folder)



# 두 데이터를 하나로 합쳐줍니다. 
low_img = np.concatenate((low_img,low_img_val),axis=0)
high_img = np.concatenate((high_img,high_img_val),axis=0)
dx1 = np.concatenate((dx1,dx1_val),axis=0)
dx2 = np.concatenate((dx2,dx2_val),axis=0)
dx3 = np.concatenate((dx3,dx3_val),axis=0)
dy1 = np.concatenate((dy1,dy1_val),axis=0)
dy2 = np.concatenate((dy2,dy2_val),axis=0)
dy3 = np.concatenate((dy3,dy3_val),axis=0)

se1 = np.concatenate((se1,se1_val),axis=0)
se2 = np.concatenate((se2,se2_val),axis=0)
se3 = np.concatenate((se3,se3_val),axis=0)
se_sum = np.concatenate((se_sum,se_sum_val),axis=0)

# 메모리 부족 문제로 합치고 난 변수들을 삭제합니다. 
del low_img_val, high_img_val, dx1_val, dx2_val, dx3_val
del dy1_val, dy2_val, dy3_val
del se1_val, se2_val, se3_val, se_sum_val
# Out:
# data loading.....

# %% [markdown]
# ## Test dataset 나누기

# %%
## 데이터를 정해진 비율대로 train/test set으로 나누고 batch 수에 맞게 데이터 갯수를 조정합니다.

print('data processing.....')

nData = low_img.shape[0]

n_per_case = 1000

def multiple_slice(a, start1, end1, start2, end2):
    return np.concatenate((a[start1:end1, :], a[start2:end2, :]),axis=0)
    

# low_img_train = low_img[0:case_size*5, :]  # 1~5 까지
# high_img_train = high_img[0:case_size*5:, :]


# Train 데이터 자르기
start1 = 0
end1 = n_per_case*5  #validation 포함:4, train따로:5
start2 = n_per_case*6
end2 = n_per_case*10 #validation 포함:9, train따로:10
low_img_train = multiple_slice(low_img,start1,end1,start2,end2)
high_img_train = multiple_slice(high_img,start1,end1,start2,end2)
dx1_train = multiple_slice(dx1,start1,end1,start2,end2)
dx2_train = multiple_slice(dx2,start1,end1,start2,end2)
dx3_train = multiple_slice(dx3,start1,end1,start2,end2)
dy1_train = multiple_slice(dy1,start1,end1,start2,end2)
dy2_train = multiple_slice(dy2,start1,end1,start2,end2)
dy3_train = multiple_slice(dy3,start1,end1,start2,end2)
se1_train = multiple_slice(se1,start1,end1,start2,end2)
se2_train = multiple_slice(se2,start1,end1,start2,end2)
se3_train = multiple_slice(se3,start1,end1,start2,end2)
se_sum_train = multiple_slice(se_sum,start1,end1,start2,end2)

#validation : 5, 10번 
start1 = n_per_case*4
end1 = n_per_case*5
start2 = n_per_case*9
end2 = n_per_case*10
low_img_val = multiple_slice(low_img,start1,end1,start2,end2)
high_img_val = multiple_slice(high_img,start1,end1,start2,end2)
dx1_val = multiple_slice(dx1,start1,end1,start2,end2)
dx2_val = multiple_slice(dx2,start1,end1,start2,end2)
dx3_val = multiple_slice(dx3,start1,end1,start2,end2)
dy1_val = multiple_slice(dy1,start1,end1,start2,end2)
dy2_val = multiple_slice(dy2,start1,end1,start2,end2)
dy3_val = multiple_slice(dy3,start1,end1,start2,end2)
se1_val = multiple_slice(se1,start1,end1,start2,end2)
se2_val = multiple_slice(se2,start1,end1,start2,end2)
se3_val = multiple_slice(se3,start1,end1,start2,end2)
se_sum_val = multiple_slice(se_sum,start1,end1,start2,end2)


# Test 데이터 자르기 6번 11번
start1 = n_per_case*5
end1 = n_per_case*6
start2 = n_per_case*10
end2 = n_per_case*11
low_img_test = multiple_slice(low_img,start1,end1,start2,end2)
high_img_test = multiple_slice(high_img,start1,end1,start2,end2)
dx1_test = multiple_slice(dx1,start1,end1,start2,end2)
dx2_test = multiple_slice(dx2,start1,end1,start2,end2)
dx3_test = multiple_slice(dx3,start1,end1,start2,end2)
dy1_test = multiple_slice(dy1,start1,end1,start2,end2)
dy2_test = multiple_slice(dy2,start1,end1,start2,end2)
dy3_test = multiple_slice(dy3,start1,end1,start2,end2)
se1_test = multiple_slice(se1,start1,end1,start2,end2)
se2_test = multiple_slice(se2,start1,end1,start2,end2)
se3_test = multiple_slice(se3,start1,end1,start2,end2)
se_sum_test = multiple_slice(se_sum,start1,end1,start2,end2)

print('size of data(train, val, test):',low_img_train.shape, low_img_val.shape, low_img_test.shape)
# Out:
# data processing.....
# size of data(train, val, test): (9000, 144) (2000, 144) (2000, 144)

# %% [markdown]
# ## 데이터를 image 형태로 reshape 합니다. (1D -> 2D)

# %%
def data_reshape(img,rows = img_rows,cols=img_cols,ch=1):
    return img.reshape((img.shape[0],rows,cols,ch))

low_img_train = data_reshape(low_img_train,ch=1)
high_img_train = data_reshape(high_img_train,img_rows*upscale, img_cols*upscale,1)

dx1_train = data_reshape(dx1_train,img_rows+1, img_cols+1,1)
dx2_train = data_reshape(dx2_train,img_rows+1, img_cols+1,1)
dx3_train = data_reshape(dx3_train,img_rows+1, img_cols+1,1)
dy1_train = data_reshape(dy1_train,img_rows+1, img_cols+1,1)
dy2_train = data_reshape(dy2_train,img_rows+1, img_cols+1,1)
dy3_train = data_reshape(dy3_train,img_rows+1, img_cols+1,1)


se1_train = data_reshape(se1_train,ch=1)
se2_train = data_reshape(se2_train,ch=1)
se3_train = data_reshape(se3_train,ch=1)
se_sum_train = data_reshape(se_sum_train,ch=1)

disp_train = np.concatenate((dx1_train,dx2_train,dx3_train,dy1_train,dy2_train,dy3_train),axis=3)
se_train = np.concatenate((se1_train, se2_train, se3_train, se_sum_train),axis=3)


low_img_test = data_reshape(low_img_test,ch=1)
high_img_test = data_reshape(high_img_test,img_rows*upscale, img_cols*upscale,1)


dx1_test = data_reshape(dx1_test,img_rows+1, img_cols+1,1)
dx2_test = data_reshape(dx2_test,img_rows+1, img_cols+1,1)
dx3_test = data_reshape(dx3_test,img_rows+1, img_cols+1,1)
dy1_test = data_reshape(dy1_test,img_rows+1, img_cols+1,1)
dy2_test = data_reshape(dy2_test,img_rows+1, img_cols+1,1)
dy3_test = data_reshape(dy3_test,img_rows+1, img_cols+1,1)


se1_test = data_reshape(se1_test,ch=1)
se2_test = data_reshape(se2_test,ch=1)
se3_test = data_reshape(se3_test,ch=1)
se_sum_test = data_reshape(se_sum_test,ch=1)


disp_test = np.concatenate((dx1_test,dx2_test,dx3_test,dy1_test,dy2_test,dy3_test),axis=3)
se_test = np.concatenate((se1_test, se2_test, se3_test, se_sum_test),axis=3)


low_img_val = data_reshape(low_img_val,ch=1)
high_img_val = data_reshape(high_img_val,img_rows*upscale, img_cols*upscale,1)

dx1_val = data_reshape(dx1_val,img_rows+1, img_cols+1,1)
dx2_val = data_reshape(dx2_val,img_rows+1, img_cols+1,1)
dx3_val = data_reshape(dx3_val,img_rows+1, img_cols+1,1)
dy1_val = data_reshape(dy1_val,img_rows+1, img_cols+1,1)
dy2_val = data_reshape(dy2_val,img_rows+1, img_cols+1,1)
dy3_val = data_reshape(dy3_val,img_rows+1, img_cols+1,1)


se1_val = data_reshape(se1_val,ch=1)
se2_val = data_reshape(se2_val,ch=1)
se3_val = data_reshape(se3_val,ch=1)
se_sum_val = data_reshape(se_sum_val,ch=1)

disp_val = np.concatenate((dx1_val,dx2_val,dx3_val,dy1_val,dy2_val,dy3_val),axis=3)
se_val = np.concatenate((se1_val, se2_val, se3_val, se_sum_val),axis=3)

# %%
print(low_img_test.shape)
print(high_img_test.shape)
print(disp_test.shape)
print(se_test.shape)
# Out:
# (2000, 12, 12, 1)
# (2000, 96, 96, 1)
# (2000, 13, 13, 6)
# (2000, 12, 12, 4)

# %%
from sklearn.utils import shuffle
low_img_train, high_img_train, disp_train, se_train = shuffle(low_img_train, high_img_train, disp_train, se_train, random_state=0)

# %% [markdown]
# ## 경계에 걸린 패치 제거하기

# %%
def get_del_list(img, thr, minmax = 'min', lb='l'): #comp = true
    n_zero = 0
    del_list = []
    
    
    for i in range(img.shape[0]):
        if (minmax=='min'):
            v = img[i].min()
        elif (minmax=='max'):
            v = img[i].max()
        elif (minmax=='mean'):
            v = img[i].mean()
        else:
            print('error')
           
        if(v < thr and lb=='l'): 
            n_zero = n_zero +1
            del_list.append(i)
            
        elif(v > thr and lb=='u'): 
            n_zero = n_zero +1
            del_list.append(i)  
            
    print(n_zero)
    
    
    return del_list

# def delete_data_list()
def delete_data_list(del_list, traintest = 'train'):
    global low_img_train, high_img_train, disp_train, se_train
    global low_img_val, high_img_val, disp_val, se_val
    global low_img_test, high_img_test, disp_test, se_test
    if traintest =='train':
        low_img_train = np.delete(low_img_train, del_list,axis=0)
        high_img_train = np.delete(high_img_train, del_list,axis=0)
        disp_train = np.delete(disp_train, del_list,axis=0)
        se_train = np.delete(se_train, del_list,axis=0)

    if traintest =='val':
        low_img_val = np.delete(low_img_val, del_list,axis=0)
        high_img_val = np.delete(high_img_val, del_list,axis=0)
        disp_val = np.delete(disp_val, del_list,axis=0)
        se_val = np.delete(se_val, del_list,axis=0)
        
    if traintest =='test':
        low_img_test = np.delete(low_img_test, del_list,axis=0)
        high_img_test = np.delete(high_img_test, del_list,axis=0)
        disp_test = np.delete(disp_test, del_list,axis=0)
        se_test = np.delete(se_test, del_list,axis=0)
        
def del_abnormal_img(thr, minmax = 'min', lb='l'):
    del_list = get_del_list(high_img_train,thr,minmax,lb)
    delete_data_list(del_list, traintest='train')
    
    del_list = get_del_list(high_img_val,thr,minmax,lb)
    delete_data_list(del_list, traintest='val')
    
    del_list = get_del_list(high_img_test,thr,minmax,lb)
    delete_data_list(del_list, traintest='test')

# %%
## 경계에 걸린놈 제거하기. 빈공간의 경우 displacement 가 0로 세팅되어 있기 때문에 미분계산시 오류 발생. 

del_abnormal_img(0.0001,minmax = 'min',lb='l')
# Out:
# 1493
# 340
# 313

# %%
## all 블랙이나 all zero에 가까운 그림들 세어보기

del_abnormal_img(0.95,minmax = 'mean',lb='u')
del_abnormal_img(0.05,minmax = 'mean',lb='l')
# Out:
# 201
# 35
# 51
# 395
# 32
# 61

# %%
print(low_img_test.shape)
print(low_img_val.shape)
print(low_img_train.shape)
# Out:
# (1575, 12, 12, 1)
# (1593, 12, 12, 1)
# (6911, 12, 12, 1)

# %% [markdown]
# ##  변수들 분포 및 미분값(strain) 계산하기

# %%
print('low img min, max', low_img_train.max(), low_img_train.min())
print('high img min, max', high_img_train.max(), high_img_train.min())
# print('disp x size',disp_train.shape)

## low img clipping
low_img_train = np.clip(low_img_train,0.01,1)

print('low img min, max(new)', low_img_train.max(), low_img_train.min())

plt.hist(low_img_train.flatten(), bins=15)
plt.show()
plt.hist(high_img_train.flatten(), bins=15)
# Out:
# low img min, max 1.015873 0.01001114
# high img min, max 1.0 0.01
# low img min, max(new) 1.0 0.01001114
# (array([38509479.,  2116465.,  1244333.,   841259.,   622583.,   511219.,
#           457858.,   434037.,   427159.,   429018.,   437865.,   452643.,
#           466664.,   479487., 16261707.]),
#  array([0.01 , 0.076, 0.142, 0.208, 0.274, 0.34 , 0.406, 0.472, 0.538,
#         0.604, 0.67 , 0.736, 0.802, 0.868, 0.934, 1.   ], dtype=float32),
#  <a list of 15 Patch objects>)

# %%
print('min, max', disp_train.max(), disp_train.min())
print('disp x size',disp_train.shape)

plt.hist(disp_train.flatten(), bins=15)

## displacement는 위치에 따라 다른 값을 가지므로 방향성을 찾을 수 없음.
## Patch의 위치에 따라 절대값이 달라지므로 그대로 이용할 수 없음.
## Transformer 를 쓴다면?!
# Out:
# min, max 29.98295 -24.55797
# disp x size (6911, 13, 13, 6)
# (array([   6464.,   38825.,  132695.,  291124.,  441370.,  848902.,
#         2592993., 1067915.,  626380.,  503729.,  287001.,  118009.,
#           37014.,   10816.,    4517.]),
#  array([-24.55797  , -20.92191  , -17.285847 , -13.649786 , -10.013724 ,
#          -6.377663 ,  -2.741602 ,   0.8944594,   4.530521 ,   8.166582 ,
#          11.802644 ,  15.4387045,  19.074766 ,  22.710827 ,  26.34689  ,
#          29.98295  ], dtype=float32),
#  <a list of 15 Patch objects>)

# %%
## disp를 통해서 미분 계산하기

diff_dx_train = np.gradient(disp_train,axis=2)
diff_dy_train = np.gradient(disp_train,axis=1)

diff_dx_test = np.gradient(disp_test,axis=2)
diff_dy_test = np.gradient(disp_test,axis=1)

diff_dx_val = np.gradient(disp_val,axis=2)
diff_dy_val = np.gradient(disp_val,axis=1)

plt.hist(diff_dx_train.flatten(), bins=30)
plt.show()

plt.hist(diff_dy_train.flatten(), bins=30)
plt.show()

# %%
## 대략 -1~1로 scaling 하기 위해서 10을 곱함.
diff_dx_train = diff_dx_train*10
diff_dy_train = diff_dy_train*10

diff_dx_test = diff_dx_test*10
diff_dy_test = diff_dy_test*10

diff_dx_val = diff_dx_val*10
diff_dy_val = diff_dy_val*10

# %%
id = 100

plt.figure(figsize=(12, 12))
plt.subplot(121)
plt.imshow(low_img_train[id,:,:,0], origin='lower')
plt.subplot(122)
plt.imshow(high_img_train[id,:,:,0], origin='lower')
plt.show()

# %%
nTrain = diff_dx_train.shape[0]
plt.figure(figsize=(20, 20))

def plt_plot(data):
    plt.imshow(data, origin='lower')
    plt.colorbar()

index = 0        
        
for index in range (6):
    plt.subplot(321+index)
    plt_plot(diff_dx_train[id,:,:,index])
    plt.colorbar()


plt.show()

# %%
diff_train = np.concatenate( (diff_dx_train[:,:,:,0:3], diff_dy_train[:,:,:,3:6]), axis=3) ## xx,xy,yx, yy 중 xx,yy 성분만 우선 사용
diff_test = np.concatenate( (diff_dx_test[:,:,:,0:3], diff_dy_test[:,:,:,3:6]), axis=3) ## xx,xy,yx, yy 중 xx,yy 성분만 우선 사용
diff_val = np.concatenate( (diff_dx_val[:,:,:,0:3], diff_dy_val[:,:,:,3:6]), axis=3)

print(diff_train.shape)
print(diff_val.shape)
print(diff_test.shape)

from skimage.transform import resize
diff_train_resize = resize(diff_train, (diff_train.shape[0],12, 12,6),anti_aliasing=True)
diff_test_resize = resize(diff_test, (diff_test.shape[0],12, 12,6),anti_aliasing=True)
diff_val_resize = resize(diff_val, (diff_val.shape[0],12, 12,6),anti_aliasing=True)

print(diff_train_resize.shape)
print(diff_test_resize.shape)


diff_train = diff_train_resize
diff_test = diff_test_resize
diff_val = diff_val_resize
# Out:
# (6911, 13, 13, 6)
# (1593, 13, 13, 6)
# (1575, 13, 13, 6)
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\skimage\transform\_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\skimage\transform\_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\skimage\transform\_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# (6911, 12, 12, 6)
# (1575, 12, 12, 6)

# %%
##strain energy
plt.figure(figsize=(15, 5))   

plt.subplot(121)
plt.hist((se_train.flatten()), bins=15)
plt.subplot(122)
plt.hist(np.log(se_train.flatten()), bins=15)
plt.show()

# %%
# se 정규화?

se_train = np.log(se_train)/10
se_val = np.log(se_val)/10
se_test = np.log(se_test)/10

plt.hist((se_train.flatten()), bins=15)
# Out:
# (array([1.000000e+00, 2.800000e+01, 2.090000e+02, 1.065000e+03,
#         4.649000e+03, 1.925200e+04, 7.084200e+04, 2.168610e+05,
#         4.683760e+05, 6.048430e+05, 7.930770e+05, 1.009831e+06,
#         6.479500e+05, 1.385000e+05, 5.252000e+03]),
#  array([-1.47667422, -1.36589647, -1.25511873, -1.14434098, -1.03356324,
#         -0.92278549, -0.81200774, -0.70123   , -0.59045225, -0.4796745 ,
#         -0.36889676, -0.25811901, -0.14734126, -0.03656352,  0.07421423,
#          0.18499198]),
#  <a list of 15 Patch objects>)

# %% [markdown]
# ## 데이터를 augmentation 하기위한 함수 정의 (90도씩 돌리고 flip -> 8배)

# %%
from scipy.ndimage import rotate
import math

# plt.imshow(low[500].reshape(img_rows, img_cols), cmap='Greys', vmin=0, vmax=1)
# plt.show()

def rot_augment(img):
    img90 = np.rot90(img,k=1,axes=(2,1))
    img180 = np.rot90(img,k=2,axes=(2,1))
    img270 = np.rot90(img,k=3,axes=(2,1))

    return np.concatenate((img, img90, img180, img270), axis=0)
    # return img

def flip_augment(img):
    fl=img[:,:,::-1,:]

#     fl=img[:,::-1,:,:]

    return np.concatenate((img,fl),axis=0)

def flip_augment_vector(img):
#     fl=-img[:,::-1,:,:]
    fl=-img[:,:,::-1,:]
    return np.concatenate((img,fl),axis=0)

def augment(img):
    return flip_augment(rot_augment(img))
    #return rot_augment(img)

def rot_vector(vx,vy,k):
    vx = np.rot90(vx,k,axes=(2,1))
    vy = np.rot90(vy,k,axes=(2,1))

    th = (2*3.141592)*(k*90/360)
    print('th=',th)
    vx_rot = vx*math.cos(th)-vy*math.sin(th)
    vy_rot = vx*math.sin(th)+vy*math.cos(th)
    
    return vx_rot, vy_rot

def rot_augment_vector(vx, vy):

    vx90, vy90 = rot_vector(vx,vy,1)
    vx180, vy180 = rot_vector(vx,vy,2)
    vx270, vy270 = rot_vector(vx,vy,3)

    vx = np.concatenate((vx,vx90,vx180,vx270),axis=0)
    vy = np.concatenate((vy,vy90,vy180,vy270),axis=0)
    
    return flip_augment_vector(vx), flip_augment(vy)

def rot_augment_vector2(v):

    vx = v[:,:,:,:3]
    vy = v[:,:,:,3:]
    
    vx_arg, vy_arg = rot_augment_vector(vx,vy)
    return np.concatenate((vx_arg,vy_arg),axis=3)


#return vx, vy

# %% [markdown]
# ## Augmentation

# %%
low_img_train_aug = augment(low_img_train)
high_img_train_aug = augment(high_img_train)

low_img_val_aug = augment(low_img_val)
high_img_val_aug = augment(high_img_val)


disp_train_aug = rot_augment_vector2(disp_train)
diff_train_aug = rot_augment_vector2(diff_train)

disp_val_aug = rot_augment_vector2(disp_val)
diff_val_aug = rot_augment_vector2(diff_val)

se_train_aug = augment(se_train)
se_val_aug = augment(se_val)


print('data augment end')

print(disp_train.shape)
# Out:
# th= 1.570796
# th= 3.141592
# th= 4.712388000000001
# th= 1.570796
# th= 3.141592
# th= 4.712388000000001
# th= 1.570796
# th= 3.141592
# th= 4.712388000000001
# th= 1.570796
# th= 3.141592
# th= 4.712388000000001
# data augment end
# (6911, 13, 13, 6)

# %% [markdown]
# ## Augmentation 결과 확인

# %%
## density 분포 
id = 101

plt.figure(figsize=(20, 10))
for i in range (8):
    plt.subplot(241+i)
    plt.imshow(high_img_train_aug[id+nTrain*i,:,:,0],origin='lower')
#     plt_plot(diff_dx_train[id,:,:,index])
#     plt.colorbar()

# for i in range(8):
#     plt.imshow(high_img_train_aug[id+nTrain*i,:,:,0],origin='lower')
    
plt.show()

# %%
# diff (gradient) x,y 를 시각적으로 표현. augmentation 제대로 되고 있나 확인


x = np.arange(0,12,1)
y = np.arange(0,12,1)

X, Y = np.meshgrid(x, y)

# for i in range (8):
#     plt.subplot(241+i)
plt.figure(figsize=(20, 10))

for i in range(8):
    plt.subplot(241+i)
    u = diff_train_aug[id+nTrain*i,:,:,0]
    v = diff_train_aug[id+nTrain*i,:,:,3]

#     fig, ax = plt.subplots(figsize=(7,7))
#     ax.quiver(X,Y,u,v)
    plt.quiver(X,Y,u,v)
    
plt.show()

# %%
# u,v -> r, cos, sin

diff_train_aug_rcs = np.zeros((diff_train_aug.shape[0],12,12,9))
diff_val_aug_rcs = np.zeros((diff_val_aug.shape[0],12,12,9))
diff_test_rcs = np.zeros((diff_test.shape[0],12,12,9))

for i in range(3):
    u = diff_train_aug[:,:,:,i]
    v = diff_train_aug[:,:,:,i+3]
    r = (u**2+v**2)**0.5
    diff_train_aug_rcs[:,:,:,i*3+0] = r
    diff_train_aug_rcs[:,:,:,i*3+1] = u/r
    diff_train_aug_rcs[:,:,:,i*3+2] = v/r
    
for i in range(3):
    u = diff_val_aug[:,:,:,i]
    v = diff_val_aug[:,:,:,i+3]
    r = (u**2+v**2)**0.5
    diff_val_aug_rcs[:,:,:,i*3+0] = r
    diff_val_aug_rcs[:,:,:,i*3+1] = u/r
    diff_val_aug_rcs[:,:,:,i*3+2] = v/r
    
for i in range(3):
    u = diff_test[:,:,:,i]
    v = diff_test[:,:,:,i+3]
    r = (u**2+v**2)**0.5
    diff_test_rcs[:,:,:,i*3+0] = r
    diff_test_rcs[:,:,:,i*3+1] = u/r
    diff_test_rcs[:,:,:,i*3+2] = v/r

# %%
plt.hist((diff_train_aug_rcs[id,:,:,0].flatten()), bins=15)
print(r.shape)
plt.figure(figsize=(20, 10))
for i in range(8):
    plt.subplot(241+i)
    u = diff_train_aug_rcs[id+nTrain*i,:,:,1]
    v = diff_train_aug_rcs[id+nTrain*i,:,:,2]

#     fig, ax = plt.subplots(figsize=(7,7))
#     ax.quiver(X,Y,u,v)
    plt.quiver(X,Y,u,v)
    
    
plt.show()


# u = diff_train_aug_rcs[id,:,:,1]
# v = diff_train_aug_rcs[id,:,:,4]
# plt.quiver(X,Y,u,v)
# plt.figure(figsize=(8, 8))
plt.show()
# Out:
# (1575, 12, 12)

# %%
def SubpixelConv2D(input_shape, scale=4):
    """
    Keras layer to do subpixel convolution.
    NOTE: Tensorflow backend only. Uses tf.depth_to_space
    Ref:
        [1] Real-Time Single Image and Video Super-Resolution Using an Efficient Sub-Pixel Convolutional Neural Network
            Shi et Al.
            https://arxiv.org/abs/1609.05158
    :param input_shape: tensor shape, (batch, height, width, channel)
    :param scale: upsampling scale. Default=4
    :return:
    """
    # upsample using depth_to_space
    def subpixel_shape(input_shape):
        dims = [input_shape[0],
                input_shape[1] * scale,
                input_shape[2] * scale,
                int(input_shape[3] / (scale ** 2))]
        output_shape = tuple(dims)
        return output_shape

    def subpixel(x):
        return tf.nn.depth_to_space(x, scale)


#     return Lambda(subpixel, output_shape=subpixel_shape, name='subpixel')
    return Lambda(subpixel, output_shape=subpixel_shape)

# %%
def custom_loss(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    return keras.losses.mean_absolute_error(y_true_f, y_pred_f)

def custom_loss2(y_true, y_pred):
    y_true_f = y_true[2,:]
    y_pred_f = y_pred[2,:]
    return keras.losses.mean_absolute_error(y_true_f, y_pred_f)

# %% [markdown]
# ## 학습조건

# %%
def run(name = ""):

    n_ch = 2
    if rcs and use_r:
        n_ch = n_ch+1
    if seInfo == True :
        n_ch = n_ch+1

    se_train_aug_sum = se_train_aug[:,:,:,3]
    se_val_aug_sum = se_val_aug[:,:,:,3]
    se_test_sum = se_test[:,:,:,3]

    se_train_aug_sum = data_reshape(se_train_aug_sum,12,12,1)
    se_val_aug_sum = data_reshape(se_val_aug_sum,12,12,1)
    se_test_sum = data_reshape(se_test_sum,12,12,1)


    # diff_train_aug[id+nTrain*i,:,:,0]
    # diff_train_aug[id+nTrain*i,:,:,3]

    # x = diff_train_aug
#     n_ch = 2

    # else:
    #     n_ch = 2
    if strInfo:
        if rcs:
            diff_train_aug_rcs2 = np.zeros((diff_train_aug.shape[0],12,12,3,n_ch))
            if use_r:
                diff_train_aug_rcs2[:,:,:,0,0:3] = diff_train_aug_rcs[:,:,:,0:3]
                diff_train_aug_rcs2[:,:,:,1,0:3] = diff_train_aug_rcs[:,:,:,3:6]
                diff_train_aug_rcs2[:,:,:,2,0:3] = diff_train_aug_rcs[:,:,:,6:9]
                if seInfo:     
                    diff_train_aug_rcs2[:,:,:,:,3] = se_train_aug[:,:,:,0:3]
            else:
                diff_train_aug_rcs2[:,:,:,0,0:2] = diff_train_aug_rcs[:,:,:,1:3]
                diff_train_aug_rcs2[:,:,:,1,0:2] = diff_train_aug_rcs[:,:,:,4:6]
                diff_train_aug_rcs2[:,:,:,2,0:2] = diff_train_aug_rcs[:,:,:,7:9] 
                if seInfo:     
                    diff_train_aug_rcs2[:,:,:,:,2] = se_train_aug[:,:,:,0:3]

        else:
            diff_train_aug2 = np.zeros((diff_train_aug.shape[0],12,12,3,n_ch))
            diff_train_aug2[:,:,:,:,0] = diff_train_aug[:,:,:,0:3]
            diff_train_aug2[:,:,:,:,1] = diff_train_aug[:,:,:,3:6]
            if seInfo:
                diff_train_aug2[:,:,:,:,2] = se_train_aug[:,:,:,0:3]
    # diff_train_aug_rcs



#     print(diff_train_aug2.shape)



    if strInfo:
        if rcs:
            diff_val_aug_rcs2 = np.zeros((diff_val_aug.shape[0],12,12,3,n_ch))
            if use_r:            
                diff_val_aug_rcs2[:,:,:,0,0:3] = diff_val_aug_rcs[:,:,:,0:3]
                diff_val_aug_rcs2[:,:,:,1,0:3] = diff_val_aug_rcs[:,:,:,3:6]
                diff_val_aug_rcs2[:,:,:,2,0:3] = diff_val_aug_rcs[:,:,:,6:9]
                if seInfo:
                    diff_val_aug_rcs2[:,:,:,:,3] = se_val_aug[:,:,:,0:3]
            ## cs만
            else:
                diff_val_aug_rcs2[:,:,:,0,0:2] = diff_val_aug_rcs[:,:,:,1:3]
                diff_val_aug_rcs2[:,:,:,1,0:2] = diff_val_aug_rcs[:,:,:,4:6]
                diff_val_aug_rcs2[:,:,:,2,0:2] = diff_val_aug_rcs[:,:,:,7:9]
                if seInfo:
                    diff_val_aug_rcs2[:,:,:,:,2] = se_val_aug[:,:,:,0:3]

        else:
            diff_val_aug2 = np.zeros((diff_val_aug.shape[0],12,12,3,n_ch))
            diff_val_aug2[:,:,:,:,0] = diff_val_aug[:,:,:,0:3]
            diff_val_aug2[:,:,:,:,1] = diff_val_aug[:,:,:,3:6]
            if seInfo:
                diff_val_aug2[:,:,:,:,2] = se_val_aug[:,:,:,0:3]





    if strInfo:
        if rcs:
            diff_test_rcs2 = np.zeros((diff_test.shape[0],12,12,3,n_ch))
            if use_r:        
                diff_test_rcs2[:,:,:,0,0:3] = diff_test_rcs[:,:,:,0:3]
                diff_test_rcs2[:,:,:,1,0:3] = diff_test_rcs[:,:,:,3:6]
                diff_test_rcs2[:,:,:,2,0:3] = diff_test_rcs[:,:,:,6:9]
                if seInfo:
                    diff_test_rcs2[:,:,:,:,3] = se_test[:,:,:,0:3]
            else:
                diff_test_rcs2[:,:,:,0,0:2] = diff_test_rcs[:,:,:,1:3]
                diff_test_rcs2[:,:,:,1,0:2] = diff_test_rcs[:,:,:,4:6]
                diff_test_rcs2[:,:,:,2,0:2] = diff_test_rcs[:,:,:,7:9]
                if seInfo:
                    diff_test_rcs2[:,:,:,:,3] = se_test[:,:,:,0:3]        
        else:
 
            diff_test2 = np.zeros((diff_test.shape[0],12,12,3,n_ch))
            diff_test2[:,:,:,:,0] = diff_test[:,:,:,0:3]
            diff_test2[:,:,:,:,1] = diff_test[:,:,:,3:6]   
            if seInfo:
                diff_test2[:,:,:,:,2] = se_test[:,:,:,0:3]



    def ConvBlock(fn, fs, act, pad, repeat,x):

        y = x
        for i in range(repeat):
            s = y
            y = Conv2D(fn,fs,padding = pad, kernel_initializer = init_f)(y)
            y = BatchNormalization()(y)
    #         y = Activation(act)(y)
            y = PReLU()(y)
            y = Conv2D(fn,fs, padding = pad, kernel_initializer = init_f)(y)
            y = BatchNormalization()(y)

            y = keras.layers.add([s,y])

        y = Conv2D(fn,fs,padding = pad, kernel_initializer = init_f)(y)
        y = BatchNormalization()(y)
        y = keras.layers.add([x,y])
        return y
    
    ## 입력 tensor의 정의 

    # if rcs == True: ## rcs 사용하는 경우
    #     n_ch = n_ch+1

    low = Input(batch_shape=(None,) + input_size)
    high = Input(batch_shape=(None,) + original_img_size)
    disp = Input(batch_shape=(None,) + disp_size)

    if permut_inv == True:  #
        diff = Input(batch_shape=(None,) + (12,12,3,n_ch))
    else:
        diff = Input(batch_shape=(None,) + (12,12,3*n_rcs))

    se = Input(batch_shape=(None,) + se_size)
    se_sum = Input(batch_shape=(None,) + (12,12,1))


    ## model의 정의 
    from keras.layers import Conv3D, MaxPooling3D, Permute, Add, AveragePooling3D
    from keras.layers.advanced_activations import PReLU

    # disp는 nodal information이고 se는 element information이므로 차원이 다릅니다. (n,m),(n+1,m+1)
    # 따라서 차원을 맞춰주기 위해서 padding이 없고 filter size 가 2인 cnn을 먹여서 차원을 같게 맞춰준후 concatenate합니다. 




    # def SrModel(strInfo=False, seInfo=False, permut_inv=False):
    # @tf.function
    def layers(low,diff,se):
        if strInfo==True:
            if permut_inv == True:
    ########################################################################################################
    ## structural information 처리 부분 
    ############################ new structure for structural information (puermutation invariation layer)
                conv0 = Conv3D(int(n_ker_st/4),(3,3,1), activation = act_f, padding = 'same', kernel_initializer = init_f)(diff)
                conv0 = Conv3D(int(n_ker_st/2),(3,3,1), activation = act_f, padding = 'same', kernel_initializer = init_f)(conv0)
                conv0 = Conv3D(int(n_ker_st),(3,3,1), activation = act_f, padding = 'same', kernel_initializer = init_f)(conv0)
        #         conv1 = Permute((1,2,4,3))(conv0)
    #             conv0 = MaxPooling3D((1,1,3))(conv0)
                conv0 = AveragePooling3D((1,1,3))(conv0)
                conv0 = Permute((1,2,4,3))(conv0)
                conv0 = Reshape((12,12,int(n_ker_st)))(conv0)


    ##########################################################################################################
            else: ###### old structure
                conv0 = Conv2D(32,3,activation=act_f, padding = 'same', kernel_initializer = init_f)(diff)
                conv0 = Conv2D(64,3,activation=act_f, padding = 'same', kernel_initializer = init_f)(conv0)
                conv0 = Conv2D(128,3,activation=act_f, padding = 'same', kernel_initializer = init_f)(conv0)

    ##########################################################################################################    



    ## main network Resnet + subpixelCNN
        if strInfo==True and seInfo == True:
            x = keras.layers.concatenate([low,se_sum], axis=3)
        else:
            x = low
            
        y = Conv2D(n_ker,3, padding='same',kernel_initializer=init_f)(x)

        if strInfo==True:
            y = keras.layers.concatenate([y,conv0], axis=3)

    # use only str
    #     y = conv0


        y = Conv2D(n_ker,3, padding='same',kernel_initializer=init_f)(y)
        y = PReLU()(y)

    #     out = [0]*3
        for n in range(3): ##  한번에 두배씩 8배 upscaling
#             y = ConvBlock(n_ker, 3, 'relu', 'same',  repeat, y)
#             y = Conv2D(n_ker*4,3,padding='same',kernel_initializer=init_f)(y)
#             y = SubpixelConv2D((12*(2**n),12*(2**n),n_ker*4), scale=2)(y)

            y = ConvBlock(n_ker//(4**n), 3, 'relu', 'same',  repeat, y)
            y = SubpixelConv2D((12*(2**n),12*(2**n),n_ker//(4**n)), scale=2)(y)

            
            y = PReLU()(y)            
            
            
    #     out24 = out[0]
    #     out48 = out[1]
    #     out96 = out[2]    


#         pre_up = UpSampling2D(size = (8,8), interpolation=interpolation)(low)
#         y = keras.layers.concatenate([y,up],axis=3)

        y = Conv2D(1, 1, activation='sigmoid',padding='same')(y)

        return y


    def SrModel():

        if strInfo==True:
            if seInfo == True:
                x = [low,diff, se_sum]
            else:
                x = [low,diff]
        else:
            x = low

        out96 = layers(low,diff,se)
        model = Model(x,out96)
        return model

    # model = SrModel(strInfo,  seInfo, permut_inv)

    model = SrModel()
    if print_summary:
        model.summary()

    model.compile(optimizer='adam',#''rmsprop',
    #             loss=custom_loss,
    #             loss='binary_rossentropy',
              loss='mae',
    #         metrics=['mae'],
                )
    csv_logger = callbacks.CSVLogger('log_g%s.txt'%gpu_id,append=True)
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)

    MODEL_SAVE_FOLDER_PATH = './model/'
    if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
      os.mkdir(MODEL_SAVE_FOLDER_PATH)

    model_path = MODEL_SAVE_FOLDER_PATH + '{epoch:02d}-{val_loss:.4f}-gpu%s.hdf5'%gpu_id

    checkpoint = callbacks.ModelCheckpoint(filepath=model_path, 
                                           monitor='val_loss',
                                           verbose=0, 
                                           save_best_only=True)

    checkpoint2 = callbacks.ModelCheckpoint('check_g%s.h5'%gpu_id, 
                                            monitor='val_loss', 
                                            verbose=0, 
                                            save_best_only=True, 
                                            save_weights_only=True, 
                                            mode='auto', 
                                            period=1)

    if prog_loss == True:
        y_train = [high_img_train_aug24, high_img_train_aug48, high_img_train_aug]
        y_val = [high_img_val_aug24, high_img_val_aug48, high_img_val_aug]
    else:
        y_train = high_img_train_aug
        y_val =high_img_val_aug


    if strInfo:
        if permut_inv == True:
            if rcs==True:
                x_diff_train = diff_train_aug_rcs2
                x_diff_val = diff_val_aug_rcs2
            else:
                x_diff_train = diff_train_aug2
                x_diff_val = diff_val_aug2

    if strInfo==True:
        if seInfo==True:
            x_train = [low_img_train_aug, 
                       x_diff_train,
                       se_train_aug_sum,
                        ]
            x_val = [low_img_val_aug,  
                     x_diff_val,
                     se_val_aug_sum,
                    ]
        else:
            x_train = [low_img_train_aug, 
                       x_diff_train,
                      ]
            x_val = [low_img_val_aug,  
                     x_diff_val,
                    ]
    else:
        x_train = low_img_train_aug
        x_val = low_img_val_aug  


    print('strInfo:',strInfo)
    print('permut:',permut_inv)
    print('se:',seInfo)
    print('prog_loss:', prog_loss)
#     epochs = 50
    import time
    start_vect=time.time()     
    
    from sklearn.utils import shuffle
#     x_train[0], y_train = shuffle(x_train[0], y_train,random_state=0)
    
    his = model.fit(x_train, 
                    y_train,
                    shuffle=True,
                    epochs=epochs,
                    batch_size=batch_size,
                    verbose=verbose,
                    callbacks=[csv_logger, checkpoint, checkpoint2],
                           #early_stopping
                           # ])
                    validation_split=0.2,
#                     validation_data=(x_val, y_val)
                    )

    print("training Runtime: %0.2f Minutes"%((time.time() - start_vect)/60))


    model.save('model_final_g%s.h5'%gpu_id,overwrite=True)
    model.save_weights('model_final_weight_g%s.h5'%gpu_id)

    ##################Test
    ## load best model
    model.load_weights("check_g%s.h5"%gpu_id)

    if prog_loss == True:
        y_test = [high_img_test24, high_img_test48,high_img_test]
    else:
        y_test = high_img_test

    if strInfo==True:
    #     evaluate = model.evaluate([low_img_test, disp_test, se_test], high_img_test,  batch_size, verbose=2)
    #     predict_img = model.predict([low_img_test, disp_test, se_test],  batch_size, verbose=2)
    #     evaluate = model.evaluate([low_img_test, diff_test2, se_test], high_img_test,  batch_size, verbose=2)
    #     predict_img = model.predict([low_img_test, diff_test2, se_test],  batch_size, verbose=2)
        if permut_inv == True:
            if rcs == True:
                x_diff_test = diff_test_rcs2
            else:
                x_diff_test = diff_test2
        if seInfo ==True:
            evaluate = model.evaluate([low_img_test, x_diff_test, se_test_sum], y_test,  batch_size, verbose=2)
            predict_img = model.predict([low_img_test, x_diff_test, se_test_sum],  batch_size, verbose=2)
        else:
            evaluate = model.evaluate([low_img_test, x_diff_test], y_test,  batch_size, verbose=2)
            predict_img = model.predict([low_img_test, x_diff_test],  batch_size, verbose=2)

    else:
        evaluate = model.evaluate(low_img_test, y_test,  batch_size, verbose=2)
        predict_img = model.predict(low_img_test,  batch_size, verbose=2)

        
    print(evaluate)
    ##################Plot History
    if plot_history:
        fig, loss_ax = plt.subplots()
        # acc_ax = loss_ax.twinx()

        loss_ax.plot(his.history['loss'], 'y', label='train loss')
        loss_ax.plot(his.history['val_loss'], 'r', label='val loss')
        loss_ax.set_xlabel('epoch')
        loss_ax.set_ylabel('loss')
        loss_ax.legend(loc='upper right')
        # seaborn.despine(ax=loss_ax, offset=0) # the important part here

        # loss_ax.axhline(y=0, color='k')
        # loss_ax.axvline(x=0, color='k')

        # plt.ylim(bottom=0)
        plt.grid(True)
        plt.show()

    if plot_output:
        for i in range(4):
            plt.figure(figsize=(15, 8))
            plt.subplot(131)
            plt.imshow(low_img_test[id+i,:,:,0])
            plt.subplot(132)
            plt.imshow(high_img_test[id+i,:,:,0])
            plt.subplot(133)
            plt.imshow(predict_img[id+i,:,:,0])
            plt.show()
        
    if save_output:
        np.save(name+'_true',high_img_test)
        np.save(name+'_pred',predict_img)
#         np.save(name+'output',high_img_test)
            # !pip install jovian -q --upgrade
    # jovian.commit()
    return evaluate

# %%
####################### 시험 조건############################
strInfo = False   # 추가적인 structural information을 고려하는가?
rcs = True
use_r = True
seInfo = False   # strain(grdient)외에 strain engery도 고려하는가?
prog_loss = False # high res. 뿐만 아니라 중간 단계 결과물에 대해서 loss를 고려하는가?
permut_inv = True
verbose = 2 #0 = silent, 1 = progress bar, 2 = one line per epoch.
batch_size = 32
epochs = 50
plot_output = True
plot_history = True
save_output = True
print_summary = True
id = 150
n_ker = int(512) #128
n_ker_st = n_ker


interpolation='bilinear' #'nearest'   #upscaling시 방법 nearest는 같은 값으로 채우고, bilinear는 interpolation 합니다.
act_f = 'relu'

init_f = 'glorot_uniform' #'he_normal'
repeat = 10 # 5

# %%
eval1 = run("no_st")
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_28 (InputLayer)           (None, 12, 12, 3, 3) 0
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 12, 12, 3, 11 3136        input_28[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 12, 12, 3, 22 226016      conv3d_10[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 12, 12, 3, 44 903616      conv3d_11[0][0]
# __________________________________________________________________________________________________
# input_25 (InputLayer)           (None, 12, 12, 1)    0
# __________________________________________________________________________________________________
# input_30 (InputLayer)           (None, 12, 12, 1)    0
# __________________________________________________________________________________________________
# average_pooling3d_4 (AveragePoo (None, 12, 12, 1, 44 0           conv3d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 12, 12, 2)    0           input_25[0][0]
#                                                                  input_30[0][0]
# __________________________________________________________________________________________________
# permute_4 (Permute)             (None, 12, 12, 448,  0           average_pooling3d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_265 (Conv2D)             (None, 12, 12, 448)  8512        concatenate_6[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 12, 12, 448)  0           permute_4[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 12, 12, 896)  0           conv2d_265[0][0]
#                                                                  reshape_4[0][0]
# __________________________________________________________________________________________________
# conv2d_266 (Conv2D)             (None, 12, 12, 448)  3613120     concatenate_7[0][0]
# __________________________________________________________________________________________________
# p_re_lu_137 (PReLU)             (None, 12, 12, 448)  64512       conv2d_266[0][0]
# __________________________________________________________________________________________________
# conv2d_267 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_137[0][0]
# __________________________________________________________________________________________________
# batch_normalization_253 (BatchN (None, 12, 12, 448)  1792        conv2d_267[0][0]
# __________________________________________________________________________________________________
# p_re_lu_138 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_253[0][0]
# __________________________________________________________________________________________________
# conv2d_268 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_138[0][0]
# __________________________________________________________________________________________________
# batch_normalization_254 (BatchN (None, 12, 12, 448)  1792        conv2d_268[0][0]
# __________________________________________________________________________________________________
# add_133 (Add)                   (None, 12, 12, 448)  0           p_re_lu_137[0][0]
#                                                                  batch_normalization_254[0][0]
# __________________________________________________________________________________________________
# conv2d_269 (Conv2D)             (None, 12, 12, 448)  1806784     add_133[0][0]
# __________________________________________________________________________________________________
# batch_normalization_255 (BatchN (None, 12, 12, 448)  1792        conv2d_269[0][0]
# __________________________________________________________________________________________________
# p_re_lu_139 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_255[0][0]
# __________________________________________________________________________________________________
# conv2d_270 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_139[0][0]
# __________________________________________________________________________________________________
# batch_normalization_256 (BatchN (None, 12, 12, 448)  1792        conv2d_270[0][0]
# __________________________________________________________________________________________________
# add_134 (Add)                   (None, 12, 12, 448)  0           add_133[0][0]
#                                                                  batch_normalization_256[0][0]
# __________________________________________________________________________________________________
# conv2d_271 (Conv2D)             (None, 12, 12, 448)  1806784     add_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_257 (BatchN (None, 12, 12, 448)  1792        conv2d_271[0][0]
# __________________________________________________________________________________________________
# p_re_lu_140 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_257[0][0]
# __________________________________________________________________________________________________
# conv2d_272 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_258 (BatchN (None, 12, 12, 448)  1792        conv2d_272[0][0]
# __________________________________________________________________________________________________
# add_135 (Add)                   (None, 12, 12, 448)  0           add_134[0][0]
#                                                                  batch_normalization_258[0][0]
# __________________________________________________________________________________________________
# conv2d_273 (Conv2D)             (None, 12, 12, 448)  1806784     add_135[0][0]
# __________________________________________________________________________________________________
# batch_normalization_259 (BatchN (None, 12, 12, 448)  1792        conv2d_273[0][0]
# __________________________________________________________________________________________________
# p_re_lu_141 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_259[0][0]
# __________________________________________________________________________________________________
# conv2d_274 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_141[0][0]
# __________________________________________________________________________________________________
# batch_normalization_260 (BatchN (None, 12, 12, 448)  1792        conv2d_274[0][0]
# __________________________________________________________________________________________________
# add_136 (Add)                   (None, 12, 12, 448)  0           add_135[0][0]
#                                                                  batch_normalization_260[0][0]
# __________________________________________________________________________________________________
# conv2d_275 (Conv2D)             (None, 12, 12, 448)  1806784     add_136[0][0]
# __________________________________________________________________________________________________
# batch_normalization_261 (BatchN (None, 12, 12, 448)  1792        conv2d_275[0][0]
# __________________________________________________________________________________________________
# p_re_lu_142 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_261[0][0]
# __________________________________________________________________________________________________
# conv2d_276 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_262 (BatchN (None, 12, 12, 448)  1792        conv2d_276[0][0]
# __________________________________________________________________________________________________
# add_137 (Add)                   (None, 12, 12, 448)  0           add_136[0][0]
#                                                                  batch_normalization_262[0][0]
# __________________________________________________________________________________________________
# conv2d_277 (Conv2D)             (None, 12, 12, 448)  1806784     add_137[0][0]
# __________________________________________________________________________________________________
# batch_normalization_263 (BatchN (None, 12, 12, 448)  1792        conv2d_277[0][0]
# __________________________________________________________________________________________________
# p_re_lu_143 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_263[0][0]
# __________________________________________________________________________________________________
# conv2d_278 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_143[0][0]
# __________________________________________________________________________________________________
# batch_normalization_264 (BatchN (None, 12, 12, 448)  1792        conv2d_278[0][0]
# __________________________________________________________________________________________________
# add_138 (Add)                   (None, 12, 12, 448)  0           add_137[0][0]
#                                                                  batch_normalization_264[0][0]
# __________________________________________________________________________________________________
# conv2d_279 (Conv2D)             (None, 12, 12, 448)  1806784     add_138[0][0]
# __________________________________________________________________________________________________
# batch_normalization_265 (BatchN (None, 12, 12, 448)  1792        conv2d_279[0][0]
# __________________________________________________________________________________________________
# p_re_lu_144 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_265[0][0]
# __________________________________________________________________________________________________
# conv2d_280 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_266 (BatchN (None, 12, 12, 448)  1792        conv2d_280[0][0]
# __________________________________________________________________________________________________
# add_139 (Add)                   (None, 12, 12, 448)  0           add_138[0][0]
#                                                                  batch_normalization_266[0][0]
# __________________________________________________________________________________________________
# conv2d_281 (Conv2D)             (None, 12, 12, 448)  1806784     add_139[0][0]
# __________________________________________________________________________________________________
# batch_normalization_267 (BatchN (None, 12, 12, 448)  1792        conv2d_281[0][0]
# __________________________________________________________________________________________________
# p_re_lu_145 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_267[0][0]
# __________________________________________________________________________________________________
# conv2d_282 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_145[0][0]
# __________________________________________________________________________________________________
# batch_normalization_268 (BatchN (None, 12, 12, 448)  1792        conv2d_282[0][0]
# __________________________________________________________________________________________________
# add_140 (Add)                   (None, 12, 12, 448)  0           add_139[0][0]
#                                                                  batch_normalization_268[0][0]
# __________________________________________________________________________________________________
# conv2d_283 (Conv2D)             (None, 12, 12, 448)  1806784     add_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_269 (BatchN (None, 12, 12, 448)  1792        conv2d_283[0][0]
# __________________________________________________________________________________________________
# p_re_lu_146 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_269[0][0]
# __________________________________________________________________________________________________
# conv2d_284 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_270 (BatchN (None, 12, 12, 448)  1792        conv2d_284[0][0]
# __________________________________________________________________________________________________
# add_141 (Add)                   (None, 12, 12, 448)  0           add_140[0][0]
#                                                                  batch_normalization_270[0][0]
# __________________________________________________________________________________________________
# conv2d_285 (Conv2D)             (None, 12, 12, 448)  1806784     add_141[0][0]
# __________________________________________________________________________________________________
# batch_normalization_271 (BatchN (None, 12, 12, 448)  1792        conv2d_285[0][0]
# __________________________________________________________________________________________________
# p_re_lu_147 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_271[0][0]
# __________________________________________________________________________________________________
# conv2d_286 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_272 (BatchN (None, 12, 12, 448)  1792        conv2d_286[0][0]
# __________________________________________________________________________________________________
# add_142 (Add)                   (None, 12, 12, 448)  0           add_141[0][0]
#                                                                  batch_normalization_272[0][0]
# __________________________________________________________________________________________________
# conv2d_287 (Conv2D)             (None, 12, 12, 448)  1806784     add_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_273 (BatchN (None, 12, 12, 448)  1792        conv2d_287[0][0]
# __________________________________________________________________________________________________
# add_143 (Add)                   (None, 12, 12, 448)  0           p_re_lu_137[0][0]
#                                                                  batch_normalization_273[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 24, 24, 112)  0           add_143[0][0]
# __________________________________________________________________________________________________
# p_re_lu_148 (PReLU)             (None, 24, 24, 112)  64512       lambda_13[0][0]
# __________________________________________________________________________________________________
# conv2d_288 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_274 (BatchN (None, 24, 24, 112)  448         conv2d_288[0][0]
# __________________________________________________________________________________________________
# p_re_lu_149 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_274[0][0]
# __________________________________________________________________________________________________
# conv2d_289 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_149[0][0]
# __________________________________________________________________________________________________
# batch_normalization_275 (BatchN (None, 24, 24, 112)  448         conv2d_289[0][0]
# __________________________________________________________________________________________________
# add_144 (Add)                   (None, 24, 24, 112)  0           p_re_lu_148[0][0]
#                                                                  batch_normalization_275[0][0]
# __________________________________________________________________________________________________
# conv2d_290 (Conv2D)             (None, 24, 24, 112)  113008      add_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_276 (BatchN (None, 24, 24, 112)  448         conv2d_290[0][0]
# __________________________________________________________________________________________________
# p_re_lu_150 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_276[0][0]
# __________________________________________________________________________________________________
# conv2d_291 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_150[0][0]
# __________________________________________________________________________________________________
# batch_normalization_277 (BatchN (None, 24, 24, 112)  448         conv2d_291[0][0]
# __________________________________________________________________________________________________
# add_145 (Add)                   (None, 24, 24, 112)  0           add_144[0][0]
#                                                                  batch_normalization_277[0][0]
# __________________________________________________________________________________________________
# conv2d_292 (Conv2D)             (None, 24, 24, 112)  113008      add_145[0][0]
# __________________________________________________________________________________________________
# batch_normalization_278 (BatchN (None, 24, 24, 112)  448         conv2d_292[0][0]
# __________________________________________________________________________________________________
# p_re_lu_151 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_278[0][0]
# __________________________________________________________________________________________________
# conv2d_293 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_151[0][0]
# __________________________________________________________________________________________________
# batch_normalization_279 (BatchN (None, 24, 24, 112)  448         conv2d_293[0][0]
# __________________________________________________________________________________________________
# add_146 (Add)                   (None, 24, 24, 112)  0           add_145[0][0]
#                                                                  batch_normalization_279[0][0]
# __________________________________________________________________________________________________
# conv2d_294 (Conv2D)             (None, 24, 24, 112)  113008      add_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_280 (BatchN (None, 24, 24, 112)  448         conv2d_294[0][0]
# __________________________________________________________________________________________________
# p_re_lu_152 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_280[0][0]
# __________________________________________________________________________________________________
# conv2d_295 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_152[0][0]
# __________________________________________________________________________________________________
# batch_normalization_281 (BatchN (None, 24, 24, 112)  448         conv2d_295[0][0]
# __________________________________________________________________________________________________
# add_147 (Add)                   (None, 24, 24, 112)  0           add_146[0][0]
#                                                                  batch_normalization_281[0][0]
# __________________________________________________________________________________________________
# conv2d_296 (Conv2D)             (None, 24, 24, 112)  113008      add_147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_282 (BatchN (None, 24, 24, 112)  448         conv2d_296[0][0]
# __________________________________________________________________________________________________
# p_re_lu_153 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_282[0][0]
# __________________________________________________________________________________________________
# conv2d_297 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_153[0][0]
# __________________________________________________________________________________________________
# batch_normalization_283 (BatchN (None, 24, 24, 112)  448         conv2d_297[0][0]
# __________________________________________________________________________________________________
# add_148 (Add)                   (None, 24, 24, 112)  0           add_147[0][0]
#                                                                  batch_normalization_283[0][0]
# __________________________________________________________________________________________________
# conv2d_298 (Conv2D)             (None, 24, 24, 112)  113008      add_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_284 (BatchN (None, 24, 24, 112)  448         conv2d_298[0][0]
# __________________________________________________________________________________________________
# p_re_lu_154 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_284[0][0]
# __________________________________________________________________________________________________
# conv2d_299 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_154[0][0]
# __________________________________________________________________________________________________
# batch_normalization_285 (BatchN (None, 24, 24, 112)  448         conv2d_299[0][0]
# __________________________________________________________________________________________________
# add_149 (Add)                   (None, 24, 24, 112)  0           add_148[0][0]
#                                                                  batch_normalization_285[0][0]
# __________________________________________________________________________________________________
# conv2d_300 (Conv2D)             (None, 24, 24, 112)  113008      add_149[0][0]
# __________________________________________________________________________________________________
# batch_normalization_286 (BatchN (None, 24, 24, 112)  448         conv2d_300[0][0]
# __________________________________________________________________________________________________
# p_re_lu_155 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_286[0][0]
# __________________________________________________________________________________________________
# conv2d_301 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_155[0][0]
# __________________________________________________________________________________________________
# batch_normalization_287 (BatchN (None, 24, 24, 112)  448         conv2d_301[0][0]
# __________________________________________________________________________________________________
# add_150 (Add)                   (None, 24, 24, 112)  0           add_149[0][0]
#                                                                  batch_normalization_287[0][0]
# __________________________________________________________________________________________________
# conv2d_302 (Conv2D)             (None, 24, 24, 112)  113008      add_150[0][0]
# __________________________________________________________________________________________________
# batch_normalization_288 (BatchN (None, 24, 24, 112)  448         conv2d_302[0][0]
# __________________________________________________________________________________________________
# p_re_lu_156 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_288[0][0]
# __________________________________________________________________________________________________
# conv2d_303 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_156[0][0]
# __________________________________________________________________________________________________
# batch_normalization_289 (BatchN (None, 24, 24, 112)  448         conv2d_303[0][0]
# __________________________________________________________________________________________________
# add_151 (Add)                   (None, 24, 24, 112)  0           add_150[0][0]
#                                                                  batch_normalization_289[0][0]
# __________________________________________________________________________________________________
# conv2d_304 (Conv2D)             (None, 24, 24, 112)  113008      add_151[0][0]
# __________________________________________________________________________________________________
# batch_normalization_290 (BatchN (None, 24, 24, 112)  448         conv2d_304[0][0]
# __________________________________________________________________________________________________
# p_re_lu_157 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_290[0][0]
# __________________________________________________________________________________________________
# conv2d_305 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_157[0][0]
# __________________________________________________________________________________________________
# batch_normalization_291 (BatchN (None, 24, 24, 112)  448         conv2d_305[0][0]
# __________________________________________________________________________________________________
# add_152 (Add)                   (None, 24, 24, 112)  0           add_151[0][0]
#                                                                  batch_normalization_291[0][0]
# __________________________________________________________________________________________________
# conv2d_306 (Conv2D)             (None, 24, 24, 112)  113008      add_152[0][0]
# __________________________________________________________________________________________________
# batch_normalization_292 (BatchN (None, 24, 24, 112)  448         conv2d_306[0][0]
# __________________________________________________________________________________________________
# p_re_lu_158 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_292[0][0]
# __________________________________________________________________________________________________
# conv2d_307 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_293 (BatchN (None, 24, 24, 112)  448         conv2d_307[0][0]
# __________________________________________________________________________________________________
# add_153 (Add)                   (None, 24, 24, 112)  0           add_152[0][0]
#                                                                  batch_normalization_293[0][0]
# __________________________________________________________________________________________________
# conv2d_308 (Conv2D)             (None, 24, 24, 112)  113008      add_153[0][0]
# __________________________________________________________________________________________________
# batch_normalization_294 (BatchN (None, 24, 24, 112)  448         conv2d_308[0][0]
# __________________________________________________________________________________________________
# add_154 (Add)                   (None, 24, 24, 112)  0           p_re_lu_148[0][0]
#                                                                  batch_normalization_294[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 48, 48, 28)   0           add_154[0][0]
# __________________________________________________________________________________________________
# p_re_lu_159 (PReLU)             (None, 48, 48, 28)   64512       lambda_14[0][0]
# __________________________________________________________________________________________________
# conv2d_309 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_159[0][0]
# __________________________________________________________________________________________________
# batch_normalization_295 (BatchN (None, 48, 48, 28)   112         conv2d_309[0][0]
# __________________________________________________________________________________________________
# p_re_lu_160 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_295[0][0]
# __________________________________________________________________________________________________
# conv2d_310 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_160[0][0]
# __________________________________________________________________________________________________
# batch_normalization_296 (BatchN (None, 48, 48, 28)   112         conv2d_310[0][0]
# __________________________________________________________________________________________________
# add_155 (Add)                   (None, 48, 48, 28)   0           p_re_lu_159[0][0]
#                                                                  batch_normalization_296[0][0]
# __________________________________________________________________________________________________
# conv2d_311 (Conv2D)             (None, 48, 48, 28)   7084        add_155[0][0]
# __________________________________________________________________________________________________
# batch_normalization_297 (BatchN (None, 48, 48, 28)   112         conv2d_311[0][0]
# __________________________________________________________________________________________________
# p_re_lu_161 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_297[0][0]
# __________________________________________________________________________________________________
# conv2d_312 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_161[0][0]
# __________________________________________________________________________________________________
# batch_normalization_298 (BatchN (None, 48, 48, 28)   112         conv2d_312[0][0]
# __________________________________________________________________________________________________
# add_156 (Add)                   (None, 48, 48, 28)   0           add_155[0][0]
#                                                                  batch_normalization_298[0][0]
# __________________________________________________________________________________________________
# conv2d_313 (Conv2D)             (None, 48, 48, 28)   7084        add_156[0][0]
# __________________________________________________________________________________________________
# batch_normalization_299 (BatchN (None, 48, 48, 28)   112         conv2d_313[0][0]
# __________________________________________________________________________________________________
# p_re_lu_162 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_299[0][0]
# __________________________________________________________________________________________________
# conv2d_314 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_162[0][0]
# __________________________________________________________________________________________________
# batch_normalization_300 (BatchN (None, 48, 48, 28)   112         conv2d_314[0][0]
# __________________________________________________________________________________________________
# add_157 (Add)                   (None, 48, 48, 28)   0           add_156[0][0]
#                                                                  batch_normalization_300[0][0]
# __________________________________________________________________________________________________
# conv2d_315 (Conv2D)             (None, 48, 48, 28)   7084        add_157[0][0]
# __________________________________________________________________________________________________
# batch_normalization_301 (BatchN (None, 48, 48, 28)   112         conv2d_315[0][0]
# __________________________________________________________________________________________________
# p_re_lu_163 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_301[0][0]
# __________________________________________________________________________________________________
# conv2d_316 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_302 (BatchN (None, 48, 48, 28)   112         conv2d_316[0][0]
# __________________________________________________________________________________________________
# add_158 (Add)                   (None, 48, 48, 28)   0           add_157[0][0]
#                                                                  batch_normalization_302[0][0]
# __________________________________________________________________________________________________
# conv2d_317 (Conv2D)             (None, 48, 48, 28)   7084        add_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_303 (BatchN (None, 48, 48, 28)   112         conv2d_317[0][0]
# __________________________________________________________________________________________________
# p_re_lu_164 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_303[0][0]
# __________________________________________________________________________________________________
# conv2d_318 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_164[0][0]
# __________________________________________________________________________________________________
# batch_normalization_304 (BatchN (None, 48, 48, 28)   112         conv2d_318[0][0]
# __________________________________________________________________________________________________
# add_159 (Add)                   (None, 48, 48, 28)   0           add_158[0][0]
#                                                                  batch_normalization_304[0][0]
# __________________________________________________________________________________________________
# conv2d_319 (Conv2D)             (None, 48, 48, 28)   7084        add_159[0][0]
# __________________________________________________________________________________________________
# batch_normalization_305 (BatchN (None, 48, 48, 28)   112         conv2d_319[0][0]
# __________________________________________________________________________________________________
# p_re_lu_165 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_305[0][0]
# __________________________________________________________________________________________________
# conv2d_320 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_165[0][0]
# __________________________________________________________________________________________________
# batch_normalization_306 (BatchN (None, 48, 48, 28)   112         conv2d_320[0][0]
# __________________________________________________________________________________________________
# add_160 (Add)                   (None, 48, 48, 28)   0           add_159[0][0]
#                                                                  batch_normalization_306[0][0]
# __________________________________________________________________________________________________
# conv2d_321 (Conv2D)             (None, 48, 48, 28)   7084        add_160[0][0]
# __________________________________________________________________________________________________
# batch_normalization_307 (BatchN (None, 48, 48, 28)   112         conv2d_321[0][0]
# __________________________________________________________________________________________________
# p_re_lu_166 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_307[0][0]
# __________________________________________________________________________________________________
# conv2d_322 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_166[0][0]
# __________________________________________________________________________________________________
# batch_normalization_308 (BatchN (None, 48, 48, 28)   112         conv2d_322[0][0]
# __________________________________________________________________________________________________
# add_161 (Add)                   (None, 48, 48, 28)   0           add_160[0][0]
#                                                                  batch_normalization_308[0][0]
# __________________________________________________________________________________________________
# conv2d_323 (Conv2D)             (None, 48, 48, 28)   7084        add_161[0][0]
# __________________________________________________________________________________________________
# batch_normalization_309 (BatchN (None, 48, 48, 28)   112         conv2d_323[0][0]
# __________________________________________________________________________________________________
# p_re_lu_167 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_309[0][0]
# __________________________________________________________________________________________________
# conv2d_324 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_310 (BatchN (None, 48, 48, 28)   112         conv2d_324[0][0]
# __________________________________________________________________________________________________
# add_162 (Add)                   (None, 48, 48, 28)   0           add_161[0][0]
#                                                                  batch_normalization_310[0][0]
# __________________________________________________________________________________________________
# conv2d_325 (Conv2D)             (None, 48, 48, 28)   7084        add_162[0][0]
# __________________________________________________________________________________________________
# batch_normalization_311 (BatchN (None, 48, 48, 28)   112         conv2d_325[0][0]
# __________________________________________________________________________________________________
# p_re_lu_168 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_311[0][0]
# __________________________________________________________________________________________________
# conv2d_326 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_168[0][0]
# __________________________________________________________________________________________________
# batch_normalization_312 (BatchN (None, 48, 48, 28)   112         conv2d_326[0][0]
# __________________________________________________________________________________________________
# add_163 (Add)                   (None, 48, 48, 28)   0           add_162[0][0]
#                                                                  batch_normalization_312[0][0]
# __________________________________________________________________________________________________
# conv2d_327 (Conv2D)             (None, 48, 48, 28)   7084        add_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_313 (BatchN (None, 48, 48, 28)   112         conv2d_327[0][0]
# __________________________________________________________________________________________________
# p_re_lu_169 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_313[0][0]
# __________________________________________________________________________________________________
# conv2d_328 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_314 (BatchN (None, 48, 48, 28)   112         conv2d_328[0][0]
# __________________________________________________________________________________________________
# add_164 (Add)                   (None, 48, 48, 28)   0           add_163[0][0]
#                                                                  batch_normalization_314[0][0]
# __________________________________________________________________________________________________
# conv2d_329 (Conv2D)             (None, 48, 48, 28)   7084        add_164[0][0]
# __________________________________________________________________________________________________
# batch_normalization_315 (BatchN (None, 48, 48, 28)   112         conv2d_329[0][0]
# __________________________________________________________________________________________________
# add_165 (Add)                   (None, 48, 48, 28)   0           p_re_lu_159[0][0]
#                                                                  batch_normalization_315[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 96, 96, 7)    0           add_165[0][0]
# __________________________________________________________________________________________________
# p_re_lu_170 (PReLU)             (None, 96, 96, 7)    64512       lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_330 (Conv2D)             (None, 96, 96, 1)    8           p_re_lu_170[0][0]
# ==================================================================================================
# Total params: 47,461,604
# Trainable params: 47,436,908
# Non-trainable params: 24,696
# __________________________________________________________________________________________________
# strInfo: True
# permut: True
# se: True
# prog_loss: False
# Train on 44230 samples, validate on 11058 samples
# Epoch 1/50
#  - 469s - loss: 0.1011 - val_loss: 0.0882
# Epoch 2/50
#  - 448s - loss: 0.0811 - val_loss: 0.0812
# Epoch 3/50
#  - 448s - loss: 0.0742 - val_loss: 0.0785
# Epoch 4/50
#  - 450s - loss: 0.0692 - val_loss: 0.0757
# Epoch 5/50
#  - 453s - loss: 0.0649 - val_loss: 0.0755
# Epoch 6/50
#  - 453s - loss: 0.0611 - val_loss: 0.0733
# Epoch 7/50
#  - 453s - loss: 0.0579 - val_loss: 0.0735
# Epoch 8/50
#  - 453s - loss: 0.0549 - val_loss: 0.0727
# Epoch 9/50
#  - 454s - loss: 0.0524 - val_loss: 0.0729
# Epoch 10/50
#  - 454s - loss: 0.0500 - val_loss: 0.0717
# Epoch 11/50
#  - 454s - loss: 0.0480 - val_loss: 0.0720
# Epoch 12/50
#  - 454s - loss: 0.0461 - val_loss: 0.0720
# Epoch 13/50
#  - 449s - loss: 0.0444 - val_loss: 0.0720
# Epoch 14/50
#  - 448s - loss: 0.0429 - val_loss: 0.0717
# Epoch 15/50
#  - 448s - loss: 0.0414 - val_loss: 0.0713
# Epoch 16/50
#  - 448s - loss: 0.0402 - val_loss: 0.0717
# Epoch 17/50
#  - 448s - loss: 0.0390 - val_loss: 0.0712
# Epoch 18/50
#  - 448s - loss: 0.0379 - val_loss: 0.0711
# Epoch 19/50
#  - 448s - loss: 0.0369 - val_loss: 0.0710
# Epoch 20/50
#  - 448s - loss: 0.0360 - val_loss: 0.0711
# Epoch 21/50
#  - 448s - loss: 0.0351 - val_loss: 0.0708
# Epoch 22/50
#  - 448s - loss: 0.0343 - val_loss: 0.0707
# Epoch 23/50
#  - 448s - loss: 0.0336 - val_loss: 0.0704
# Epoch 24/50
#  - 448s - loss: 0.0329 - val_loss: 0.0703
# Epoch 25/50
#  - 448s - loss: 0.0322 - val_loss: 0.0700
# Epoch 26/50
#  - 448s - loss: 0.0316 - val_loss: 0.0706
# Epoch 27/50
#  - 449s - loss: 0.0310 - val_loss: 0.0704
# Epoch 28/50
#  - 448s - loss: 0.0305 - val_loss: 0.0707
# Epoch 29/50
#  - 448s - loss: 0.0300 - val_loss: 0.0706
# Epoch 30/50
#  - 448s - loss: 0.0295 - val_loss: 0.0701
# Epoch 31/50
#  - 448s - loss: 0.0290 - val_loss: 0.0702
# Epoch 32/50
#  - 448s - loss: 0.0286 - val_loss: 0.0705
# Epoch 33/50
#  - 448s - loss: 0.0282 - val_loss: 0.0700
# Epoch 34/50
#  - 448s - loss: 0.0278 - val_loss: 0.0701
# Epoch 35/50
#  - 449s - loss: 0.0274 - val_loss: 0.0698
# Epoch 36/50
#  - 448s - loss: 0.0271 - val_loss: 0.0700
# Epoch 37/50
#  - 448s - loss: 0.0267 - val_loss: 0.0697
# Epoch 38/50
#  - 448s - loss: 0.0264 - val_loss: 0.0707
# Epoch 39/50
#  - 449s - loss: 0.0261 - val_loss: 0.0697
# Epoch 40/50
#  - 448s - loss: 0.0258 - val_loss: 0.0704
# Epoch 41/50
#  - 448s - loss: 0.0255 - val_loss: 0.0699
# Epoch 42/50
#  - 448s - loss: 0.0252 - val_loss: 0.0696
# Epoch 43/50
#  - 449s - loss: 0.0250 - val_loss: 0.0700
# Epoch 44/50
#  - 448s - loss: 0.0247 - val_loss: 0.0705
# Epoch 45/50
#  - 448s - loss: 0.0245 - val_loss: 0.0700
# Epoch 46/50
#  - 448s - loss: 0.0243 - val_loss: 0.0693
# Epoch 47/50
#  - 448s - loss: 0.0240 - val_loss: 0.0695
# Epoch 48/50
#  - 449s - loss: 0.0238 - val_loss: 0.0700
# Epoch 49/50
#  - 448s - loss: 0.0236 - val_loss: 0.0697
# Epoch 50/50
#  - 448s - loss: 0.0234 - val_loss: 0.0698
# training Runtime: 381.37 Minutes
# 0.047165633551185096

# %%
n_ker = int(512-64) #128
n_ker_st = n_ker
batch_size = 16

strInfo = True
eval2 = run('disp')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           (None, 12, 12, 3, 3) 0
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 12, 12, 3, 11 3136        input_10[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 12, 12, 3, 22 226016      conv3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 12, 12, 3, 44 903616      conv3d_2[0][0]
# __________________________________________________________________________________________________
# average_pooling3d_1 (AveragePoo (None, 12, 12, 1, 44 0           conv3d_3[0][0]
# __________________________________________________________________________________________________
# input_7 (InputLayer)            (None, 12, 12, 1)    0
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 12, 12, 448,  0           average_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 12, 12, 448)  4480        input_7[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 12, 12, 448)  0           permute_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12, 12, 896)  0           conv2d_67[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 12, 12, 448)  3613120     concatenate_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_35 (PReLU)              (None, 12, 12, 448)  64512       conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 12, 12, 448)  1806784     p_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 12, 12, 448)  1792        conv2d_69[0][0]
# __________________________________________________________________________________________________
# p_re_lu_36 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 12, 12, 448)  1806784     p_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 12, 12, 448)  1792        conv2d_70[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 12, 12, 448)  0           p_re_lu_35[0][0]
#                                                                  batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 12, 12, 448)  1806784     add_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 12, 12, 448)  1792        conv2d_71[0][0]
# __________________________________________________________________________________________________
# p_re_lu_37 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 12, 12, 448)  1806784     p_re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 12, 12, 448)  1792        conv2d_72[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 12, 12, 448)  0           add_34[0][0]
#                                                                  batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 12, 12, 448)  1806784     add_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 12, 12, 448)  1792        conv2d_73[0][0]
# __________________________________________________________________________________________________
# p_re_lu_38 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 12, 12, 448)  1806784     p_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 12, 12, 448)  1792        conv2d_74[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 12, 12, 448)  0           add_35[0][0]
#                                                                  batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 12, 12, 448)  1806784     add_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 12, 12, 448)  1792        conv2d_75[0][0]
# __________________________________________________________________________________________________
# p_re_lu_39 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 12, 12, 448)  1806784     p_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 12, 12, 448)  1792        conv2d_76[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 12, 12, 448)  0           add_36[0][0]
#                                                                  batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 12, 12, 448)  1806784     add_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 12, 12, 448)  1792        conv2d_77[0][0]
# __________________________________________________________________________________________________
# p_re_lu_40 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 12, 12, 448)  1806784     p_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 12, 12, 448)  1792        conv2d_78[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 12, 12, 448)  0           add_37[0][0]
#                                                                  batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 12, 12, 448)  1806784     add_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 12, 12, 448)  1792        conv2d_79[0][0]
# __________________________________________________________________________________________________
# p_re_lu_41 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 12, 12, 448)  1806784     p_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 12, 12, 448)  1792        conv2d_80[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 12, 12, 448)  0           add_38[0][0]
#                                                                  batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 12, 12, 448)  1806784     add_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 12, 12, 448)  1792        conv2d_81[0][0]
# __________________________________________________________________________________________________
# p_re_lu_42 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 12, 12, 448)  1806784     p_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 12, 12, 448)  1792        conv2d_82[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 12, 12, 448)  0           add_39[0][0]
#                                                                  batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 12, 12, 448)  1806784     add_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 12, 12, 448)  1792        conv2d_83[0][0]
# __________________________________________________________________________________________________
# p_re_lu_43 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 12, 12, 448)  1806784     p_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 12, 12, 448)  1792        conv2d_84[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 12, 12, 448)  0           add_40[0][0]
#                                                                  batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 12, 12, 448)  1806784     add_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 12, 12, 448)  1792        conv2d_85[0][0]
# __________________________________________________________________________________________________
# p_re_lu_44 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 12, 12, 448)  1806784     p_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 12, 12, 448)  1792        conv2d_86[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 12, 12, 448)  0           add_41[0][0]
#                                                                  batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 12, 12, 448)  1806784     add_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 12, 12, 448)  1792        conv2d_87[0][0]
# __________________________________________________________________________________________________
# p_re_lu_45 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 12, 12, 448)  1806784     p_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 12, 12, 448)  1792        conv2d_88[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 12, 12, 448)  0           add_42[0][0]
#                                                                  batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 12, 12, 448)  1806784     add_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 12, 12, 448)  1792        conv2d_89[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 12, 12, 448)  0           p_re_lu_35[0][0]
#                                                                  batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 24, 24, 112)  0           add_44[0][0]
# __________________________________________________________________________________________________
# p_re_lu_46 (PReLU)              (None, 24, 24, 112)  64512       lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 24, 24, 112)  113008      p_re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 24, 24, 112)  448         conv2d_90[0][0]
# __________________________________________________________________________________________________
# p_re_lu_47 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 24, 24, 112)  113008      p_re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 24, 24, 112)  448         conv2d_91[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 24, 24, 112)  0           p_re_lu_46[0][0]
#                                                                  batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 24, 24, 112)  113008      add_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 24, 24, 112)  448         conv2d_92[0][0]
# __________________________________________________________________________________________________
# p_re_lu_48 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 24, 24, 112)  113008      p_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 24, 24, 112)  448         conv2d_93[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 24, 24, 112)  0           add_45[0][0]
#                                                                  batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 24, 24, 112)  113008      add_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 24, 24, 112)  448         conv2d_94[0][0]
# __________________________________________________________________________________________________
# p_re_lu_49 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 24, 24, 112)  113008      p_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 24, 24, 112)  448         conv2d_95[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 24, 24, 112)  0           add_46[0][0]
#                                                                  batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 24, 24, 112)  113008      add_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 24, 24, 112)  448         conv2d_96[0][0]
# __________________________________________________________________________________________________
# p_re_lu_50 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 24, 24, 112)  113008      p_re_lu_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 24, 24, 112)  448         conv2d_97[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 24, 24, 112)  0           add_47[0][0]
#                                                                  batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 24, 24, 112)  113008      add_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 24, 24, 112)  448         conv2d_98[0][0]
# __________________________________________________________________________________________________
# p_re_lu_51 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 24, 24, 112)  113008      p_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 24, 24, 112)  448         conv2d_99[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 24, 24, 112)  0           add_48[0][0]
#                                                                  batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 24, 24, 112)  113008      add_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 24, 24, 112)  448         conv2d_100[0][0]
# __________________________________________________________________________________________________
# p_re_lu_52 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 24, 24, 112)  448         conv2d_101[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 24, 24, 112)  0           add_49[0][0]
#                                                                  batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 24, 24, 112)  113008      add_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 24, 24, 112)  448         conv2d_102[0][0]
# __________________________________________________________________________________________________
# p_re_lu_53 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 24, 24, 112)  448         conv2d_103[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 24, 24, 112)  0           add_50[0][0]
#                                                                  batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 24, 24, 112)  113008      add_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 24, 24, 112)  448         conv2d_104[0][0]
# __________________________________________________________________________________________________
# p_re_lu_54 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 24, 24, 112)  448         conv2d_105[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, 24, 24, 112)  0           add_51[0][0]
#                                                                  batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 24, 24, 112)  113008      add_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 24, 24, 112)  448         conv2d_106[0][0]
# __________________________________________________________________________________________________
# p_re_lu_55 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 24, 24, 112)  448         conv2d_107[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, 24, 24, 112)  0           add_52[0][0]
#                                                                  batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 24, 24, 112)  113008      add_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 24, 24, 112)  448         conv2d_108[0][0]
# __________________________________________________________________________________________________
# p_re_lu_56 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 24, 24, 112)  448         conv2d_109[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, 24, 24, 112)  0           add_53[0][0]
#                                                                  batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 24, 24, 112)  113008      add_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 24, 24, 112)  448         conv2d_110[0][0]
# __________________________________________________________________________________________________
# add_55 (Add)                    (None, 24, 24, 112)  0           p_re_lu_46[0][0]
#                                                                  batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 48, 48, 28)   0           add_55[0][0]
# __________________________________________________________________________________________________
# p_re_lu_57 (PReLU)              (None, 48, 48, 28)   64512       lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 48, 48, 28)   112         conv2d_111[0][0]
# __________________________________________________________________________________________________
# p_re_lu_58 (PReLU)              (None, 48, 48, 28)   64512       batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 48, 48, 28)   112         conv2d_112[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, 48, 48, 28)   0           p_re_lu_57[0][0]
#                                                                  batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 48, 48, 28)   7084        add_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 48, 48, 28)   112         conv2d_113[0][0]
# __________________________________________________________________________________________________
# p_re_lu_59 (PReLU)              (None, 48, 48, 28)   64512       batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 48, 48, 28)   112         conv2d_114[0][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, 48, 48, 28)   0           add_56[0][0]
#                                                                  batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 48, 48, 28)   7084        add_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 48, 48, 28)   112         conv2d_115[0][0]
# __________________________________________________________________________________________________
# p_re_lu_60 (PReLU)              (None, 48, 48, 28)   64512       batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 48, 48, 28)   112         conv2d_116[0][0]
# __________________________________________________________________________________________________
# add_58 (Add)                    (None, 48, 48, 28)   0           add_57[0][0]
#                                                                  batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 48, 48, 28)   7084        add_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 48, 48, 28)   112         conv2d_117[0][0]
# __________________________________________________________________________________________________
# p_re_lu_61 (PReLU)              (None, 48, 48, 28)   64512       batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 48, 48, 28)   112         conv2d_118[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, 48, 48, 28)   0           add_58[0][0]
#                                                                  batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 48, 48, 28)   7084        add_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 48, 48, 28)   112         conv2d_119[0][0]
# __________________________________________________________________________________________________
# p_re_lu_62 (PReLU)              (None, 48, 48, 28)   64512       batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 48, 48, 28)   112         conv2d_120[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, 48, 48, 28)   0           add_59[0][0]
#                                                                  batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 48, 48, 28)   7084        add_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 48, 48, 28)   112         conv2d_121[0][0]
# __________________________________________________________________________________________________
# p_re_lu_63 (PReLU)              (None, 48, 48, 28)   64512       batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 48, 48, 28)   112         conv2d_122[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, 48, 48, 28)   0           add_60[0][0]
#                                                                  batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 48, 48, 28)   7084        add_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 48, 48, 28)   112         conv2d_123[0][0]
# __________________________________________________________________________________________________
# p_re_lu_64 (PReLU)              (None, 48, 48, 28)   64512       batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 48, 48, 28)   112         conv2d_124[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, 48, 48, 28)   0           add_61[0][0]
#                                                                  batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 48, 48, 28)   7084        add_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 48, 48, 28)   112         conv2d_125[0][0]
# __________________________________________________________________________________________________
# p_re_lu_65 (PReLU)              (None, 48, 48, 28)   64512       batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 48, 48, 28)   112         conv2d_126[0][0]
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, 48, 48, 28)   0           add_62[0][0]
#                                                                  batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 48, 48, 28)   7084        add_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 48, 48, 28)   112         conv2d_127[0][0]
# __________________________________________________________________________________________________
# p_re_lu_66 (PReLU)              (None, 48, 48, 28)   64512       batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 48, 48, 28)   112         conv2d_128[0][0]
# __________________________________________________________________________________________________
# add_64 (Add)                    (None, 48, 48, 28)   0           add_63[0][0]
#                                                                  batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 48, 48, 28)   7084        add_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 48, 48, 28)   112         conv2d_129[0][0]
# __________________________________________________________________________________________________
# p_re_lu_67 (PReLU)              (None, 48, 48, 28)   64512       batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 48, 48, 28)   112         conv2d_130[0][0]
# __________________________________________________________________________________________________
# add_65 (Add)                    (None, 48, 48, 28)   0           add_64[0][0]
#                                                                  batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 48, 48, 28)   7084        add_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 48, 48, 28)   112         conv2d_131[0][0]
# __________________________________________________________________________________________________
# add_66 (Add)                    (None, 48, 48, 28)   0           p_re_lu_57[0][0]
#                                                                  batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 96, 96, 7)    0           add_66[0][0]
# __________________________________________________________________________________________________
# p_re_lu_68 (PReLU)              (None, 96, 96, 7)    64512       lambda_6[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 96, 96, 1)    8           p_re_lu_68[0][0]
# ==================================================================================================
# Total params: 47,457,572
# Trainable params: 47,432,876
# Non-trainable params: 24,696
# __________________________________________________________________________________________________
# strInfo: True
# permut: True
# se: False
# prog_loss: False
# Train on 44230 samples, validate on 11058 samples
# Epoch 1/50
#  - 450s - loss: 0.1010 - val_loss: 0.0894
# Epoch 2/50
#  - 428s - loss: 0.0816 - val_loss: 0.0819
# Epoch 3/50
#  - 428s - loss: 0.0753 - val_loss: 0.0802
# Epoch 4/50
#  - 443s - loss: 0.0704 - val_loss: 0.0774
# Epoch 5/50
#  - 428s - loss: 0.0662 - val_loss: 0.0764
# Epoch 6/50
#  - 450s - loss: 0.0625 - val_loss: 0.0766
# Epoch 7/50
#  - 437s - loss: 0.0592 - val_loss: 0.0747
# Epoch 8/50
#  - 429s - loss: 0.0563 - val_loss: 0.0741
# Epoch 9/50
#  - 430s - loss: 0.0536 - val_loss: 0.0733
# Epoch 10/50
#  - 429s - loss: 0.0512 - val_loss: 0.0736
# Epoch 11/50
#  - 428s - loss: 0.0490 - val_loss: 0.0730
# Epoch 12/50
#  - 428s - loss: 0.0470 - val_loss: 0.0732
# Epoch 13/50
#  - 428s - loss: 0.0453 - val_loss: 0.0733
# Epoch 14/50
#  - 428s - loss: 0.0436 - val_loss: 0.0730
# Epoch 15/50
#  - 455s - loss: 0.0422 - val_loss: 0.0726
# Epoch 16/50
#  - 430s - loss: 0.0408 - val_loss: 0.0734
# Epoch 17/50
#  - 431s - loss: 0.0396 - val_loss: 0.0725
# Epoch 18/50
#  - 439s - loss: 0.0385 - val_loss: 0.0722
# Epoch 19/50
#  - 426s - loss: 0.0374 - val_loss: 0.0733
# Epoch 20/50
#  - 429s - loss: 0.0365 - val_loss: 0.0727
# Epoch 21/50
#  - 429s - loss: 0.0356 - val_loss: 0.0721
# Epoch 22/50
#  - 428s - loss: 0.0347 - val_loss: 0.0719
# Epoch 23/50
#  - 428s - loss: 0.0340 - val_loss: 0.0723
# Epoch 24/50
#  - 434s - loss: 0.0333 - val_loss: 0.0724
# Epoch 25/50
#  - 428s - loss: 0.0326 - val_loss: 0.0719
# Epoch 26/50
#  - 428s - loss: 0.0319 - val_loss: 0.0719
# Epoch 27/50
#  - 446s - loss: 0.0313 - val_loss: 0.0720
# Epoch 28/50
#  - 439s - loss: 0.0308 - val_loss: 0.0724
# Epoch 29/50
#  - 432s - loss: 0.0303 - val_loss: 0.0725
# Epoch 30/50
#  - 439s - loss: 0.0297 - val_loss: 0.0717
# Epoch 31/50
#  - 438s - loss: 0.0293 - val_loss: 0.0722
# Epoch 32/50
#  - 435s - loss: 0.0288 - val_loss: 0.0719
# Epoch 33/50
#  - 435s - loss: 0.0284 - val_loss: 0.0716
# Epoch 34/50
#  - 436s - loss: 0.0280 - val_loss: 0.0720
# Epoch 35/50
#  - 444s - loss: 0.0276 - val_loss: 0.0723
# Epoch 36/50
#  - 431s - loss: 0.0273 - val_loss: 0.0723
# Epoch 37/50
#  - 429s - loss: 0.0269 - val_loss: 0.0716
# Epoch 38/50
#  - 428s - loss: 0.0266 - val_loss: 0.0716
# Epoch 39/50
#  - 432s - loss: 0.0262 - val_loss: 0.0715
# Epoch 40/50
#  - 434s - loss: 0.0259 - val_loss: 0.0715
# Epoch 41/50
#  - 442s - loss: 0.0257 - val_loss: 0.0715
# Epoch 42/50
#  - 435s - loss: 0.0254 - val_loss: 0.0716
# Epoch 43/50
#  - 432s - loss: 0.0251 - val_loss: 0.0717
# Epoch 44/50
#  - 429s - loss: 0.0249 - val_loss: 0.0715
# Epoch 45/50
#  - 429s - loss: 0.0246 - val_loss: 0.0715
# Epoch 46/50
#  - 430s - loss: 0.0244 - val_loss: 0.0717
# Epoch 47/50
#  - 429s - loss: 0.0242 - val_loss: 0.0716
# Epoch 48/50
#  - 428s - loss: 0.0239 - val_loss: 0.0715
# Epoch 49/50
#  - 428s - loss: 0.0237 - val_loss: 0.0714
# Epoch 50/50
#  - 428s - loss: 0.0235 - val_loss: 0.0720
# training Runtime: 364.61 Minutes
# 0.04842394548630904

# %%
strInfo = True
seInfo = True
# m_ker_st = 64
eval3 = run('disp_se')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_16 (InputLayer)           (None, 12, 12, 3, 4) 0
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 12, 12, 3, 11 4144        input_16[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 12, 12, 3, 22 226016      conv3d_4[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 12, 12, 3, 44 903616      conv3d_5[0][0]
# __________________________________________________________________________________________________
# input_13 (InputLayer)           (None, 12, 12, 1)    0
# __________________________________________________________________________________________________
# input_18 (InputLayer)           (None, 12, 12, 1)    0
# __________________________________________________________________________________________________
# average_pooling3d_2 (AveragePoo (None, 12, 12, 1, 44 0           conv3d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 12, 12, 2)    0           input_13[0][0]
#                                                                  input_18[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 12, 12, 448,  0           average_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 12, 12, 448)  8512        concatenate_2[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 12, 12, 448)  0           permute_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 12, 12, 896)  0           conv2d_133[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 12, 12, 448)  3613120     concatenate_3[0][0]
# __________________________________________________________________________________________________
# p_re_lu_69 (PReLU)              (None, 12, 12, 448)  64512       conv2d_134[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 12, 12, 448)  1792        conv2d_135[0][0]
# __________________________________________________________________________________________________
# p_re_lu_70 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 12, 12, 448)  1792        conv2d_136[0][0]
# __________________________________________________________________________________________________
# add_67 (Add)                    (None, 12, 12, 448)  0           p_re_lu_69[0][0]
#                                                                  batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 12, 12, 448)  1806784     add_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 12, 12, 448)  1792        conv2d_137[0][0]
# __________________________________________________________________________________________________
# p_re_lu_71 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 12, 12, 448)  1792        conv2d_138[0][0]
# __________________________________________________________________________________________________
# add_68 (Add)                    (None, 12, 12, 448)  0           add_67[0][0]
#                                                                  batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 12, 12, 448)  1806784     add_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 12, 12, 448)  1792        conv2d_139[0][0]
# __________________________________________________________________________________________________
# p_re_lu_72 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 12, 12, 448)  1792        conv2d_140[0][0]
# __________________________________________________________________________________________________
# add_69 (Add)                    (None, 12, 12, 448)  0           add_68[0][0]
#                                                                  batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 12, 12, 448)  1806784     add_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 12, 12, 448)  1792        conv2d_141[0][0]
# __________________________________________________________________________________________________
# p_re_lu_73 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 12, 12, 448)  1792        conv2d_142[0][0]
# __________________________________________________________________________________________________
# add_70 (Add)                    (None, 12, 12, 448)  0           add_69[0][0]
#                                                                  batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 12, 12, 448)  1806784     add_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 12, 12, 448)  1792        conv2d_143[0][0]
# __________________________________________________________________________________________________
# p_re_lu_74 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 12, 12, 448)  1792        conv2d_144[0][0]
# __________________________________________________________________________________________________
# add_71 (Add)                    (None, 12, 12, 448)  0           add_70[0][0]
#                                                                  batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 12, 12, 448)  1806784     add_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 12, 12, 448)  1792        conv2d_145[0][0]
# __________________________________________________________________________________________________
# p_re_lu_75 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 12, 12, 448)  1792        conv2d_146[0][0]
# __________________________________________________________________________________________________
# add_72 (Add)                    (None, 12, 12, 448)  0           add_71[0][0]
#                                                                  batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 12, 12, 448)  1806784     add_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 12, 12, 448)  1792        conv2d_147[0][0]
# __________________________________________________________________________________________________
# p_re_lu_76 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 12, 12, 448)  1792        conv2d_148[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, 12, 12, 448)  0           add_72[0][0]
#                                                                  batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 12, 12, 448)  1806784     add_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 12, 12, 448)  1792        conv2d_149[0][0]
# __________________________________________________________________________________________________
# p_re_lu_77 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 12, 12, 448)  1792        conv2d_150[0][0]
# __________________________________________________________________________________________________
# add_74 (Add)                    (None, 12, 12, 448)  0           add_73[0][0]
#                                                                  batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 12, 12, 448)  1806784     add_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 12, 12, 448)  1792        conv2d_151[0][0]
# __________________________________________________________________________________________________
# p_re_lu_78 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 12, 12, 448)  1792        conv2d_152[0][0]
# __________________________________________________________________________________________________
# add_75 (Add)                    (None, 12, 12, 448)  0           add_74[0][0]
#                                                                  batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 12, 12, 448)  1806784     add_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 12, 12, 448)  1792        conv2d_153[0][0]
# __________________________________________________________________________________________________
# p_re_lu_79 (PReLU)              (None, 12, 12, 448)  64512       batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 12, 12, 448)  1792        conv2d_154[0][0]
# __________________________________________________________________________________________________
# add_76 (Add)                    (None, 12, 12, 448)  0           add_75[0][0]
#                                                                  batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 12, 12, 448)  1806784     add_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 12, 12, 448)  1792        conv2d_155[0][0]
# __________________________________________________________________________________________________
# add_77 (Add)                    (None, 12, 12, 448)  0           p_re_lu_69[0][0]
#                                                                  batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 24, 24, 112)  0           add_77[0][0]
# __________________________________________________________________________________________________
# p_re_lu_80 (PReLU)              (None, 24, 24, 112)  64512       lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 24, 24, 112)  448         conv2d_156[0][0]
# __________________________________________________________________________________________________
# p_re_lu_81 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 24, 24, 112)  448         conv2d_157[0][0]
# __________________________________________________________________________________________________
# add_78 (Add)                    (None, 24, 24, 112)  0           p_re_lu_80[0][0]
#                                                                  batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 24, 24, 112)  113008      add_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 24, 24, 112)  448         conv2d_158[0][0]
# __________________________________________________________________________________________________
# p_re_lu_82 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_151 (BatchN (None, 24, 24, 112)  448         conv2d_159[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 24, 24, 112)  0           add_78[0][0]
#                                                                  batch_normalization_151[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 24, 24, 112)  113008      add_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_152 (BatchN (None, 24, 24, 112)  448         conv2d_160[0][0]
# __________________________________________________________________________________________________
# p_re_lu_83 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_152[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_153 (BatchN (None, 24, 24, 112)  448         conv2d_161[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 24, 24, 112)  0           add_79[0][0]
#                                                                  batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 24, 24, 112)  113008      add_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 24, 24, 112)  448         conv2d_162[0][0]
# __________________________________________________________________________________________________
# p_re_lu_84 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 24, 24, 112)  448         conv2d_163[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, 24, 24, 112)  0           add_80[0][0]
#                                                                  batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 24, 24, 112)  113008      add_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_156 (BatchN (None, 24, 24, 112)  448         conv2d_164[0][0]
# __________________________________________________________________________________________________
# p_re_lu_85 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_157 (BatchN (None, 24, 24, 112)  448         conv2d_165[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, 24, 24, 112)  0           add_81[0][0]
#                                                                  batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 24, 24, 112)  113008      add_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 24, 24, 112)  448         conv2d_166[0][0]
# __________________________________________________________________________________________________
# p_re_lu_86 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 24, 24, 112)  448         conv2d_167[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, 24, 24, 112)  0           add_82[0][0]
#                                                                  batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 24, 24, 112)  113008      add_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_160 (BatchN (None, 24, 24, 112)  448         conv2d_168[0][0]
# __________________________________________________________________________________________________
# p_re_lu_87 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_160[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_161 (BatchN (None, 24, 24, 112)  448         conv2d_169[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, 24, 24, 112)  0           add_83[0][0]
#                                                                  batch_normalization_161[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 24, 24, 112)  113008      add_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_162 (BatchN (None, 24, 24, 112)  448         conv2d_170[0][0]
# __________________________________________________________________________________________________
# p_re_lu_88 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_163 (BatchN (None, 24, 24, 112)  448         conv2d_171[0][0]
# __________________________________________________________________________________________________
# add_85 (Add)                    (None, 24, 24, 112)  0           add_84[0][0]
#                                                                  batch_normalization_163[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 24, 24, 112)  113008      add_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_164 (BatchN (None, 24, 24, 112)  448         conv2d_172[0][0]
# __________________________________________________________________________________________________
# p_re_lu_89 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_164[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_165 (BatchN (None, 24, 24, 112)  448         conv2d_173[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, 24, 24, 112)  0           add_85[0][0]
#                                                                  batch_normalization_165[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 24, 24, 112)  113008      add_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_166 (BatchN (None, 24, 24, 112)  448         conv2d_174[0][0]
# __________________________________________________________________________________________________
# p_re_lu_90 (PReLU)              (None, 24, 24, 112)  64512       batch_normalization_166[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_167 (BatchN (None, 24, 24, 112)  448         conv2d_175[0][0]
# __________________________________________________________________________________________________
# add_87 (Add)                    (None, 24, 24, 112)  0           add_86[0][0]
#                                                                  batch_normalization_167[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 24, 24, 112)  113008      add_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_168 (BatchN (None, 24, 24, 112)  448         conv2d_176[0][0]
# __________________________________________________________________________________________________
# add_88 (Add)                    (None, 24, 24, 112)  0           p_re_lu_80[0][0]
#                                                                  batch_normalization_168[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 48, 48, 28)   0           add_88[0][0]
# __________________________________________________________________________________________________
# p_re_lu_91 (PReLU)              (None, 48, 48, 28)   64512       lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_169 (BatchN (None, 48, 48, 28)   112         conv2d_177[0][0]
# __________________________________________________________________________________________________
# p_re_lu_92 (PReLU)              (None, 48, 48, 28)   64512       batch_normalization_169[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_170 (BatchN (None, 48, 48, 28)   112         conv2d_178[0][0]
# __________________________________________________________________________________________________
# add_89 (Add)                    (None, 48, 48, 28)   0           p_re_lu_91[0][0]
#                                                                  batch_normalization_170[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 48, 48, 28)   7084        add_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_171 (BatchN (None, 48, 48, 28)   112         conv2d_179[0][0]
# __________________________________________________________________________________________________
# p_re_lu_93 (PReLU)              (None, 48, 48, 28)   64512       batch_normalization_171[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_172 (BatchN (None, 48, 48, 28)   112         conv2d_180[0][0]
# __________________________________________________________________________________________________
# add_90 (Add)                    (None, 48, 48, 28)   0           add_89[0][0]
#                                                                  batch_normalization_172[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 48, 48, 28)   7084        add_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_173 (BatchN (None, 48, 48, 28)   112         conv2d_181[0][0]
# __________________________________________________________________________________________________
# p_re_lu_94 (PReLU)              (None, 48, 48, 28)   64512       batch_normalization_173[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_174 (BatchN (None, 48, 48, 28)   112         conv2d_182[0][0]
# __________________________________________________________________________________________________
# add_91 (Add)                    (None, 48, 48, 28)   0           add_90[0][0]
#                                                                  batch_normalization_174[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 48, 48, 28)   7084        add_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_175 (BatchN (None, 48, 48, 28)   112         conv2d_183[0][0]
# __________________________________________________________________________________________________
# p_re_lu_95 (PReLU)              (None, 48, 48, 28)   64512       batch_normalization_175[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_176 (BatchN (None, 48, 48, 28)   112         conv2d_184[0][0]
# __________________________________________________________________________________________________
# add_92 (Add)                    (None, 48, 48, 28)   0           add_91[0][0]
#                                                                  batch_normalization_176[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 48, 48, 28)   7084        add_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_177 (BatchN (None, 48, 48, 28)   112         conv2d_185[0][0]
# __________________________________________________________________________________________________
# p_re_lu_96 (PReLU)              (None, 48, 48, 28)   64512       batch_normalization_177[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_178 (BatchN (None, 48, 48, 28)   112         conv2d_186[0][0]
# __________________________________________________________________________________________________
# add_93 (Add)                    (None, 48, 48, 28)   0           add_92[0][0]
#                                                                  batch_normalization_178[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 48, 48, 28)   7084        add_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_179 (BatchN (None, 48, 48, 28)   112         conv2d_187[0][0]
# __________________________________________________________________________________________________
# p_re_lu_97 (PReLU)              (None, 48, 48, 28)   64512       batch_normalization_179[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_180 (BatchN (None, 48, 48, 28)   112         conv2d_188[0][0]
# __________________________________________________________________________________________________
# add_94 (Add)                    (None, 48, 48, 28)   0           add_93[0][0]
#                                                                  batch_normalization_180[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 48, 48, 28)   7084        add_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181 (BatchN (None, 48, 48, 28)   112         conv2d_189[0][0]
# __________________________________________________________________________________________________
# p_re_lu_98 (PReLU)              (None, 48, 48, 28)   64512       batch_normalization_181[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182 (BatchN (None, 48, 48, 28)   112         conv2d_190[0][0]
# __________________________________________________________________________________________________
# add_95 (Add)                    (None, 48, 48, 28)   0           add_94[0][0]
#                                                                  batch_normalization_182[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 48, 48, 28)   7084        add_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, 48, 48, 28)   112         conv2d_191[0][0]
# __________________________________________________________________________________________________
# p_re_lu_99 (PReLU)              (None, 48, 48, 28)   64512       batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_184 (BatchN (None, 48, 48, 28)   112         conv2d_192[0][0]
# __________________________________________________________________________________________________
# add_96 (Add)                    (None, 48, 48, 28)   0           add_95[0][0]
#                                                                  batch_normalization_184[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 48, 48, 28)   7084        add_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185 (BatchN (None, 48, 48, 28)   112         conv2d_193[0][0]
# __________________________________________________________________________________________________
# p_re_lu_100 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_185[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 48, 48, 28)   112         conv2d_194[0][0]
# __________________________________________________________________________________________________
# add_97 (Add)                    (None, 48, 48, 28)   0           add_96[0][0]
#                                                                  batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 48, 48, 28)   7084        add_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 48, 48, 28)   112         conv2d_195[0][0]
# __________________________________________________________________________________________________
# p_re_lu_101 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 48, 48, 28)   112         conv2d_196[0][0]
# __________________________________________________________________________________________________
# add_98 (Add)                    (None, 48, 48, 28)   0           add_97[0][0]
#                                                                  batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 48, 48, 28)   7084        add_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 48, 48, 28)   112         conv2d_197[0][0]
# __________________________________________________________________________________________________
# add_99 (Add)                    (None, 48, 48, 28)   0           p_re_lu_91[0][0]
#                                                                  batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 96, 96, 7)    0           add_99[0][0]
# __________________________________________________________________________________________________
# p_re_lu_102 (PReLU)             (None, 96, 96, 7)    64512       lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 96, 96, 1)    8           p_re_lu_102[0][0]
# ==================================================================================================
# Total params: 47,462,612
# Trainable params: 47,437,916
# Non-trainable params: 24,696
# __________________________________________________________________________________________________
# strInfo: True
# permut: True
# se: True
# prog_loss: False
# Train on 44230 samples, validate on 11058 samples
# Epoch 1/50
#  - 451s - loss: 0.0994 - val_loss: 0.0879
# Epoch 2/50
#  - 434s - loss: 0.0799 - val_loss: 0.0823
# Epoch 3/50
#  - 445s - loss: 0.0733 - val_loss: 0.0781
# Epoch 4/50
#  - 434s - loss: 0.0683 - val_loss: 0.0762
# Epoch 5/50
#  - 456s - loss: 0.0642 - val_loss: 0.0744
# Epoch 6/50
#  - 483s - loss: 0.0606 - val_loss: 0.0746
# Epoch 7/50
#  - 488s - loss: 0.0574 - val_loss: 0.0733
# Epoch 8/50
#  - 529s - loss: 0.0546 - val_loss: 0.0728
# Epoch 9/50
#  - 464s - loss: 0.0520 - val_loss: 0.0726
# Epoch 10/50
#  - 459s - loss: 0.0496 - val_loss: 0.0719
# Epoch 11/50
#  - 478s - loss: 0.0474 - val_loss: 0.0716
# Epoch 12/50
#  - 497s - loss: 0.0455 - val_loss: 0.0718
# Epoch 13/50
#  - 482s - loss: 0.0437 - val_loss: 0.0709
# Epoch 14/50
#  - 453s - loss: 0.0421 - val_loss: 0.0717
# Epoch 15/50
#  - 439s - loss: 0.0406 - val_loss: 0.0713
# Epoch 16/50
#  - 443s - loss: 0.0393 - val_loss: 0.0714
# Epoch 17/50
#  - 439s - loss: 0.0380 - val_loss: 0.0705
# Epoch 18/50
#  - 437s - loss: 0.0369 - val_loss: 0.0705
# Epoch 19/50
#  - 437s - loss: 0.0358 - val_loss: 0.0714
# Epoch 20/50
#  - 437s - loss: 0.0349 - val_loss: 0.0708
# Epoch 21/50
#  - 437s - loss: 0.0340 - val_loss: 0.0704
# Epoch 22/50
#  - 440s - loss: 0.0331 - val_loss: 0.0705
# Epoch 23/50
#  - 447s - loss: 0.0323 - val_loss: 0.0704
# Epoch 24/50
#  - 444s - loss: 0.0316 - val_loss: 0.0705
# Epoch 25/50
#  - 437s - loss: 0.0309 - val_loss: 0.0704
# Epoch 26/50
#  - 437s - loss: 0.0303 - val_loss: 0.0701
# Epoch 27/50
#  - 436s - loss: 0.0297 - val_loss: 0.0701
# Epoch 28/50
#  - 436s - loss: 0.0292 - val_loss: 0.0703
# Epoch 29/50
#  - 436s - loss: 0.0286 - val_loss: 0.0701
# Epoch 30/50
#  - 436s - loss: 0.0282 - val_loss: 0.0695
# Epoch 31/50
#  - 457s - loss: 0.0277 - val_loss: 0.0703
# Epoch 32/50
#  - 467s - loss: 0.0272 - val_loss: 0.0701
# Epoch 33/50
#  - 444s - loss: 0.0268 - val_loss: 0.0696
# Epoch 34/50
#  - 440s - loss: 0.0264 - val_loss: 0.0697
# Epoch 35/50
#  - 440s - loss: 0.0260 - val_loss: 0.0697
# Epoch 36/50
#  - 439s - loss: 0.0257 - val_loss: 0.0696
# Epoch 37/50
#  - 439s - loss: 0.0254 - val_loss: 0.0701
# Epoch 38/50
#  - 439s - loss: 0.0250 - val_loss: 0.0699
# Epoch 39/50
#  - 448s - loss: 0.0247 - val_loss: 0.0697
# Epoch 40/50
#  - 438s - loss: 0.0244 - val_loss: 0.0695
# Epoch 41/50
#  - 440s - loss: 0.0242 - val_loss: 0.0700
# Epoch 42/50
#  - 435s - loss: 0.0239 - val_loss: 0.0694
# Epoch 43/50
#  - 435s - loss: 0.0236 - val_loss: 0.0693
# Epoch 44/50
#  - 434s - loss: 0.0234 - val_loss: 0.0696
# Epoch 45/50
#  - 434s - loss: 0.0231 - val_loss: 0.0698
# Epoch 46/50
#  - 434s - loss: 0.0229 - val_loss: 0.0694
# Epoch 47/50
#  - 434s - loss: 0.0227 - val_loss: 0.0699
# Epoch 48/50
#  - 434s - loss: 0.0225 - val_loss: 0.0700
# Epoch 49/50
#  - 436s - loss: 0.0223 - val_loss: 0.0700
# Epoch 50/50
#  - 439s - loss: 0.0221 - val_loss: 0.0692
# training Runtime: 377.25 Minutes
# 0.04661553580018263

# %%
rcs=False
eval4 = run('disp_se_no_rcs')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_22 (InputLayer)           (None, 12, 12, 3, 3) 0
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 12, 12, 3, 11 3136        input_22[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 12, 12, 3, 22 226016      conv3d_7[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 12, 12, 3, 44 903616      conv3d_8[0][0]
# __________________________________________________________________________________________________
# input_19 (InputLayer)           (None, 12, 12, 1)    0
# __________________________________________________________________________________________________
# input_24 (InputLayer)           (None, 12, 12, 1)    0
# __________________________________________________________________________________________________
# average_pooling3d_3 (AveragePoo (None, 12, 12, 1, 44 0           conv3d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 12, 12, 2)    0           input_19[0][0]
#                                                                  input_24[0][0]
# __________________________________________________________________________________________________
# permute_3 (Permute)             (None, 12, 12, 448,  0           average_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 12, 12, 448)  8512        concatenate_4[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 12, 12, 448)  0           permute_3[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 12, 12, 896)  0           conv2d_199[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 12, 12, 448)  3613120     concatenate_5[0][0]
# __________________________________________________________________________________________________
# p_re_lu_103 (PReLU)             (None, 12, 12, 448)  64512       conv2d_200[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 12, 12, 448)  1792        conv2d_201[0][0]
# __________________________________________________________________________________________________
# p_re_lu_104 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 12, 12, 448)  1792        conv2d_202[0][0]
# __________________________________________________________________________________________________
# add_100 (Add)                   (None, 12, 12, 448)  0           p_re_lu_103[0][0]
#                                                                  batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, 12, 12, 448)  1806784     add_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 12, 12, 448)  1792        conv2d_203[0][0]
# __________________________________________________________________________________________________
# p_re_lu_105 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# conv2d_204 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 12, 12, 448)  1792        conv2d_204[0][0]
# __________________________________________________________________________________________________
# add_101 (Add)                   (None, 12, 12, 448)  0           add_100[0][0]
#                                                                  batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# conv2d_205 (Conv2D)             (None, 12, 12, 448)  1806784     add_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 12, 12, 448)  1792        conv2d_205[0][0]
# __________________________________________________________________________________________________
# p_re_lu_106 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# conv2d_206 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 12, 12, 448)  1792        conv2d_206[0][0]
# __________________________________________________________________________________________________
# add_102 (Add)                   (None, 12, 12, 448)  0           add_101[0][0]
#                                                                  batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# conv2d_207 (Conv2D)             (None, 12, 12, 448)  1806784     add_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 12, 12, 448)  1792        conv2d_207[0][0]
# __________________________________________________________________________________________________
# p_re_lu_107 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# conv2d_208 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 12, 12, 448)  1792        conv2d_208[0][0]
# __________________________________________________________________________________________________
# add_103 (Add)                   (None, 12, 12, 448)  0           add_102[0][0]
#                                                                  batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# conv2d_209 (Conv2D)             (None, 12, 12, 448)  1806784     add_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 12, 12, 448)  1792        conv2d_209[0][0]
# __________________________________________________________________________________________________
# p_re_lu_108 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 12, 12, 448)  1792        conv2d_210[0][0]
# __________________________________________________________________________________________________
# add_104 (Add)                   (None, 12, 12, 448)  0           add_103[0][0]
#                                                                  batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 12, 12, 448)  1806784     add_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 12, 12, 448)  1792        conv2d_211[0][0]
# __________________________________________________________________________________________________
# p_re_lu_109 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# conv2d_212 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 12, 12, 448)  1792        conv2d_212[0][0]
# __________________________________________________________________________________________________
# add_105 (Add)                   (None, 12, 12, 448)  0           add_104[0][0]
#                                                                  batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 12, 12, 448)  1806784     add_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 12, 12, 448)  1792        conv2d_213[0][0]
# __________________________________________________________________________________________________
# p_re_lu_110 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# conv2d_214 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_203 (BatchN (None, 12, 12, 448)  1792        conv2d_214[0][0]
# __________________________________________________________________________________________________
# add_106 (Add)                   (None, 12, 12, 448)  0           add_105[0][0]
#                                                                  batch_normalization_203[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 12, 12, 448)  1806784     add_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_204 (BatchN (None, 12, 12, 448)  1792        conv2d_215[0][0]
# __________________________________________________________________________________________________
# p_re_lu_111 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_204[0][0]
# __________________________________________________________________________________________________
# conv2d_216 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_205 (BatchN (None, 12, 12, 448)  1792        conv2d_216[0][0]
# __________________________________________________________________________________________________
# add_107 (Add)                   (None, 12, 12, 448)  0           add_106[0][0]
#                                                                  batch_normalization_205[0][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 12, 12, 448)  1806784     add_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_206 (BatchN (None, 12, 12, 448)  1792        conv2d_217[0][0]
# __________________________________________________________________________________________________
# p_re_lu_112 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_206[0][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_207 (BatchN (None, 12, 12, 448)  1792        conv2d_218[0][0]
# __________________________________________________________________________________________________
# add_108 (Add)                   (None, 12, 12, 448)  0           add_107[0][0]
#                                                                  batch_normalization_207[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 12, 12, 448)  1806784     add_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_208 (BatchN (None, 12, 12, 448)  1792        conv2d_219[0][0]
# __________________________________________________________________________________________________
# p_re_lu_113 (PReLU)             (None, 12, 12, 448)  64512       batch_normalization_208[0][0]
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, 12, 12, 448)  1806784     p_re_lu_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_209 (BatchN (None, 12, 12, 448)  1792        conv2d_220[0][0]
# __________________________________________________________________________________________________
# add_109 (Add)                   (None, 12, 12, 448)  0           add_108[0][0]
#                                                                  batch_normalization_209[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 12, 12, 448)  1806784     add_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_210 (BatchN (None, 12, 12, 448)  1792        conv2d_221[0][0]
# __________________________________________________________________________________________________
# add_110 (Add)                   (None, 12, 12, 448)  0           p_re_lu_103[0][0]
#                                                                  batch_normalization_210[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 24, 24, 112)  0           add_110[0][0]
# __________________________________________________________________________________________________
# p_re_lu_114 (PReLU)             (None, 24, 24, 112)  64512       lambda_10[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_211 (BatchN (None, 24, 24, 112)  448         conv2d_222[0][0]
# __________________________________________________________________________________________________
# p_re_lu_115 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_211[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_212 (BatchN (None, 24, 24, 112)  448         conv2d_223[0][0]
# __________________________________________________________________________________________________
# add_111 (Add)                   (None, 24, 24, 112)  0           p_re_lu_114[0][0]
#                                                                  batch_normalization_212[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 24, 24, 112)  113008      add_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_213 (BatchN (None, 24, 24, 112)  448         conv2d_224[0][0]
# __________________________________________________________________________________________________
# p_re_lu_116 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_213[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_214 (BatchN (None, 24, 24, 112)  448         conv2d_225[0][0]
# __________________________________________________________________________________________________
# add_112 (Add)                   (None, 24, 24, 112)  0           add_111[0][0]
#                                                                  batch_normalization_214[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 24, 24, 112)  113008      add_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_215 (BatchN (None, 24, 24, 112)  448         conv2d_226[0][0]
# __________________________________________________________________________________________________
# p_re_lu_117 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_215[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_216 (BatchN (None, 24, 24, 112)  448         conv2d_227[0][0]
# __________________________________________________________________________________________________
# add_113 (Add)                   (None, 24, 24, 112)  0           add_112[0][0]
#                                                                  batch_normalization_216[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 24, 24, 112)  113008      add_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_217 (BatchN (None, 24, 24, 112)  448         conv2d_228[0][0]
# __________________________________________________________________________________________________
# p_re_lu_118 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_217[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_218 (BatchN (None, 24, 24, 112)  448         conv2d_229[0][0]
# __________________________________________________________________________________________________
# add_114 (Add)                   (None, 24, 24, 112)  0           add_113[0][0]
#                                                                  batch_normalization_218[0][0]
# __________________________________________________________________________________________________
# conv2d_230 (Conv2D)             (None, 24, 24, 112)  113008      add_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_219 (BatchN (None, 24, 24, 112)  448         conv2d_230[0][0]
# __________________________________________________________________________________________________
# p_re_lu_119 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_219[0][0]
# __________________________________________________________________________________________________
# conv2d_231 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_220 (BatchN (None, 24, 24, 112)  448         conv2d_231[0][0]
# __________________________________________________________________________________________________
# add_115 (Add)                   (None, 24, 24, 112)  0           add_114[0][0]
#                                                                  batch_normalization_220[0][0]
# __________________________________________________________________________________________________
# conv2d_232 (Conv2D)             (None, 24, 24, 112)  113008      add_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_221 (BatchN (None, 24, 24, 112)  448         conv2d_232[0][0]
# __________________________________________________________________________________________________
# p_re_lu_120 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_221[0][0]
# __________________________________________________________________________________________________
# conv2d_233 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_120[0][0]
# __________________________________________________________________________________________________
# batch_normalization_222 (BatchN (None, 24, 24, 112)  448         conv2d_233[0][0]
# __________________________________________________________________________________________________
# add_116 (Add)                   (None, 24, 24, 112)  0           add_115[0][0]
#                                                                  batch_normalization_222[0][0]
# __________________________________________________________________________________________________
# conv2d_234 (Conv2D)             (None, 24, 24, 112)  113008      add_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_223 (BatchN (None, 24, 24, 112)  448         conv2d_234[0][0]
# __________________________________________________________________________________________________
# p_re_lu_121 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_223[0][0]
# __________________________________________________________________________________________________
# conv2d_235 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_224 (BatchN (None, 24, 24, 112)  448         conv2d_235[0][0]
# __________________________________________________________________________________________________
# add_117 (Add)                   (None, 24, 24, 112)  0           add_116[0][0]
#                                                                  batch_normalization_224[0][0]
# __________________________________________________________________________________________________
# conv2d_236 (Conv2D)             (None, 24, 24, 112)  113008      add_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_225 (BatchN (None, 24, 24, 112)  448         conv2d_236[0][0]
# __________________________________________________________________________________________________
# p_re_lu_122 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_225[0][0]
# __________________________________________________________________________________________________
# conv2d_237 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_226 (BatchN (None, 24, 24, 112)  448         conv2d_237[0][0]
# __________________________________________________________________________________________________
# add_118 (Add)                   (None, 24, 24, 112)  0           add_117[0][0]
#                                                                  batch_normalization_226[0][0]
# __________________________________________________________________________________________________
# conv2d_238 (Conv2D)             (None, 24, 24, 112)  113008      add_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_227 (BatchN (None, 24, 24, 112)  448         conv2d_238[0][0]
# __________________________________________________________________________________________________
# p_re_lu_123 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_227[0][0]
# __________________________________________________________________________________________________
# conv2d_239 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_228 (BatchN (None, 24, 24, 112)  448         conv2d_239[0][0]
# __________________________________________________________________________________________________
# add_119 (Add)                   (None, 24, 24, 112)  0           add_118[0][0]
#                                                                  batch_normalization_228[0][0]
# __________________________________________________________________________________________________
# conv2d_240 (Conv2D)             (None, 24, 24, 112)  113008      add_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_229 (BatchN (None, 24, 24, 112)  448         conv2d_240[0][0]
# __________________________________________________________________________________________________
# p_re_lu_124 (PReLU)             (None, 24, 24, 112)  64512       batch_normalization_229[0][0]
# __________________________________________________________________________________________________
# conv2d_241 (Conv2D)             (None, 24, 24, 112)  113008      p_re_lu_124[0][0]
# __________________________________________________________________________________________________
# batch_normalization_230 (BatchN (None, 24, 24, 112)  448         conv2d_241[0][0]
# __________________________________________________________________________________________________
# add_120 (Add)                   (None, 24, 24, 112)  0           add_119[0][0]
#                                                                  batch_normalization_230[0][0]
# __________________________________________________________________________________________________
# conv2d_242 (Conv2D)             (None, 24, 24, 112)  113008      add_120[0][0]
# __________________________________________________________________________________________________
# batch_normalization_231 (BatchN (None, 24, 24, 112)  448         conv2d_242[0][0]
# __________________________________________________________________________________________________
# add_121 (Add)                   (None, 24, 24, 112)  0           p_re_lu_114[0][0]
#                                                                  batch_normalization_231[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 48, 48, 28)   0           add_121[0][0]
# __________________________________________________________________________________________________
# p_re_lu_125 (PReLU)             (None, 48, 48, 28)   64512       lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_232 (BatchN (None, 48, 48, 28)   112         conv2d_243[0][0]
# __________________________________________________________________________________________________
# p_re_lu_126 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_232[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_233 (BatchN (None, 48, 48, 28)   112         conv2d_244[0][0]
# __________________________________________________________________________________________________
# add_122 (Add)                   (None, 48, 48, 28)   0           p_re_lu_125[0][0]
#                                                                  batch_normalization_233[0][0]
# __________________________________________________________________________________________________
# conv2d_245 (Conv2D)             (None, 48, 48, 28)   7084        add_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_234 (BatchN (None, 48, 48, 28)   112         conv2d_245[0][0]
# __________________________________________________________________________________________________
# p_re_lu_127 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_234[0][0]
# __________________________________________________________________________________________________
# conv2d_246 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_235 (BatchN (None, 48, 48, 28)   112         conv2d_246[0][0]
# __________________________________________________________________________________________________
# add_123 (Add)                   (None, 48, 48, 28)   0           add_122[0][0]
#                                                                  batch_normalization_235[0][0]
# __________________________________________________________________________________________________
# conv2d_247 (Conv2D)             (None, 48, 48, 28)   7084        add_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_236 (BatchN (None, 48, 48, 28)   112         conv2d_247[0][0]
# __________________________________________________________________________________________________
# p_re_lu_128 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_236[0][0]
# __________________________________________________________________________________________________
# conv2d_248 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_237 (BatchN (None, 48, 48, 28)   112         conv2d_248[0][0]
# __________________________________________________________________________________________________
# add_124 (Add)                   (None, 48, 48, 28)   0           add_123[0][0]
#                                                                  batch_normalization_237[0][0]
# __________________________________________________________________________________________________
# conv2d_249 (Conv2D)             (None, 48, 48, 28)   7084        add_124[0][0]
# __________________________________________________________________________________________________
# batch_normalization_238 (BatchN (None, 48, 48, 28)   112         conv2d_249[0][0]
# __________________________________________________________________________________________________
# p_re_lu_129 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_238[0][0]
# __________________________________________________________________________________________________
# conv2d_250 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_129[0][0]
# __________________________________________________________________________________________________
# batch_normalization_239 (BatchN (None, 48, 48, 28)   112         conv2d_250[0][0]
# __________________________________________________________________________________________________
# add_125 (Add)                   (None, 48, 48, 28)   0           add_124[0][0]
#                                                                  batch_normalization_239[0][0]
# __________________________________________________________________________________________________
# conv2d_251 (Conv2D)             (None, 48, 48, 28)   7084        add_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_240 (BatchN (None, 48, 48, 28)   112         conv2d_251[0][0]
# __________________________________________________________________________________________________
# p_re_lu_130 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_240[0][0]
# __________________________________________________________________________________________________
# conv2d_252 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_241 (BatchN (None, 48, 48, 28)   112         conv2d_252[0][0]
# __________________________________________________________________________________________________
# add_126 (Add)                   (None, 48, 48, 28)   0           add_125[0][0]
#                                                                  batch_normalization_241[0][0]
# __________________________________________________________________________________________________
# conv2d_253 (Conv2D)             (None, 48, 48, 28)   7084        add_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_242 (BatchN (None, 48, 48, 28)   112         conv2d_253[0][0]
# __________________________________________________________________________________________________
# p_re_lu_131 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_242[0][0]
# __________________________________________________________________________________________________
# conv2d_254 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_131[0][0]
# __________________________________________________________________________________________________
# batch_normalization_243 (BatchN (None, 48, 48, 28)   112         conv2d_254[0][0]
# __________________________________________________________________________________________________
# add_127 (Add)                   (None, 48, 48, 28)   0           add_126[0][0]
#                                                                  batch_normalization_243[0][0]
# __________________________________________________________________________________________________
# conv2d_255 (Conv2D)             (None, 48, 48, 28)   7084        add_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_244 (BatchN (None, 48, 48, 28)   112         conv2d_255[0][0]
# __________________________________________________________________________________________________
# p_re_lu_132 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_244[0][0]
# __________________________________________________________________________________________________
# conv2d_256 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_245 (BatchN (None, 48, 48, 28)   112         conv2d_256[0][0]
# __________________________________________________________________________________________________
# add_128 (Add)                   (None, 48, 48, 28)   0           add_127[0][0]
#                                                                  batch_normalization_245[0][0]
# __________________________________________________________________________________________________
# conv2d_257 (Conv2D)             (None, 48, 48, 28)   7084        add_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_246 (BatchN (None, 48, 48, 28)   112         conv2d_257[0][0]
# __________________________________________________________________________________________________
# p_re_lu_133 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_246[0][0]
# __________________________________________________________________________________________________
# conv2d_258 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_133[0][0]
# __________________________________________________________________________________________________
# batch_normalization_247 (BatchN (None, 48, 48, 28)   112         conv2d_258[0][0]
# __________________________________________________________________________________________________
# add_129 (Add)                   (None, 48, 48, 28)   0           add_128[0][0]
#                                                                  batch_normalization_247[0][0]
# __________________________________________________________________________________________________
# conv2d_259 (Conv2D)             (None, 48, 48, 28)   7084        add_129[0][0]
# __________________________________________________________________________________________________
# batch_normalization_248 (BatchN (None, 48, 48, 28)   112         conv2d_259[0][0]
# __________________________________________________________________________________________________
# p_re_lu_134 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_248[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_249 (BatchN (None, 48, 48, 28)   112         conv2d_260[0][0]
# __________________________________________________________________________________________________
# add_130 (Add)                   (None, 48, 48, 28)   0           add_129[0][0]
#                                                                  batch_normalization_249[0][0]
# __________________________________________________________________________________________________
# conv2d_261 (Conv2D)             (None, 48, 48, 28)   7084        add_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_250 (BatchN (None, 48, 48, 28)   112         conv2d_261[0][0]
# __________________________________________________________________________________________________
# p_re_lu_135 (PReLU)             (None, 48, 48, 28)   64512       batch_normalization_250[0][0]
# __________________________________________________________________________________________________
# conv2d_262 (Conv2D)             (None, 48, 48, 28)   7084        p_re_lu_135[0][0]
# __________________________________________________________________________________________________
# batch_normalization_251 (BatchN (None, 48, 48, 28)   112         conv2d_262[0][0]
# __________________________________________________________________________________________________
# add_131 (Add)                   (None, 48, 48, 28)   0           add_130[0][0]
#                                                                  batch_normalization_251[0][0]
# __________________________________________________________________________________________________
# conv2d_263 (Conv2D)             (None, 48, 48, 28)   7084        add_131[0][0]
# __________________________________________________________________________________________________
# batch_normalization_252 (BatchN (None, 48, 48, 28)   112         conv2d_263[0][0]
# __________________________________________________________________________________________________
# add_132 (Add)                   (None, 48, 48, 28)   0           p_re_lu_125[0][0]
#                                                                  batch_normalization_252[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 96, 96, 7)    0           add_132[0][0]
# __________________________________________________________________________________________________
# p_re_lu_136 (PReLU)             (None, 96, 96, 7)    64512       lambda_12[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 96, 96, 1)    8           p_re_lu_136[0][0]
# ==================================================================================================
# Total params: 47,461,604
# Trainable params: 47,436,908
# Non-trainable params: 24,696
# __________________________________________________________________________________________________
# strInfo: True
# permut: True
# se: True
# prog_loss: False
# Train on 44230 samples, validate on 11058 samples
# Epoch 1/50
#  - 465s - loss: 0.1020 - val_loss: 0.1022
# Epoch 2/50
#  - 439s - loss: 0.0801 - val_loss: 0.0881
# Epoch 3/50
#  - 438s - loss: 0.0733 - val_loss: 0.0774
# Epoch 4/50
#  - 439s - loss: 0.0684 - val_loss: 0.0811
# Epoch 5/50
#  - 439s - loss: 0.0643 - val_loss: 0.0815
# Epoch 6/50
#  - 438s - loss: 0.0606 - val_loss: 0.0896
# Epoch 7/50
#  - 438s - loss: 0.0574 - val_loss: 0.1039
# Epoch 8/50
#  - 439s - loss: 0.0546 - val_loss: 0.0905
# Epoch 9/50
#  - 438s - loss: 0.0520 - val_loss: 0.0825
# Epoch 10/50
#  - 438s - loss: 0.0497 - val_loss: 0.0827
# Epoch 11/50
#  - 438s - loss: 0.0476 - val_loss: 0.0913
# Epoch 12/50
#  - 438s - loss: 0.0457 - val_loss: 0.0817
# Epoch 13/50
#  - 439s - loss: 0.0440 - val_loss: 0.0810
# Epoch 14/50
#  - 439s - loss: 0.0424 - val_loss: 0.0797
# Epoch 15/50
#  - 438s - loss: 0.0410 - val_loss: 0.0754
# Epoch 16/50
#  - 438s - loss: 0.0396 - val_loss: 0.0765
# Epoch 17/50
#  - 439s - loss: 0.0385 - val_loss: 0.0750
# Epoch 18/50
#  - 438s - loss: 0.0374 - val_loss: 0.0780
# Epoch 19/50
#  - 439s - loss: 0.0364 - val_loss: 0.0716
# Epoch 20/50
#  - 438s - loss: 0.0354 - val_loss: 0.0743
# Epoch 21/50
#  - 438s - loss: 0.0346 - val_loss: 0.0711
# Epoch 22/50
#  - 439s - loss: 0.0337 - val_loss: 0.0707
# Epoch 23/50
#  - 438s - loss: 0.0330 - val_loss: 0.0702
# Epoch 24/50
#  - 438s - loss: 0.0323 - val_loss: 0.0704
# Epoch 25/50
#  - 438s - loss: 0.0316 - val_loss: 0.0706
# Epoch 26/50
#  - 439s - loss: 0.0310 - val_loss: 0.0700
# Epoch 27/50
#  - 439s - loss: 0.0304 - val_loss: 0.0700
# Epoch 28/50
#  - 438s - loss: 0.0299 - val_loss: 0.0703
# Epoch 29/50
#  - 438s - loss: 0.0293 - val_loss: 0.0700
# Epoch 30/50
#  - 439s - loss: 0.0289 - val_loss: 0.0697
# Epoch 31/50
#  - 438s - loss: 0.0285 - val_loss: 0.0702
# Epoch 32/50
#  - 438s - loss: 0.0280 - val_loss: 0.0702
# Epoch 33/50
#  - 438s - loss: 0.0276 - val_loss: 0.0700
# Epoch 34/50
#  - 439s - loss: 0.0272 - val_loss: 0.0702
# Epoch 35/50
#  - 438s - loss: 0.0268 - val_loss: 0.0702
# Epoch 36/50
#  - 438s - loss: 0.0265 - val_loss: 0.0698
# Epoch 37/50
#  - 438s - loss: 0.0261 - val_loss: 0.0697
# Epoch 38/50
#  - 439s - loss: 0.0258 - val_loss: 0.0698
# Epoch 39/50
#  - 438s - loss: 0.0255 - val_loss: 0.0698
# Epoch 40/50
#  - 438s - loss: 0.0252 - val_loss: 0.0698
# Epoch 41/50
#  - 438s - loss: 0.0249 - val_loss: 0.0695
# Epoch 42/50
#  - 439s - loss: 0.0246 - val_loss: 0.0697
# Epoch 43/50
#  - 438s - loss: 0.0244 - val_loss: 0.0695
# Epoch 44/50
#  - 438s - loss: 0.0241 - val_loss: 0.0699
# Epoch 45/50
#  - 438s - loss: 0.0239 - val_loss: 0.0701
# Epoch 46/50
#  - 439s - loss: 0.0237 - val_loss: 0.0696
# Epoch 47/50
#  - 438s - loss: 0.0234 - val_loss: 0.0695
# Epoch 48/50
#  - 438s - loss: 0.0232 - val_loss: 0.0691
# Epoch 49/50
#  - 438s - loss: 0.0230 - val_loss: 0.0692
# Epoch 50/50
#  - 438s - loss: 0.0228 - val_loss: 0.0698
# training Runtime: 370.66 Minutes
# 0.04691567369633251

# %%
print(eval1, eval2, eval3, eval4)
# Out:
# 0.047165633551185096 0.04842394548630904 0.04661553580018263 0.04691567369633251

# %%
# import jovian
# jovian.commit(nb_filename='bone_sr_class.ipynb')

# %%
## 결과를 플롯하기 위한 함수 
def comparison_plot(start=0, n_figure=200, show=False):
    plot_row = 2
    plot_col = 3
    #n_figure = 200

#     predict_img = model.predict([low_img_val, disp_val, se_val],  batch_size, verbose=2)

    # np.savetxt('predict.txt',y_predict)

    plt.rcParams["figure.figsize"] = (20,8)
    for i_figure in range(0, n_figure):

        # fig = plt.figure(nrows=4, ncols=5)
        fig = plt.figure()
        
        
        # plt.subplots_adjust(hspace = 0.5, wspace = 0.3)
        # print('predict start:', start + i_figure * plot_row*plot_col)

        start_time = time.time()
        for i_col in range(0, plot_col):
            for i_row in range(0, plot_row):

                index = start + i_figure * plot_row * plot_col  + plot_row * i_col + i_row
                # print('index',index)
                one_y_orig = high_img_test[index].reshape(img_rows*upscale, img_cols*upscale).transpose()
                one_y_low = low_img_test[index].reshape(img_rows, img_cols).transpose()
                one_y_predict = predict_img[index].reshape(img_rows*upscale, img_cols*upscale).transpose()


                plt.subplot(plot_col, plot_row * 3, (plot_row *3 * i_col + i_row*3) + 1) # 2 * 3 * 4 + 1 * 3 + 3 = 24 + 3 + 3 = 30
                plt.imshow(one_y_low, cmap='Greys', vmin=0, vmax=1)
                plt.xticks([])
                plt.yticks([])
                # plt.ylabel("n:%d" % index+1)
                if i_col == plot_col - 1:
                    plt.xlabel("low-res.")

                plt.subplot(plot_col, plot_row*3, (plot_row *3 * i_col + i_row*3) + 2)
                plt.imshow(one_y_predict, cmap='Greys', vmin=0, vmax=1)
                plt.xticks([])
                plt.yticks([])
                # plt.ylabel("n:%d" % index + 1)
                if i_col == plot_col - 1:
                    plt.xlabel("predicted")
                plt.subplot(plot_col, plot_row * 3, (plot_row *3 * i_col + i_row*3) + 3)
                plt.imshow(one_y_orig, cmap='Greys', vmin=0, vmax=1)
                plt.xticks([])
                plt.yticks([])
                # plt.ylabel("n:%d" % index + 1)
                if i_col == plot_col - 1:
                    plt.xlabel("high-res.")


        end_time= (time.time() - start_time)/plot_row
        # print('computing time for predict : %f s' % end_time)
        #plt.savefig("../train/vae/cmp_epoch%03d_latent%02d_i%04d.png" % (epochs, latent_dim, i_figure))
        plt.tight_layout()

        
        import os
        outDir = "./output_fig"
        if not os.path.isdir(outDir):
            os.mkdir(outDir)
            
        plt.savefig("./output_fig/out_figure_%s.png" % i_figure,dpi=300)
        if show==True:
#             plt.figure(figsize=(2,2)) 
#             plt.rcParams['figure.figsize'] = [100, 50]
            plt.show()
        plt.close()

# %%
# 0번부터 3개의 데이터의 결과를 출력합니다.
# comparison_plot(150,1,True)

# %%
# 100번 부터 100개의 데이터를 출력합니다. (화면 출력 X)
# comparison_plot(100, 100, False)

# %%
#  permutational invariance 제대로 되는지 테스트

# diff_test2 = np.zeros((diff_test.shape[0],12,12,3,2))
# # 인위적으로 순서를 바꿔서 넣어봅니다.
# diff_test2[:,:,:,2,0] = diff_test[:,:,:,0]
# diff_test2[:,:,:,1,0] = diff_test[:,:,:,1]
# diff_test2[:,:,:,0,0] = diff_test[:,:,:,2]

# diff_test2[:,:,:,2,1] = diff_test[:,:,:,3]
# diff_test2[:,:,:,1,1] = diff_test[:,:,:,4]
# diff_test2[:,:,:,0,1] = diff_test[:,:,:,5]


# if strInfo==True:
# #     evaluate = model.evaluate([low_img_test, disp_test, se_test], high_img_test,  batch_size, verbose=2)
# #     predict_img = model.predict([low_img_test, disp_test, se_test],  batch_size, verbose=2)
# #     evaluate = model.evaluate([low_img_test, diff_test2, se_test], high_img_test,  batch_size, verbose=2)
# #     predict_img = model.predict([low_img_test, diff_test2, se_test],  batch_size, verbose=2)

#     evaluate = model.evaluate([low_img_test, diff_test2], high_img_test,  batch_size, verbose=2)
#     predict_img = model.predict([low_img_test, diff_test2],  batch_size, verbose=2)
    
# else:
#     evaluate = model.evaluate(low_img_test, high_img_test,  batch_size, verbose=2)
#     predict_img = model.predict(low_img_test,  batch_size, verbose=2)
    
    
# print('test accuracy(mae):', evaluate)
